# %%
# %load_ext autoreload
# %autoreload 2
from mmpp import MMPP
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 get_ipython().run_line_magic('load_ext', 'autoreload')
#       2 get_ipython().run_line_magic('autoreload', '2')
# ----> 3 from mmpp import MMPP
#
# ModuleNotFoundError: No module named 'mmpp'

# %%
op = MMPP("/zfn2/mannga/jobs/vortices/spectrum/d100_sinc4.zarr")
lista = op.scan(force=True)
# Out:
# [17:28:05] INFO     mmpp | INFO | Loaded single zarr file: /zfn2/mannga/jobs/vortices/spectrum/d100_sinc4.zarr

# %%
op = MMPP("/zfn2/mannga/jobs/vortices/spectrum/d100_sinc4.zarr")
lista = op.scan(force=False)
# Out:
# [17:29:25] INFO     mmpp | INFO | Loaded single zarr file: /zfn2/mannga/jobs/vortices/spectrum/d100_sinc4.zarr

# %%
op[0].p
# Out:
# [17:29:34] INFO     mmpp | INFO | Database: d100_sinc4, Structure: /
#                      ├── alpha (1, 11, 1296, 1296, 1) float32
#                      ├── fft
#                      │   ├── freq
#                      │   ├── m_z5-8
#                      │   │   ├── freqs (300,) float64
#                      │   │   ├── spec (300, 3) float64
#                      │   │   └── sum (300, 3) float64
#                      │   ├── m_z5-8_z0_m1
#                      │   │   ├── frequencies (300,) float64
#                      │   │   └── spectrum (300, 3) float64
#                      │   └── spectrum
#                      ├── m_z5-8 (599, 3, 1296, 1296, 3) float32
#                      ├── m_z5-8_z-1_m1
#                      │   ├── frequencies (300,) float64
#                      │   └── spectrum (300, 3) float64
#                      └── modes
#                          └── m_z5-8
#                              ├── arr (300, 3, 1296, 1296, 3) complex64
#                              └── freqs (300,) float64

# %%
op[0].fft.modes.plot

# %%
# %matplotlib widget
op[0].mpl.snapshot(dset="m_z11-14", z=-1)

# %%
op[0].p
# Out:
# [13:46:43] INFO     mmpp | INFO | Database: d100_sinc4, Structure: /
#                      ├── alpha (1, 11, 1296, 1296, 1) float32
#                      ├── fft
#                      │   ├── freq
#                      │   ├── m_z5-8_z0_m1
#                      │   │   ├── frequencies (300,) float64
#                      │   │   └── spectrum (300, 3) float64
#                      │   └── spectrum
#                      ├── m_z5-8 (599, 3, 1296, 1296, 3) float32
#                      └── m_z5-8_z-1_m1
#                          ├── frequencies (300,) float64
#                          └── spectrum (300, 3) float64

# %%
# %matplotlib widget
op[0].fft.plot_spectrum(
    dset="m_z5-8",
    z=0,  # Dataset name
    method=1,  # FFT method
    z_layer=0,  # Z-layer (-1 for last layer)
    window="hamming",
    log_scale=False,  # Use logarithmic scale
    # normalize=True,
    # save=True, # Whether to save the plot
    force=False,  # Don't force - check if cache works
)
# Out:
# [13:47:16] INFO     mmpp.fft | INFO | Loaded existing FFT data in 0.029s, spectrum shape: (300, 3)
#            INFO     mmpp.fft | INFO | ✓ Loaded existing FFT data for m_z5-8_z0_m1 (parameters verified)
# (<Figure size 1000x600 with 1 Axes>,
#  <Axes: title={'center': 'Power Spectrum - m_z5-8 (Method 1)'}, xlabel='Frequency (GHz)', ylabel='FFT Amplitude($10^{-6}$ arb. units)'>)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib widget
op[0].fft.modes.compute_modes(dset="m_z5-8")
fig, axes = op[0].fft.modes.plot_modes(
    frequency=2.5,
    dset="m_z5-8",
    # z_layer=0,
    # figsize=(15, 10),
    # show_combined=True,  # Pokaż combined plot (phase + magnitude)
    # component='all',     # Wszystkie komponenty (x, y, z)
    # normalize=True,
    # save_path="modes_2.5GHz.png"  # Zapisz do pliku
)
# Out:
# [17:29:55] INFO     mmpp.fft.modes | INFO | Opened zarr file: /zfn2/mannga/jobs/vortices/spectrum/d100_sinc4.zarr
#            INFO     mmpp.fft.modes | INFO | Loaded frequencies: 300 points, range 0.000 - 4.400 GHz
#            INFO     mmpp.fft.modes | INFO | Loaded spectrum data: shape (300,)
#            INFO     mmpp.fft.modes | INFO | Mode data already exists, use force=True to recompute
#            INFO     mmpp.fft.modes | INFO | Opened zarr file: /zfn2/mannga/jobs/vortices/spectrum/d100_sinc4.zarr
#            WARNING  mmpp.fft.modes | WARNING | No spectrum data found for dataset 'm'. Expected paths: fft/m/spec
#                     or fft/m/sum
#            INFO     mmpp.fft.modes | INFO | Opened zarr file: /zfn2/mannga/jobs/vortices/spectrum/d100_sinc4.zarr
#            INFO     mmpp.fft.modes | INFO | Loaded frequencies: 300 points, range 0.000 - 4.400 GHz
#            INFO     mmpp.fft.modes | INFO | Loaded spectrum data: shape (300,)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib widget
op[0].fft.modes.interactive_spectrum(
    dset="m_z5-8",
    z_layer=0,
)
# Out:
# [17:30:50] INFO     mmpp.fft.modes | INFO | Opened zarr file: /zfn2/mannga/jobs/vortices/spectrum/d100_sinc4.zarr
#            WARNING  mmpp.fft.modes | WARNING | No spectrum data found for dataset 'm'. Expected paths: fft/m/spec
#                     or fft/m/sum
#            INFO     mmpp.fft.modes | INFO | Opened zarr file: /zfn2/mannga/jobs/vortices/spectrum/d100_sinc4.zarr
#            INFO     mmpp.fft.modes | INFO | Loaded frequencies: 300 points, range 0.000 - 4.400 GHz
#            INFO     mmpp.fft.modes | INFO | Loaded spectrum data: shape (300,)
#            INFO     mmpp.fft.modes | INFO | Found 5 peaks in frequency range 0.0-40.0 GHz
#            INFO     mmpp.fft.modes | INFO | Interactive spectrum plot created. Click to select frequency,
#                     right-click to snap to peaks.
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
peaks = op[0].fft.modes.find_peaks()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 peaks = op[0].fft.modes.find_peaks()
#
# AttributeError: 'FFTModeInterface' object has no attribute 'find_peaks'

# %%
op[0].fft.modes.save_modes_animation(
    dset="m_z5-8",
    frequency=2.019,  # Stała częstotliwość
    save_path="/home/MateuszZelent/git/mmpp/temporal_balance.gif",  # Plik wyjściowy
    animation_type="temporal",  # Typ: oscylacje w czasie
    fps=24,  # Klatki na sekundę
    z_layer=-1,  # Warstwa Z
    component="z",  # Komponent magnetyzacji
    # ✨ NOWE: Zaawansowane opcje
    colormap="cmo.balance",  # Mapa cmocean
    use_midpoint_norm=True,  # Symetryczna normalizacja
    figsize=(10, 8),
    # Rozmiar figury
)
# Out:
# [17:36:40] INFO     mmpp.fft.modes | INFO | Opened zarr file: /zfn2/mannga/jobs/vortices/spectrum/d100_sinc4.zarr
#            WARNING  mmpp.fft.modes | WARNING | No spectrum data found for dataset 'm'. Expected paths: fft/m/spec
#                     or fft/m/sum
#            INFO     mmpp.fft.modes | INFO | Opened zarr file: /zfn2/mannga/jobs/vortices/spectrum/d100_sinc4.zarr
#            INFO     mmpp.fft.modes | INFO | Loaded frequencies: 300 points, range 0.000 - 4.400 GHz
#            INFO     mmpp.fft.modes | INFO | Loaded spectrum data: shape (300,)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 op[0].fft.modes.save_modes_animation(
#       2         dset="m_z5-8",
#       3         frequency=2.019,              # Stała częstotliwość
#       4         save_path="/home/MateuszZelent/git/mmpp/temporal_balance.gif",   # Plik wyjściowy
#       5         animation_type="temporal",          # Typ: oscylacje w czasie
#       6         fps=24,                             # Klatki na sekundę
#       7         z_layer=-1,                          # Warstwa Z
#       8         component='z',                      # Komponent magnetyzacji
#       9
#      10         # ✨ NOWE: Zaawansowane opcje
#      11         colormap="cmo.balance",                 # Mapa cmocean
#      12         use_midpoint_norm=True,             # Symetryczna normalizacja
#      13         figsize=(10, 8),
#      14                              dpi=200,                     # Rozmiar figury
#      15     )
#
# File ~/git/mmpp/mmpp/fft/modes.py:1476, in FFTModeInterface.save_modes_animation(self, frequency_range, frequency, save_path, dset, fps, z_layer, component, animation_type, **kwargs)
#    1473         log.info(f"Computing modes for dataset '{dset}'...")
#    1474         temp_analyzer.compute_modes(save=True)
# -> 1476     return temp_analyzer.save_modes_animation(
#    1477         frequency_range=frequency_range,
#    1478         frequency=frequency,
#    1479         save_path=save_path,
#    1480         fps=fps,
#    1481         z_layer=z_layer,
#    1482         component=component,
#    1483         animation_type=animation_type,
#    1484         **kwargs
#    1485     )
#    1486 else:
#    1487     # Use default analyzer
#    1488     if not self.mode_analyzer.modes_available:
#
# TypeError: FMRModeAnalyzer.save_modes_animation() got an unexpected keyword argument 'dpi'

# %%
import zarr

a = zarr.open_group("/zfn2/mannga/jobs/vortices/spectrum/d100_sinc4.zarr", mode="r")[
    "m_z5-8"
][:]

# %%
# Krok 1: Sprawdź dostępne datasety
import zarr

zarr_store = zarr.open(op[0].path, mode="r")
print("Dostępne datasety w zarr:")
for key in zarr_store.keys():
    if "m_" in key:
        print(f"  {key}: {zarr_store[key].shape}")

# Krok 2: Sprawdź czy istnieją obliczone mody
try:
    if "modes" in zarr_store:
        print("\nIstniejące mody:")
        for key in zarr_store["modes"].keys():
            print(f"  modes/{key}")
    else:
        print("\nBrak obliczonych modów")
except:
    print("\nBrak katalogu modes")

# %%
# Krok 3: Oblicz mody FMR dla datasetu m_z5-8
from mmpp.fft.modes import FMRModeAnalyzer

# Utwórz analizator modów dla konkretnego datasetu
analyzer = FMRModeAnalyzer(
    zarr_path=op[0].path,
    dataset_name="m_z5-8",  # Konkretny dataset
    debug=True,
)

print(f"Analizator utworzony dla datasetu: {analyzer.dataset_name}")

# Sprawdź czy mody już istnieją
if not analyzer.modes_available:
    print("Obliczam mody FMR z danych czasowych...")

    # Oblicz mody (może potrwać chwilę dla dużych danych)
    analyzer.compute_modes(
        z_slice=slice(None),  # Wszystkie warstwy z
        window=True,  # Okno Hanninga dla lepszego FFT
        save=True,  # Zapisz wyniki w zarr
        chunk_size=(50, 50),  # Rozmiar chunków dla zarr
    )
    print("Mody obliczone i zapisane!")
else:
    print("Mody już istnieją w danych!")

# %%
# Krok 4: Teraz wyświetl mody!

# Sprawdź dostępne częstotliwości
frequencies = analyzer.frequencies
print(f"Dostępne częstotliwości: {frequencies[0]:.3f} - {frequencies[-1]:.3f} GHz")
print(f"Liczba próbek: {len(frequencies)}")

# Znajdź częstotliwość najbliższą 2.5 GHz
target_freq = 2.5
closest_idx = np.argmin(np.abs(frequencies - target_freq))
actual_freq = frequencies[closest_idx]
print(f"Najbliższa częstotliwość do {target_freq} GHz: {actual_freq:.3f} GHz")

# Wyświetl mody dla tej częstotliwości
fig, axes = analyzer.plot_modes(
    frequency=actual_freq,
    z_layer=0,
    figsize=(15, 10),
    normalize=True,
    save_path=f"modes_{actual_freq:.3f}GHz.png",
)

plt.show()

# %%
# Krok 5: Interaktywne spektrum z modami
print("Uruchamiam interaktywne spektrum...")
print("INSTRUKCJE:")
print("- Lewy klik: wybierz dowolną częstotliwość")
print("- Prawy klik: snap do najbliższego piku")
print("- Zamknij okno gdy skończysz")

# Uruchom interaktywne spektrum
fig = analyzer.interactive_spectrum(
    z_layer=0,
    figsize=(16, 8),
    components=["x", "y", "z"],  # Pokaż wszystkie komponenty
)

plt.show()

# %%
# Test naprawionej funkcjonalności plot_modes
print("🔧 Test: plot_modes z automatycznym obliczaniem modów")

# To powinno teraz działać - automatycznie obliczy mody dla m_z5-8 jeśli nie istnieją
try:
    fig, axes = op[0].fft.modes.plot_modes(
        frequency=2.5,
        dset="m_z5-8",  # Konkretny dataset
        z_layer=0,
        figsize=(15, 10),
        normalize=True,
        save_path="modes_2.5GHz_auto.png",
    )
    print("✅ Sukces! plot_modes działa z automatycznym obliczaniem")
    plt.show()

except Exception as e:
    print(f"❌ Błąd: {e}")
    print("Prawdopodobnie nadal trzeba ręcznie obliczyć mody")

# %%
# Alternatywna metoda: ręczne obliczenie modów
print("🔧 Alternatywa: ręczne obliczenie modów przez interface")

# Oblicz mody dla konkretnego datasetu
try:
    print("Obliczam mody dla m_z5-8...")
    op[0].fft.modes.compute_modes(
        dset="m_z5-8",
        z_slice=slice(None),  # Wszystkie warstwy z
        window=True,  # Okno Hanninga
        save=True,  # Zapisz w zarr
    )
    print("✅ Mody obliczone!")

    # Teraz spróbuj wyświetlić
    fig, axes = op[0].fft.modes.plot_modes(
        frequency=2.5, dset="m_z5-8", z_layer=0, figsize=(15, 10), normalize=True
    )
    print("✅ Wizualizacja udana!")
    plt.show()

except Exception as e:
    print(f"❌ Błąd w alternatywnej metodzie: {e}")
    print("\nSpróbuj poprzednią metodę z FMRModeAnalyzer bezpośrednio")
