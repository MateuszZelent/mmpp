# %%
# 🎯 TEST ULTRA-GENTLE k≈0 COMPRESSION - Delikatne mapowanie strength!
# %load_ext autoreload
# %autoreload 2
import sys
modules_to_remove = [name for name in sys.modules if name.startswith('mmpp')]
for module in modules_to_remove:
    del sys.modules[module]
# %matplotlib widget
sys.path.insert(0, '/home/kkingstoun/git/mmpp')
import mmpp


import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
import numpy as np
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
job2 = mmpp.MMPP("/mnt/storage_2/scratch/pl0095-01/zelent/mannga/ksob/YIG_CoFeB_resonators_matrix/CoFeB_d_180nm_p_630nm_La_5um_ant_05um_YIG_70nm_fcut_4GHz_cz_5nm/comsol_verify/transmission/transmission_k_szulc_parameters8mt_v6.zarr",debug=True)
job2[0].t_sampl
# Out:
# 12:25:22 INFO     12:25:22 | mmpp | INFO | Loaded single zarr file:
#                   /mnt/storage_2/scratch/pl0095-01/zelent/mannga/ksob/YIG_CoFeB_resonators_matrix/CoFeB_d_180nm_p_6
#                   30nm_La_5um_ant_05um_YIG_70nm_fcut_4GHz_cz_5nm/comsol_verify/transmission/transmission_k_szulc_pa
#                   rameters8mt_v6.zarr
# 7.142857142857143e-11

# %%
# 🎯 TEST ULTRA-GENTLE k≈0 COMPRESSION - Delikatne mapowanie strength!
# %load_ext autoreload
# %autoreload 2
import sys
modules_to_remove = [name for name in sys.modules if name.startswith('mmpp')]
for module in modules_to_remove:
    del sys.modules[module]
# %matplotlib widget
sys.path.insert(0, '/home/kkingstoun/git/mmpp')
import mmpp


import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
import numpy as np

job = mmpp.MMPP("/mnt/storage_2/scratch/pl0095-01/zelent/mannga/ksob/YIG_CoFeB_resonators_matrix/CoFeB_d_180nm_p_630nm_La_5um_ant_05um_YIG_70nm_fcut_4GHz_cz_5nm/comsol_verify/transmission/final/transmission_k_szulc_parameters8mt_v15_olek_long_dispersion.zarr",debug=False)
disp_result = job[0].m_resonator[:,...,2].fft.dispersion.filters(
    remove_static=True,
    average=True,
    window="hann_space"
).compute_1d(axis="x", 
            # save_result=True,
            force=True,
            orthogonal_avg_mode="magnetization",
            flipx=True,
)
fig, (ax_left) = plt.subplots(1, 1, figsize=(6, 6), dpi=100, sharey=True)  # 🔑 sharey=True!

job[0].fft.dispersion.plot_result(
    disp_result,     # Gotowy wynik
    ax=ax_left,      # Twoje osie
    # lognorm=True,
    vmax=1000,
    trim_0f=None,
    k0_normalization=0,
    fmax=2.5,
    vmin=0.5,
    colornorm="symlognorm",
    # add_comsol_points="/mnt/storage_2/scratch/pl0095-01/zelent/mannga/ksob/YIG_CoFeB_resonators_matrix/CoFeB_d_180nm_p_630nm_La_5um_ant_05um_YIG_70nm_fcut_4GHz_cz_5nm/comsol_verify/vortex1_d180_lc470_8mT_A3.7_disp.txt",
    # comsol_k_col=2,
    # comsol_f_col=3,
    # comsol_style={"edgecolors": "white", "s": 20, "alpha": 0.3},
)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 07:59:00 WARNING  07:59:00 | mmpp.fft.dispersion.utils | WARNING | Magnetization data already has single component
#                   (shape[-1]=1). Ignoring component='perp' parameter and using existing data.
# (<Figure size 600x600 with 2 Axes>,
#  <Axes: title={'center': 'Spin-Wave Dispersion S(kx, f) - perp component'}, xlabel='$k$ [rad/μm]', ylabel='Frequency [GHz]'>)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
1069.0-8*11.50+7*2.50
# Out:
# 994.5

# %%
fig, (ax_left) = plt.subplots(1, 1, figsize=(6, 6), dpi=100, sharey=True)  # 🔑 sharey=True!

job[0].fft.dispersion.plot_result(
    disp_result,     # Gotowy wynik
    ax=ax_left,      # Twoje osie
    # lognorm=True,
    vmax=1000,
    trim_0f=None,
    k0_normalization=0,
    fmax=3.2,
    vmin=0.5,
    colornorm="symlognorm",
    add_comsol_points="/mnt/storage_2/scratch/pl0095-01/zelent/mannga/ksob/YIG_CoFeB_resonators_matrix/CoFeB_d_180nm_p_630nm_La_5um_ant_05um_YIG_70nm_fcut_4GHz_cz_5nm/comsol_verify/vortex1_d180_lc470_8mT_A3.7_disp.txt",
    comsol_k_col=2,
    comsol_f_col=3,
    comsol_style={"edgecolors": "white", "s": 20, "alpha": 0.1},
)
# Out:
# (<Figure size 600x600 with 2 Axes>,
#  <Axes: title={'center': 'Spin-Wave Dispersion S(kx, f) - perp component'}, xlabel='$k$ [rad/μm]', ylabel='Frequency [GHz]'>)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Out:
# 08:00:53 WARNING  08:00:53 | mmpp.fft | WARNING | Using dt from job.attrs['t_sampl']: 7.142857142857143e-11
#                   (dataset-specific t_sampl not found)
# 📊 RAW data.shape: (981, 1, 94, 4700, 1), min: -3.90482187e-01, max: 1.73579603e-01
# ⚙️  config.filter_type = ['remove_mean', 'remove_static']
# ⚙️  config.window_function = None
# 🔧 FILTERED data: min: -2.55951136e-01, max: 1.59662291e-01
# ⏭️  SKIPPED windowing (window_function=None)
# windowed.shape: (981, 1, 94, 4700, 1), min: -2.55951136e-01, max: 1.59662291e-01
# ⚙️  y_integration_mode = sum_m
# ⚙️  spatial_window_mode = pre_fft
# ⚙️  engine = numpy
# 🔧 FFT engine: numpy.fft
# ⚠️  PRE_FFT mode: Will compute 4551 separate FFTs (slower)
# 🔧 FILTERED data: min: -2.55951136e-01, max: 1.59662291e-01
# ⏭️  SKIPPED windowing (window_function=None)
# windowed.shape: (981, 1, 94, 4700, 1), min: -2.55951136e-01, max: 1.59662291e-01
# ⚙️  y_integration_mode = sum_m
# ⚙️  spatial_window_mode = pre_fft
# ⚙️  engine = numpy
# ...

# %%
job = mmpp.MMPP("/mnt/storage_2/scratch/pl0095-01/zelent/mannga/ksob/YIG_CoFeB_resonators_matrix/CoFeB_d_180nm_p_630nm_La_5um_ant_05um_YIG_70nm_fcut_4GHz_cz_5nm/comsol_verify/transmission/final/lc630/transmission_k_szulc_parameters8mt_v15_olek_long_dispersion.zarr",debug=False)
disp_result = job[0].m_resonator[:,...,2].fft.dispersion.filters(
    remove_static=True,
    average=True,
    window="hann_space"
).compute_1d(axis="x", 
            # save_result=True,
            force=True,
            orthogonal_avg_mode="magnetization",
            flipx=True,
)

job = mmpp.MMPP("/mnt/storage_2/scratch/pl0095-01/zelent/mannga/ksob/YIG_CoFeB_resonators_matrix/CoFeB_d_180nm_p_630nm_La_5um_ant_05um_YIG_70nm_fcut_4GHz_cz_5nm/comsol_verify/transmission/final/lc630/transmission_k_szulc_parameters8mt_v15_olek_long.zarr",debug=False)

result_raw = job[0].m_layer[:,...,2].fft.transmission(
    filter_type=["remove_mean", "remove_static"],
    use_cache=False,
    save=False,
    cache_path="/tmp/fft_cache",
    window_function=None,          # Brak okna
    spatial_window=150,              # 5 punktów x
    spatial_step=1,
    average_mode="none",           # Tylko y=0, z=0
    component_weights=(1, 1, 1),   # Tylko mz
    normalize="none",              # Surowa moc
    y_integration_mode="sum_m",
    engine="numpy",
    spatial_window_mode="pre_fft"
    # raw_fft_output=True,
)
# Out:
# 13:11:34 WARNING  13:11:34 | mmpp.fft.dispersion.utils | WARNING | Magnetization data already has single component
#                   (shape[-1]=1). Ignoring component='perp' parameter and using existing data.
# 13:12:42 WARNING  13:12:42 | mmpp.fft | WARNING | Using dt from job.attrs['t_sampl']: 7.142857142857143e-11
#                   (dataset-specific t_sampl not found)
# 📊 RAW data.shape: (981, 1, 94, 6300, 1), min: -4.01081502e-01, max: 1.62602529e-01
# ⚙️  config.filter_type = ['remove_mean', 'remove_static']
# ⚙️  config.window_function = None
# 🔧 FILTERED data: min: -2.44862452e-01, max: 1.59760326e-01
# ⏭️  SKIPPED windowing (window_function=None)
# 🔧 FILTERED data: min: -2.44862452e-01, max: 1.59760326e-01
# ⏭️  SKIPPED windowing (window_function=None)
# windowed.shape: (981, 1, 94, 6300, 1), min: -2.44862452e-01, max: 1.59760326e-01
# ⚙️  y_integration_mode = sum_m
# ⚙️  spatial_window_mode = pre_fft
# ⚙️  engine = numpy
# 🔧 FFT engine: numpy.fft
# ...

# %%
import matplotlib.pyplot as plt
plt.rcParams['text.usetex'] = False

fig, axs = plt.subplots(1, 3, figsize=(16, 6), dpi=100, sharey=True)  # 🔑 sharey=True!

ax_left, ax_right, ax_third = axs
job[0].fft.dispersion.plot_result(
    disp_result,     # Gotowy wynik
    ax=ax_left,      # Twoje osie
    colornorm="symlognorm",
    colornorm_kwargs={ "linthresh": 5,    # Wartości <5 → linear, >5 → log
    "vmin": 0.5,       # Ukryj bardzo słaby szum
    "vmax": 100,       # Ogranicz do maksymalnego sygnału
    }
    # vmax=100,
    trim_0f=None,
    k0_normalization=1,
    fmax=3.3,
    # add_comsol_points="/mnt/storage_2/scratch/pl0095-01/zelent/mannga/ksob/YIG_CoFeB_resonators_matrix/CoFeB_d_180nm_p_630nm_La_5um_ant_05um_YIG_70nm_fcut_4GHz_cz_5nm/comsol_verify/vortex1_d180_lc470_8mT_A3.7_disp.txt",
    # comsol_k_col=2,
    # comsol_f_col=3,
    # comsol_style={"edgecolors": "lime", "s": 20, "alpha": 0.3},
)
x=18000  # 2 µm

figa, ax_cross, minima_freqs  = result_raw.plot_transmission_crosssection(
    ax=ax_third,
    x=x*1e-9,        # 🔑 Pozycja x w metrach (2 µm)
    freq_unit="GHz",
    trim_0f=0,        # Opcjonalnie: usuń najniższe f
    color="red",
    fmax=4.6,
    flip=True,
    linewidth=3.3,
    find_minima={ 'distance': 10, 
            'freq_range': (1.9, 2.8),
            # 'threshold': 0.001,
            },
    mark_on_ax=ax_right,  # ✅ Skala log dla transmission!" log dla transmission!"
)
# ax_right.axvline(x)
# ax_right.set_ylim(0, 2.75)

result_raw.plot_transmission(
    ax=ax_right,
    debug=True,
    plot_config={
        "freq_unit": "GHz",
        "x_unit": "um",
        "trim_0f":0,  # 🔑 Usuń 5 najniższych punktów częstotliwości!
        # "vmax": 1,
        "fmax":3.3,
        "cmap": "inferno",
    }
)


# 📏 Dodaj linie poziome dla wybranych częstotliwości
horizontal_lines = minima_freqs 

for ax in axs[:-1]:
    for freq in horizontal_lines:
        # Linia na lewym wykresie (dispersion)
        ax.axhline(y=freq, color='lime', linestyle='--', linewidth=2, alpha=0.6, zorder=10)
        

for freq in horizontal_lines:
        # Linia na lewym wykresie (dispersion)
        axs[-1].axhline(y=freq, color='green', linestyle='--', linewidth=2, alpha=0.6, zorder=10)
        
        # Opcjonalnie: dodaj label z wartością częstotliwości na prawym wykresie
        ax_third.text(ax_right.get_xlim()[1] * 0.15, freq, f'{freq} GHz', 
                    color='white', fontsize=10, fontweight='bold',
                    ha='left', va='bottom', 
                    bbox=dict(boxstyle='round,pad=0.3', facecolor='black', alpha=0.6))
fig.text(0.5, 0.01, "LC630", ha='center', fontsize=12)
plt.tight_layout()
# Out:
#   Cell In[284], line 11
#     colornorm_kwargs={
#                      ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %% [markdown]
# # 🎯 Poprawne użycie `mark_on_ax` - automatyczne linie cięcia
#
# Nowe API: `plot_transmission_crosssection` automatycznie rysuje linię pionową na wykresie transmission!
#
# ## ✅ Jednostki x:
# - **Gdy `dx` jest dostępne (nm):** `x_positions` są w **nanometrach**
# - Podaj `x` bezpośrednio w nanometrach (np. `x=15` dla 15 nm)
# - Lub użyj `x=15e-9` (metry) - automatycznie przekonwertowane
#
# ## 🎨 Parametr `mark_on_ax`:
# - Przekaż `mark_on_ax=ax_right` aby narysować linię na wykresie transmission
# - Linia będzie miała ten sam kolor co crosssection
# - Automatycznie dodana label w legendzie

# %%
# 🎯 PRZYKŁAD: Automatyczne linie cięcia z mark_on_ax

fig, (ax_left, ax_right, ax_third) = plt.subplots(1, 3, figsize=(18, 6), dpi=100, sharey=True)

# LEWY: Dyspersja
job[0].fft.dispersion.plot_result(
    disp_result,
    ax=ax_left,
    vmax=100,
    trim_0f=None,
    k0_normalization=30,
    fmax=3,
    add_comsol_points="/mnt/storage_2/scratch/pl0095-01/zelent/mannga/ksob/YIG_CoFeB_resonators_matrix/CoFeB_d_180nm_p_630nm_La_5um_ant_05um_YIG_70nm_fcut_4GHz_cz_5nm/comsol_verify/vortex1_d180_lc470_8mT_A3.7_disp.txt",
    comsol_k_col=2,
    comsol_f_col=3,
    find_minima={distance=10},
    comsol_style={"edgecolors": "white", "s": 20, "alpha": 0.2},
)

# ŚRODEK: Transmission (mapa 2D)
result_raw.plot_transmission(
    ax=ax_right,
    plot_config={
        "freq_unit": "GHz",
        "x_unit": "nm",  # 🔑 Explicite nm!
        "trim_0f": 0,
        "cmap": "inferno",
        "fmax": 3,
    }
)

# PRAWY: Crosssection z automatyczną linią na ax_right
x_nm = 15  # Pozycja w nanometrach

result_raw.plot_transmission_crosssection(
    ax=ax_third,
    x=x_nm,  # 🔑 Bezpośrednio nanometry!
    freq_unit="GHz",
    trim_0f=0,
    color="red",
    flip=True,  # Częstotliwość pionowo (jak dyspersja)
    linewidth=2.5,
    log_scale=True,
    mark_on_ax=ax_right,  # 🔥 AUTOMATYCZNA LINIA na wykresie transmission!
)

plt.tight_layout()
plt.show()

print(f"✅ Crosssection w x = {x_nm} nm")
print(f"✅ Automatyczna linia pionowa dodana na wykresie transmission")
# Out:
#   Cell In[205], line 16
#     find_minima={distance=10}
#                  ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %% [markdown]
# # 🔍 NOWE: Automatyczne znajdowanie minimów transmisji!
#
# Parametr `find_minima` automatycznie znajduje lokalne minima w danych transmisji i zwraca ich częstotliwości.
#
# ## ✅ Parametry `find_minima`:
# ```python
# find_minima = {
#     'height': None,        # Maksymalna wysokość dla minimów (default: median)
#     'distance': 5,         # Minimalna odległość między minimami w punktach
#     'prominence': None,    # Minimalna prominence (opcjonalne)
#     'width': None,         # Minimalna szerokość (opcjonalne)
#     'mark': True,          # Czy zaznaczyć minima na wykresie
#     'color': 'cyan',       # Kolor markerów
#     'marker': 'o',         # Styl markera
#     'markersize': 8,       # Rozmiar markera
# }
# ```
#
# ## 🎯 Zwracane wartości:
# ```python
# fig, ax, minima_freqs = result.plot_transmission_crosssection(
#     x=15,
#     find_minima={'distance': 10, 'color': 'lime'}
# )
# # minima_freqs = [1.23, 2.45, 3.67, ...]  # Lista częstotliwości w GHz
# ```

# %%
# 🎯 PRZYKŁAD: Znajdowanie minimów i rysowanie linii poziomych

# Utwórz 4 panele: dyspersja + transmission + 2x crosssection
fig, axs = plt.subplots(1, 4, figsize=(24, 6), dpi=100, sharey=True)
ax_disp, ax_trans, ax_cross1, ax_cross2 = axs

# PANEL 1: Dyspersja
job[0].fft.dispersion.plot_result(
    disp_result,
    ax=ax_disp,
    vmax=100,
    k0_normalization=30,
    fmax=4.6,
    add_comsol_points="/mnt/storage_2/scratch/pl0095-01/zelent/mannga/ksob/YIG_CoFeB_resonators_matrix/CoFeB_d_180nm_p_630nm_La_5um_ant_05um_YIG_70nm_fcut_4GHz_cz_5nm/comsol_verify/vortex1_d180_lc470_8mT_A3.7_disp.txt",
    comsol_k_col=2,
    comsol_f_col=3,
    comsol_style={"edgecolors": "white", "s": 20, "alpha": 0.2},
)

# PANEL 2: Transmission (mapa 2D)
result_raw.plot_transmission(
    ax=ax_trans,
    plot_config={
        "freq_unit": "GHz",
        "x_unit": "nm",
        "trim_0f": 0,
        "cmap": "inferno",
        "fmax": 4.6,
    }
)

# PANEL 3: Crosssection x=15nm z minimami
x1_nm = 15
fig, ax_cross1, minima1 = result_raw.plot_transmission_crosssection(
    ax=ax_cross1,
    x=x1_nm,
    freq_unit="GHz",
    trim_0f=0,
    fmax=4.6,
    color="red",
    flip=True,
    linewidth=2.5,
    mark_on_ax=ax_trans,
    find_minima={
        'distance': 10,      # Minimalna odległość 10 punktów
        'prominence': 0.1,   # Minimalna prominence
        'color': 'lime',     # Zielone markery
        'markersize': 10,
    }
)

# PANEL 4: Crosssection x=8000nm z minimami
x2_nm = 8000
fig, ax_cross2, minima2 = result_raw.plot_transmission_crosssection(
    ax=ax_cross2,
    x=x2_nm,
    freq_unit="GHz",
    trim_0f=0,
    fmax=4.6,
    color="blue",
    flip=True,
    linewidth=2.5,
    mark_on_ax=ax_trans,
    find_minima={
        'distance': 10,
        'prominence': 0.1,
        'color': 'cyan',
        'markersize': 10,
    }
)

# 📏 Dodaj linie poziome dla minimów na WSZYSTKICH wykresach
# Użyj minimów z pierwszego crosssection
if minima1:
    for freq in minima1:
        # Linie na dyspersji i transmission
        for ax in [ax_disp, ax_trans]:
            ax.axhline(y=freq, color='lime', linestyle='--', linewidth=1.5, alpha=0.5, zorder=10)
        
        # Label tylko na transmission
        ax_trans.text(
            ax_trans.get_xlim()[1] * 0.05, freq, 
            f'{freq:.2f} GHz', 
            color='lime', fontsize=9, fontweight='bold',
            ha='left', va='bottom', 
            bbox=dict(boxstyle='round,pad=0.3', facecolor='black', alpha=0.6)
        )

# Użyj minimów z drugiego crosssection
if minima2:
    for freq in minima2:
        # Linie tylko na crosssections
        for ax in [ax_cross1, ax_cross2]:
            ax.axhline(y=freq, color='cyan', linestyle=':', linewidth=1.5, alpha=0.5, zorder=10)

plt.tight_layout()
plt.show()

print(f"✅ Znaleziono {len(minima1) if minima1 else 0} minimów w x={x1_nm}nm")
print(f"   Częstotliwości: {[f'{f:.2f}' for f in minima1] if minima1 else []}")
print(f"✅ Znaleziono {len(minima2) if minima2 else 0} minimów w x={x2_nm}nm")
print(f"   Częstotliwości: {[f'{f:.2f}' for f in minima2] if minima2 else []}")

# %%
job = mmpp.MMPP("/zfn2/mannga/jobs/mateuszz/transmission/v13_olek_long.zarr",debug=True)
job[0].p

dane = job[0].mlayer[:,-1,:,:,2].numpy()
# Out:
# /
# ├── B_ext (1, 25, 94, 4700, 3) float32
# ├── fft
# │   └── dispersion
# │       └── mlayer
# │           └── dispersion1d_a945e8e32ba0bc3ce299e6f56fd32cd5d10cf18c
# │               ├── S (4700, 100) float64
# │               ├── f_axis (100,) float64
# │               └── k_axis (4700,) float64
# ├── m_stab (1, 25, 94, 4700, 3) float32
# ├── mlayer (981, 10, 94, 4700, 3) float32
# ├── mmolek (981, 1, 94, 4700, 3) float32
# ├── regions (1, 25, 94, 4700, 1) float32
# └── table
#     ├── B_extx (7000,) float64
#     ├── B_exty (7000,) float64
#     ├── B_extz (7000,) float64
#     ├── mx (7000,) float64
#     ├── my (7000,) float64
#     ├── mz (7000,) float64
#     ├── step (7000,) float64
#     └── t (7000,) float64

# %%
dane2 = dane-dane.mean(axis=0)
dane2 = dane2 - dane2[0, ...]  

dane2.shape
dt=job[0].sampling_interval

freqs = np.fft.rfftfreq(dane2.shape[0], dt)
fft = np.fft.rfft(dane2,axis=0)
print(fft.shape)
# Out:
# (491, 94, 4700)

# %%
job = mmpp.MMPP("/zfn2/mannga/jobs/mateuszz/transmission/v13_olek_long.zarr",debug=False)

result_raw = job[0].mlayer[:500,...,2].fft.transmission(
    filter_type=None,
    use_cache=False,
    save=False,
    cache_path="/tmp/fft_cache",
    window_function=None,          # Brak okna
    spatial_window=100,              # 5 punktów x
    spatial_step=1,
    average_mode="none",           # Tylko y=0, z=0
    component_weights=(1, 1, 1),   # Tylko mz
    normalize="none",              # Surowa moc
    y_integration_mode="sum_m",
    engine="numpy",
    spatial_window_mode="pre_fft"
    # raw_fft_output=True,
)
# Out:
# 18:53:07 WARNING  18:53:07 | mmpp.fft | WARNING | Using dt from job.attrs['t_sampl']: 7.142857142857143e-11
#                   (dataset-specific t_sampl not found)
# 📊 RAW data.shape: (500, 1, 94, 4700, 1), min: -3.40761453e-01, max: 1.71177864e-01
# ⚙️  config.filter_type = None
# ⚙️  config.window_function = None
# ⏭️  SKIPPED filtering (filter_type=None)
# ⏭️  SKIPPED windowing (window_function=None)
# windowed.shape: (500, 1, 94, 4700, 1), min: -3.40761453e-01, max: 1.71177864e-01
# ⚙️  y_integration_mode = sum_m
# ⚙️  spatial_window_mode = pre_fft
# ⚙️  engine = numpy
# 🔧 FFT engine: numpy.fft
# ⚠️  PRE_FFT mode: Will compute 4601 separate FFTs (slower)
# Computing FFT per window (pre_fft mode):   0%|          | 0/4601 [00:00<?, ?win/s]
# ✅ PRE_FFT complete: computed 4601 FFTs

# %%
dane2 = dane[:500,...]#-dane[:500,...].mean(axis=0)

# dane2 = dane2 - dane2[0, ...] 
print(dane2.shape, dane2.min(), dane2.max())

#metoda 1
fft = np.fft.rfft(dane2,axis=0)
fft = np.sum(np.abs(fft),axis=1)
print(fft.shape,np.abs(fft).min() ,np.abs(fft).max())

#metoda 2

fft = np.fft.rfft(np.sum(dane2,axis=1),axis=0)
print(fft.shape,np.abs(fft).min() ,np.abs(fft).max())
# Out:
# (500, 94, 4700) -0.34076145 0.17117786
# (251, 4700) 6.131458e-05 2255.4807
# (251, 4700) 2.06553e-05 1186.1891

# %%
fig, (ax_left, ax_right) = plt.subplots(1, 2, figsize=(16, 6), dpi=100)  # 🔑 sharey=True!


result_raw.plot_transmission(
    ax=ax_right,
    debug=True,
    plot_config={
        "freq_unit": "GHz",
        "x_unit": "um",
        "trim_0f":5,  # 🔑 Usuń 5 najniższych punktów częstotliwości!
        # "vmax": 1000,
        # "fmax": 5.75,
        "cmap": "inferno",
    }
)


im = ax_left.imshow(np.sqrt(np.real(fft[10:])**2 + np.imag(fft[10:])**2) ,aspect='auto',extent=[0,10000,0,freqs.max()],cmap='inferno')
plt.colorbar(im, ax=ax_left, label='FFT Magnitude')
horizontal_lines = [1.32e9, 2.21e9]  # GHz

for freq in horizontal_lines:
    # Linia na lewym wykresie (dispersion)
    plt.axhline(y=freq, color='white', linestyle='--', linewidth=2, alpha=0.1, zorder=10)
    
    # Linia na prawym wykresie (transmission)
    plt.axhline(y=freq, color='white', linestyle='--', linewidth=2, alpha=0.1, zorder=10)

x=-2000
plt.axvline(10000+x, color='white', linestyle='--', linewidth=2, alpha=0.1, zorder=1)
# Out:
# ...
# 🔍 DEBUG: TransmissionPlotter.plot()
# ...
# Config: TransmissionPlotConfig(which='transmission', freq_unit='GHz', x_unit='um', cmap='inferno', log_scale=False, show_colorbar=True, vmin=None, vmax=None, title=None, trim_0f=5, fmax=None)
# result.dx = 5.000e-09 m (5.000 nm)
# result.x_positions shape: (4601,)
# result.x_positions[0:5]: [247.5 252.5 257.5 262.5 267.5]
# result.frequencies shape: (251,)
#
# Frequency scaling:
#   freq_unit = GHz
#   freq_scale = 1e-09
#   freqs[0:5] = [0.    0.028 0.056 0.084 0.112]
#
# Applying trim_0f:
#   trim_0f = 5
#   trim_idx = 5
#   Setting data[0:5, :] to zero
#
# X-axis setup:
#   result.dx = 5.000e-09 m (5.000 nm)
#   x_positions shape = (4601,)
#   x_positions[0:5] = [247.5 252.5 257.5 262.5 267.5]
#   x_edges[0:5] = [245. 250. 255. 260. 265.]
#   x_unit = um
#   ✅ dx available → x should be in nm
#
# Axis labels:
#   xlabel = 'x (nm)'
#   ylabel = 'Frequency (GHz)'
#   config.x_unit = 'um'
#   Logic: x_unit=um, dx=5e-09 → xlabel=x (nm)
# ...

# %%
print(fft.shape)

# %%
plt.figure(dpi=100)
plt.plot(freqs/1e9,np.abs(fft[:,-2000]),color="gray")

for freq in horizontal_lines:
    # Linia na lewym wykresie (dispersion)
    plt.axvline(x=freq/1e9, color='white', linestyle='--', linewidth=2, alpha=0.5, zorder=10)
    
    # Linia na prawym wykresie (transmission)
    plt.axvline(x=freq/1e9, color='white', linestyle='--', linewidth=2, alpha=0.5, zorder=10)

# %%
job = mmpp.MMPP("/mnt/storage_2/scratch/pl0095-01/zelent/mannga/ksob/YIG_CoFeB_resonators_matrix/CoFeB_d_180nm_p_630nm_La_5um_ant_05um_YIG_70nm_fcut_4GHz_cz_5nm/comsol_verify/transmission/transmission_k_szulc_parameters8mt_v6.zarr",debug=True)
job[0].dx

# %%
fig, ax = plt.subplots(figsize=(10, 6),dpi=100)
ax.plot(freqs/1e9, np.abs(fft)[:,200]/2600)

# result_raw.plot_transmission_crosssection(
#     ax=ax,
#     x=1000,        # 🔑 Pozycja x w metrach (2 µm)
#     freq_unit="GHz",
#     trim_0f=10,        # Opcjonalnie: usuń najniższe f
#     color="red",
#     # flip=True,
#     linewidth=2.5,
#     # log_scale=True,  # ✅ Skala log dla transmission!"
# )

# %%
# 🎯 Metoda: Oddziel obliczenie od plotowania
# Stwórz własną figurę i użyj plot_result() zamiast plot_dispersion()

# Przykład: Dwupanelowy wykres z dyspersją i transmisją



# KROK 1: Oblicz dyspersję RAZ (to jest kosztowne)
disp_result = job[0].m_layer[:100,...].fft.dispersion.filters(
    remove_static=True,
    average=True,
    window=None
).compute_1d(
    axis="x",
    force=False,
    save_result=True,  # Zapisz do cache'u na dysku
)

# KROK 2: Plotuj wielokrotnie (to jest szybkie!)
# Możesz teraz plotować ten sam wynik wielokrotnie z różnymi ustawieniami wizualnymi
fig_ignored, ax_left = job[0].fft.dispersion.plot_result(
    disp_result,  # 🔑 Przekaż gotowy wynik!
    ax=ax_left,  # 🔑 Użyj własnego ax!
    lognorm=True,
    k0_normalization=30,
    k0_normalization_width=1,
    cmap="cmc.davos",
    vmax=0.01,
    kscale="rad_um",
    add_comsol_points="/mnt/storage_2/scratch/pl0095-01/zelent/mannga/ksob/YIG_CoFeB_resonators_matrix/CoFeB_d_180nm_p_630nm_La_5um_ant_05um_YIG_70nm_fcut_4GHz_cz_5nm/comsol_verify/vortex1_d180_lc470_8mT_A3.7_disp.txt",
    comsol_k_col=2,
    comsol_f_col=3,
    comsol_style={"edgecolors": "white", "s": 20, "alpha": 0.2},
)

# Dodaj wykres transmisji na prawym panelu
x_index = len(trans_result.x_positions) // 2
transmission_slice = trans_result.transmission[:, x_index]
freqs_trans_ghz = trans_result.frequencies / 1e9

ax_right.plot(transmission_slice, freqs_trans_ghz, linewidth=2, color='red')
ax_right.set_xlabel('Transmission T(f)', fontsize=12)
ax_right.set_ylabel('Frequency (GHz)', fontsize=12)
ax_right.set_title(f'Transmission Profile (x={trans_result.x_positions[x_index]:.1f})', 
                   fontsize=14, fontweight='bold')
ax_right.grid(True, alpha=0.3)

# Synchronizuj osie Y
y_limits = ax_left.get_ylim()
ax_right.set_ylim(y_limits)

plt.tight_layout()
plt.show()

print("✓ Dyspersja obliczona RAZ, plotowana wielokrotnie!")
print(f"✓ Wynik zapisany w: {disp_result}")

# %%
# 🎯 Metoda: Oddziel obliczenie od plotowania
# Stwórz własną figurę i użyj plot_result() zamiast plot_dispersion()

# Przykład: Dwupanelowy wykres z dyspersją i transmisją
fig, (ax_left, ax_right) = plt.subplots(1, 2, figsize=(16, 6), dpi=100)

# Załaduj dane dyspersji
zarr_path = "/mnt/storage_2/scratch/pl0095-01/zelent/mannga/ksob/YIG_CoFeB_resonators_matrix/CoFeB_d_180nm_p_630nm_La_5um_ant_05um_YIG_70nm_fcut_4GHz_cz_5nm/comsol_verify/k_szulc_parameters8mt.zarr"
job = mmpp.MMPP(zarr_path, debug=True)

# KROK 1: Oblicz dyspersję RAZ (to jest kosztowne)
disp_result = job[0].m_layer[:100,...].fft.dispersion.filters(
    remove_static=True,
    average=True,
    window=None
).compute_1d(
    axis="x",
    force=False,
    save_result=True,  # Zapisz do cache'u na dysku
)

# KROK 2: Plotuj wielokrotnie (to jest szybkie!)
# Możesz teraz plotować ten sam wynik wielokrotnie z różnymi ustawieniami wizualnymi
fig_ignored, ax_left = job[0].fft.dispersion.plot_result(
    disp_result,  # 🔑 Przekaż gotowy wynik!
    ax=ax_left,  # 🔑 Użyj własnego ax!
    lognorm=True,
    k0_normalization=30,
    k0_normalization_width=1,
    cmap="cmc.davos",
    vmax=0.01,
    kscale="rad_um",
    add_comsol_points="/mnt/storage_2/scratch/pl0095-01/zelent/mannga/ksob/YIG_CoFeB_resonators_matrix/CoFeB_d_180nm_p_630nm_La_5um_ant_05um_YIG_70nm_fcut_4GHz_cz_5nm/comsol_verify/vortex1_d180_lc470_8mT_A3.7_disp.txt",
    comsol_k_col=2,
    comsol_f_col=3,
    comsol_style={"edgecolors": "white", "s": 20, "alpha": 0.2},
)

# Dodaj wykres transmisji na prawym panelu
x_index = len(trans_result.x_positions) // 2
transmission_slice = trans_result.transmission[:, x_index]
freqs_trans_ghz = trans_result.frequencies / 1e9

ax_right.plot(transmission_slice, freqs_trans_ghz, linewidth=2, color='red')
ax_right.set_xlabel('Transmission T(f)', fontsize=12)
ax_right.set_ylabel('Frequency (GHz)', fontsize=12)
ax_right.set_title(f'Transmission Profile (x={trans_result.x_positions[x_index]:.1f})', 
                   fontsize=14, fontweight='bold')
ax_right.grid(True, alpha=0.3)

# Synchronizuj osie Y
y_limits = ax_left.get_ylim()
ax_right.set_ylim(y_limits)

plt.tight_layout()
plt.show()

print("✓ Dyspersja obliczona RAZ, plotowana wielokrotnie!")
print(f"✓ Wynik zapisany w: {disp_result}")

# %% [markdown]
# # 🎯 Transmisja z własnym `ax` - KOMPLETNY PRZYKŁAD
#
# Transmisja **już wspiera** parametr `ax`! Możemy łączyć dyspersję i transmisję w jednym układzie.

# %%
# 🚀 DEMONSTRACJA: Dyspersja + Transmisja w jednym układzie

import matplotlib.pyplot as plt

# Stwórz układ 1x2
fig, (ax_disp, ax_trans) = plt.subplots(1, 2, figsize=(18, 7), dpi=100)

# ========== LEWY PANEL: DYSPERSJA ==========
print("⏳ Obliczanie dyspersji...")
zarr_path_disp = "/mnt/storage_2/scratch/pl0095-01/zelent/mannga/ksob/YIG_CoFeB_resonators_matrix/CoFeB_d_180nm_p_630nm_La_5um_ant_05um_YIG_70nm_fcut_4GHz_cz_5nm/comsol_verify/k_szulc_parameters8mt.zarr"
job_disp = mmpp.MMPP(zarr_path_disp, debug=True)

# KROK 1: Oblicz dyspersję RAZ
disp_result = job_disp[0].m_layer[:100,...].fft.dispersion.filters(
    remove_static=True,
    average=True,
).compute_1d(
    axis="x",
    save_result=True,
)

# KROK 2: Plotuj na lewym panelu
print("📊 Plotowanie dyspersji na lewym panelu...")
job_disp[0].fft.dispersion.plot_result(
    disp_result,
    ax=ax_disp,  # 🔑 Przekaż własny ax!
    lognorm=True,
    k0_normalization=30,
    k0_normalization_width=1,
    vmax=0.01,
    kscale="rad_um",
    title="Dispersion S(k,f)",
    add_comsol_points="/mnt/storage_2/scratch/pl0095-01/zelent/mannga/ksob/YIG_CoFeB_resonators_matrix/CoFeB_d_180nm_p_630nm_La_5um_ant_05um_YIG_70nm_fcut_4GHz_cz_5nm/comsol_verify/vortex1_d180_lc470_8mT_A3.7_disp.txt",
    comsol_k_col=2,
    comsol_f_col=3,
    comsol_style={"edgecolors": "white", "s": 15, "alpha": 0.3},
)

# ========== PRAWY PANEL: TRANSMISJA ==========
print("⏳ Obliczanie transmisji...")
zarr_path_trans = "/mnt/storage_2/scratch/pl0095-01/zelent/mannga/ksob/YIG_CoFeB_resonators_matrix/CoFeB_d_180nm_p_630nm_La_5um_ant_05um_YIG_70nm_fcut_4GHz_cz_5nm/comsol_verify/transmission/transmission_k_szulc_parameters8mt_v5.zarr"
job_trans = mmpp.MMPP(zarr_path_trans, debug=True)

# KROK 1: Oblicz transmisję RAZ
trans_result = job_trans[0].fft.transmission(
    spatial_window=5,
    normalize="reference",
    reference_window=(0, 3),
)

# KROK 2: Plotuj na prawym panelu (używając plot_transmission z parametrem ax)
print("📊 Plotowanie transmisji na prawym panelu...")
trans_result.plot_transmission(
    ax=ax_trans,  # 🔑 Przekaż własny ax!
    plot_config={
        "freq_unit": "GHz",
        "log_scale": False,
        "cmap": "plasma",
        "title": "Transmission T(f,x)",
    }
)

# Synchronizuj osie Y (częstotliwość)
y_min = min(ax_disp.get_ylim()[0], ax_trans.get_ylim()[0])
y_max = max(ax_disp.get_ylim()[1], ax_trans.get_ylim()[1])
ax_disp.set_ylim(y_min, y_max)
ax_trans.set_ylim(y_min, y_max)

plt.tight_layout()
plt.show()

print("\n✅ Gotowe! Dyspersja + Transmisja w jednym układzie!")
print(f"📊 Dyspersja: {len(disp_result.k_axis)} punktów k, {len(disp_result.f_axis)} częstotliwości")
print(f"📊 Transmisja: {len(trans_result.x_positions)} pozycji x, {len(trans_result.frequencies)} częstotliwości")

# %% [markdown]
# # 📚 API Reference: Plotowanie z własnym `ax`
#
# ## 🎨 Dyspersja - DWA sposoby
#
# ### Sposób 1: `plot_dispersion()` z `ax` (oblicza + plotuje)
# ```python
# fig, ax = plt.subplots()
# job[0].fft.dispersion.plot_dispersion(
#     ax=ax,  # Twoje osie
#     axis="x",
#     lognorm=True,
#     # ... pozostałe parametry
# )
# ```
#
# ### Sposób 2: `compute_1d()` + `plot_result()` (oddzielnie)
# ```python
# # Oblicz raz
# result = job[0].fft.dispersion.compute_1d(axis="x", save_result=True)
#
# # Plotuj wielokrotnie
# fig, ax = plt.subplots()
# job[0].fft.dispersion.plot_result(
#     result,     # Pre-obliczony wynik
#     ax=ax,      # Twoje osie
#     lognorm=True,
#     # ... parametry wizualne
# )
# ```
#
# ---
#
# ## 📡 Transmisja - używa `result.plot_transmission(ax=...)`
#
# ```python
# # Oblicz raz
# trans_result = job[0].fft.transmission(spatial_window=5)
#
# # Plotuj z własnym ax
# fig, ax = plt.subplots()
# trans_result.plot_transmission(
#     ax=ax,  # Twoje osie
#     plot_config={
#         "freq_unit": "GHz",
#         "log_scale": False,
#         "cmap": "plasma",
#     }
# )
# ```
#
# ---
#
# ## 🎯 Złożone kompozycje
#
# ### 4-panelowy układ
# ```python
# fig, axes = plt.subplots(2, 2, figsize=(16, 12))
#
# # Dyspersja w różnych wariantach
# disp_result = job[0].fft.dispersion.compute_1d(axis="x")
# job[0].fft.dispersion.plot_result(disp_result, ax=axes[0,0], lognorm=False)
# job[0].fft.dispersion.plot_result(disp_result, ax=axes[0,1], lognorm=True)
#
# # Transmisja w różnych wariantach
# trans_result = job[0].fft.transmission()
# trans_result.plot_transmission(ax=axes[1,0], plot_config={"cmap": "viridis"})
# trans_result.plot_transmission(ax=axes[1,1], plot_config={"log_scale": True})
# ```
#
# ### Obok siebie (dyspersja + transmisja)
# ```python
# fig, (ax_d, ax_t) = plt.subplots(1, 2, figsize=(18, 7))
#
# # Dyspersja po lewej
# disp = job[0].fft.dispersion.compute_1d(axis="x")
# job[0].fft.dispersion.plot_result(disp, ax=ax_d)
#
# # Transmisja po prawej
# trans = job[0].fft.transmission()
# trans.plot_transmission(ax=ax_t)
#
# # Synchronizuj osie Y
# y_lim = (min(ax_d.get_ylim()[0], ax_t.get_ylim()[0]),
#          max(ax_d.get_ylim()[1], ax_t.get_ylim()[1]))
# ax_d.set_ylim(y_lim)
# ax_t.set_ylim(y_lim)
# ```

# %%
# 🎨 PRZYKŁAD ZAAWANSOWANY: 2x2 grid z dyspersją i transmisją

import matplotlib.pyplot as plt

# Stwórz układ 2x2
fig, axes = plt.subplots(2, 2, figsize=(18, 14), dpi=100)

# ========== Przygotuj dane (oblicz RAZ) ==========
print("⏳ Ładowanie danych...")

# Dyspersja
zarr_path_disp = "/mnt/storage_2/scratch/pl0095-01/zelent/mannga/ksob/YIG_CoFeB_resonators_matrix/CoFeB_d_180nm_p_630nm_La_5um_ant_05um_YIG_70nm_fcut_4GHz_cz_5nm/comsol_verify/k_szulc_parameters8mt.zarr"
job_disp = mmpp.MMPP(zarr_path_disp, debug=False)
disp_result = job_disp[0].m_layer[:100,...].fft.dispersion.filters(
    remove_static=True, average=True
).compute_1d(axis="x", save_result=True)

# Transmisja
zarr_path_trans = "/mnt/storage_2/scratch/pl0095-01/zelent/mannga/ksob/YIG_CoFeB_resonators_matrix/CoFeB_d_180nm_p_630nm_La_5um_ant_05um_YIG_70nm_fcut_4GHz_cz_5nm/comsol_verify/transmission/transmission_k_szulc_parameters8mt_v5.zarr"
job_trans = mmpp.MMPP(zarr_path_trans, debug=False)
trans_result = job_trans[0].fft.transmission(spatial_window=5, normalize="reference")

print("✓ Dane załadowane!\n")

# ========== PANEL [0,0]: Dyspersja - liniowa skala ==========
print("📊 [0,0] Dyspersja - skala liniowa...")
job_disp[0].fft.dispersion.plot_result(
    disp_result,
    ax=axes[0,0],
    lognorm=False,
    kscale="rad_um",
    title="Dispersion: Linear Scale",
)

# ========== PANEL [0,1]: Dyspersja - log + k≈0 suppression ==========
print("📊 [0,1] Dyspersja - log + k≈0 suppression...")
job_disp[0].fft.dispersion.plot_result(
    disp_result,
    ax=axes[0,1],
    lognorm=True,
    k0_normalization=30,
    k0_normalization_width=1,
    vmax=0.01,
    kscale="rad_um",
    title="Dispersion: Log + k≈0 Suppression",
)

# ========== PANEL [1,0]: Transmisja - skala liniowa ==========
print("📊 [1,0] Transmisja - skala liniowa...")
trans_result.plot_transmission(
    ax=axes[1,0],
    plot_config={
        "freq_unit": "GHz",
        "log_scale": False,
        "cmap": "viridis",
        "title": "Transmission: Linear Scale",
    }
)

# ========== PANEL [1,1]: Transmisja - log skala ==========
print("📊 [1,1] Transmisja - skala log...")
trans_result.plot_transmission(
    ax=axes[1,1],
    plot_config={
        "freq_unit": "GHz",
        "log_scale": True,
        "cmap": "plasma",
        "title": "Transmission: Log Scale",
    }
)

# ========== SYNCHRONIZACJA OSI Y (częstotliwość) ==========
print("\n🔄 Synchronizacja osi częstotliwości...")
y_limits = []
for row in axes:
    for ax in row:
        y_limits.extend(ax.get_ylim())

y_min = min(y_limits)
y_max = max(y_limits)

for row in axes:
    for ax in row:
        ax.set_ylim(y_min, y_max)

# ========== FINALIZACJA ==========
plt.tight_layout()
plt.show()

print("\n✅ Gotowe! 2x2 grid z dyspersją i transmisją")
print(f"📊 Synchronizowane osie Y: {y_min:.2f} - {y_max:.2f} GHz")

# %% [markdown]
# # ⚠️WAŻNE: Różnice w slicingu między dyspersją a transmisją
#
# ## 🔍 Analiza problemu
#
# ### ✅ Dyspersja - WSPIERA slicing
# ```python
# # TO DZIAŁA! ✅
# disp_result = job[0].m_layer[:100,...].fft.dispersion.compute_1d(axis="x")
# ```
#
# **Dlaczego działa:**
# - `FFTDispersionInterface` otrzymuje `slice_info` (`:100`) w konstruktorze
# - `SpinWaveAnalyzer` wykorzystuje `slice_info` do inteligentnego ładowania tylko potrzebnych danych
# - Slicing jest przetwarzany przez `_normalize_slice()` i `_indexer_for_tmax()`
#
# ### ❌ Transmisja - NIE WSPIERA slicingu (jeszcze)
# ```python
# # TO NIE DZIAŁA POPRAWNIE! ❌
# trans_result = job[0].m_layer[:100,...].fft.transmission()
# ```
#
# **Dlaczego nie działa:**
# - `FFTTransmissionInterface` NIE otrzymuje `slice_info`
# - `TransmissionCompute` używa `FFTCompute.load_data_from_zarr()`
# - `load_data_from_zarr()` zawsze ładuje pełny dataset: `data = data_set[...]`
# - Slicing `:100` jest **ignorowany**, ładowane są WSZYSTKIE kroki czasowe!
#
# ---
#
# ## 🛠️ Obejście problemu (tymczasowe)
#
# ### Dla transmisji: użyj parametru `tmax`
# ```python
# # Zamiast slicingu [:100]
# trans_result = job[0].fft.transmission(tmax=100)
# ```
#
# **Uwaga:** `tmax` działa INACZEJ niż slicing:
# - `:100` oznacza "pierwsze 100 kroków z załadowanych danych"
# - `tmax=100` oznacza "załaduj tylko pierwsze 100 kroków"
#
# ---
#
# ## 📊 Porównanie składni
#
# | Funkcja | Obecna składnia | Status |
# |---------|----------------|--------|
# | **Dyspersja** | `job[0].m_layer[:100,...].fft.dispersion.compute_1d()` | ✅ Działa |
# | **Transmisja** | `job[0].m_layer[:100,...].fft.transmission()` | ❌ Ignoruje slicing |
# | **Transmisja (fix)** | `job[0].fft.transmission(tmax=100)` | ✅ Obejście |
#
# ---
#
# ## 🎯 Rekomendowane użycie
#
# ### Dyspersja - używaj slicingu
# ```python
# # Preferowane - eleganckie i elastyczne
# disp = job[0].m_layer[:100, :, :, :].fft.dispersion.compute_1d(axis="x")
# disp = job[0].m_layer[:100, ...].fft.dispersion.compute_1d(axis="x")  # Krótsza forma
# ```
#
# ### Transmisja - używaj tmax
# ```python
# # Obecnie jedyna działająca metoda
# trans = job[0].fft.transmission(
#     tmax=100,
#     spatial_window=5,
#     normalize="reference"
# )
# ```
#
# ---
#
# ## 🔮 Przyszłe rozwiązanie
#
# Aby transmisja działała jak dyspersja, trzeba:
# 1. Dodać parametr `slice_info` do `FFTTransmissionInterface.__init__()`
# 2. Przekazać `slice_info` do `TransmissionCompute`
# 3. Zmodyfikować `load_data_from_zarr()` aby obsługiwał slicing
# 4. Lub: stworzyć nową metodę `load_data_with_slice()`

# %%
# 🧪 DEMONSTRACJA: Różnice w slicingu

import matplotlib.pyplot as plt

zarr_path = "/mnt/storage_2/scratch/pl0095-01/zelent/mannga/ksob/YIG_CoFeB_resonators_matrix/CoFeB_d_180nm_p_630nm_La_5um_ant_05um_YIG_70nm_fcut_4GHz_cz_5nm/comsol_verify/k_szulc_parameters8mt.zarr"
job = mmpp.MMPP(zarr_path, debug=True)

print("=" * 60)
print("TEST SLICINGU")
print("=" * 60)

# ========== TEST 1: DYSPERSJA Z SLICINGIEM ==========
print("\n✅ TEST 1: Dyspersja z [:100, ...]")
print("-" * 60)

disp_result_sliced = job[0].m_layer[:100, ...].fft.dispersion.filters(
    remove_static=True,
    average=True,
).compute_1d(axis="x")

print(f"📊 Wynik dyspersji:")
print(f"   - k-axis punktów: {len(disp_result_sliced.k_axis)}")
print(f"   - f-axis punktów: {len(disp_result_sliced.f_axis)}")
print(f"   - Shape spectrum: {disp_result_sliced.S.shape}")
print(f"   ✓ Slicing [:100] został ZASTOSOWANY przez SpinWaveAnalyzer")

# ========== TEST 2: TRANSMISJA Z SLICINGIEM (NIE DZIAŁA) ==========
print("\n⚠️  TEST 2: Transmisja z [:100, ...] (IGNORUJE SLICING!)")
print("-" * 60)

# To NIE ZADZIAŁA jak oczekiwano - slicing będzie zignorowany
# Transmisja załaduje WSZYSTKIE kroki czasowe z zarr!
print("⏳ Ładowanie... (może być wolne - ładuje WSZYSTKO!)")

# NIE URUCHAMIAJ tego na dużych plikach - załaduje wszystko!
# trans_result_wrong = job[0].m_layer[:100, ...].fft.transmission(spatial_window=5)

print("   ❌ NIE WYKONANO - slicing [:100] zostałby ZIGNOROWANY")
print("   ❌ Załadowałoby to WSZYSTKIE kroki czasowe!")

# ========== TEST 3: TRANSMISJA Z TMAX (DZIAŁA) ==========
print("\n✅ TEST 3: Transmisja z tmax=100 (POPRAWNE OBEJŚCIE)")
print("-" * 60)

zarr_path_trans = "/mnt/storage_2/scratch/pl0095-01/zelent/mannga/ksob/YIG_CoFeB_resonators_matrix/CoFeB_d_180nm_p_630nm_La_5um_ant_05um_YIG_70nm_fcut_4GHz_cz_5nm/comsol_verify/transmission/transmission_k_szulc_parameters8mt_v5.zarr"
job_trans = mmpp.MMPP(zarr_path_trans, debug=False)

trans_result_correct = job_trans[0].fft.transmission(
    tmax=100,  # 🔑 Użyj tmax zamiast slicingu!
    spatial_window=5,
    normalize="reference",
)

print(f"📊 Wynik transmisji:")
print(f"   - x-axis punktów: {len(trans_result_correct.x_positions)}")
print(f"   - f-axis punktów: {len(trans_result_correct.frequencies)}")  
print(f"   - Shape transmission: {trans_result_correct.transmission.shape}")
print(f"   ✓ tmax=100 został ZASTOSOWANY przez load_data_from_zarr")

# ========== PODSUMOWANIE ==========
print("\n" + "=" * 60)
print("📋 PODSUMOWANIE")
print("=" * 60)
print("✅ Dyspersja: job[0].m_layer[:100,...].fft.dispersion.compute_1d()")
print("   → Slicing działa poprawnie")
print()
print("❌ Transmisja: job[0].m_layer[:100,...].fft.transmission()")
print("   → Slicing jest IGNOROWANY!")
print()
print("✅ Transmisja FIX: job[0].fft.transmission(tmax=100)")
print("   → Używaj parametru tmax zamiast slicingu")
print("=" * 60)

# %% [markdown]
# # 📖 Poprawne użycie - Wzorce kodu
#
# ## ✅ WZORZEC 1: Dyspersja + Transmisja obok siebie
#
# ```python
# # Dyspersja - UŻYWAJ SLICINGU
# disp_result = job_disp[0].m_layer[:100, ...].fft.dispersion.compute_1d(
#     axis="x",
#     save_result=True
# )
#
# # Transmisja - UŻYWAJ TMAX
# trans_result = job_trans[0].fft.transmission(
#     tmax=100,  # NIE używaj [:100, ...]
#     spatial_window=5,
#     normalize="reference"
# )
#
# # Plotuj obok siebie
# fig, (ax_d, ax_t) = plt.subplots(1, 2, figsize=(18, 7))
# job_disp[0].fft.dispersion.plot_result(disp_result, ax=ax_d)
# trans_result.plot_transmission(ax=ax_t)
# ```
#
# ---
#
# ## ✅ WZORZEC 2: Różne zakresy czasowe
#
# ```python
# # Dyspersja - krótki zakres dla szybkiego testu
# disp_quick = job[0].m_layer[:50, ...].fft.dispersion.compute_1d(axis="x")
#
# # Dyspersja - pełny zakres dla dokładnej analizy
# disp_full = job[0].m_layer[:500, ...].fft.dispersion.compute_1d(axis="x")
#
# # Transmisja - odpowiednie zakresy
# trans_quick = job[0].fft.transmission(tmax=50)
# trans_full = job[0].fft.transmission(tmax=500)
# ```
#
# ---
#
# ## ✅ WZORZEC 3: Zaawansowany slicing (tylko dyspersja!)
#
# ```python
# # Dyspersja obsługuje złożone slicing
# disp_every_2nd = job[0].m_layer[::2, ...].fft.dispersion.compute_1d(axis="x")
# disp_range = job[0].m_layer[100:200, ...].fft.dispersion.compute_1d(axis="x")
# disp_specific_y = job[0].m_layer[:, 0, 5:15, :].fft.dispersion.compute_1d(axis="x")
#
# # Transmisja - tylko tmax (prostsza kontrola)
# trans_basic = job[0].fft.transmission(tmax=100)
# ```
#
# ---
#
# ## ❌ UNIKAJ - Typowe błędy
#
# ```python
# # ❌ BŁĄD 1: Slicing na transmisji
# trans_wrong = job[0].m_layer[:100, ...].fft.transmission()
# # → Załaduje WSZYSTKIE dane, zignoruje [:100]!
#
# # ❌ BŁĄD 2: Użycie zarówno slicingu i tmax
# trans_confusing = job[0].m_layer[:200, ...].fft.transmission(tmax=100)
# # → Niejasne: który limit zostanie zastosowany?
#
# # ✅ POPRAWNIE: Tylko tmax
# trans_correct = job[0].fft.transmission(tmax=100)
# ```

# %% [markdown]
# # 🎯 FINALNE PODSUMOWANIE
#
# ## ✅ CO DZIAŁA OBECNIE
#
# | Funkcja | Parametr `ax` | Slicing danych | Metoda `plot_result()` |
# |---------|---------------|----------------|----------------------|
# | **Dyspersja** | ✅ Tak | ✅ `[:100, ...]` | ✅ Tak |
# | **Transmisja** | ✅ Tak | ❌ Nie (`tmax=100`) | ❌ Nie (tylko `plot_transmission`) |
#
# ---
#
# ## 📋 Szybki przewodnik
#
# ### Dyspersja - pełna funkcjonalność
# ```python
# # 1. Oblicz raz
# result = job[0].m_layer[:100, ...].fft.dispersion.compute_1d(axis="x", save_result=True)
#
# # 2. Plotuj wielokrotnie
# fig, ax = plt.subplots()
# job[0].fft.dispersion.plot_result(result, ax=ax, lognorm=True)
# ```
#
# ### Transmisja - ograniczona funkcjonalność
# ```python
# # 1. Oblicz (używaj tmax, nie slicingu!)
# result = job[0].fft.transmission(tmax=100, spatial_window=5)
#
# # 2. Plotuj (nazwa metody inna niż dyspersja)
# fig, ax = plt.subplots()
# result.plot_transmission(ax=ax, plot_config={"freq_unit": "GHz"})
# ```
#
# ---
#
# ## 🔧 Główne różnice
#
# ### Dostęp do danych
# - **Dyspersja**: `job[0].m_layer[:100, ...]` ✅
# - **Transmisja**: `job[0].fft.transmission(tmax=100)` ⚠️
#
# ### Plotowanie wyniku
# - **Dyspersja**: `dispersion.plot_result(result, ax=...)` ✅
# - **Transmisja**: `result.plot_transmission(ax=...)` ✅
#
# ### Cache i reużywalność
# - **Dyspersja**: `compute_1d(save_result=True)` → cache na dysku ✅
# - **Transmisja**: Brak wbudowanego cache ❌
#
# ---
#
# ## 🚀 Rekomendowany workflow
#
# ```python
# import matplotlib.pyplot as plt
# import mmpp
#
# # Setup
# zarr_disp = "path/to/dispersion.zarr"
# zarr_trans = "path/to/transmission.zarr"
#
# job_d = mmpp.MMPP(zarr_disp)
# job_t = mmpp.MMPP(zarr_trans)
#
# # Oblicz raz
# disp = job_d[0].m_layer[:100, ...].fft.dispersion.compute_1d(axis="x", save_result=True)
# trans = job_t[0].fft.transmission(tmax=100)
#
# # Stwórz layout
# fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 7))
#
# # Plotuj wielokrotnie z różnymi parametrami
# job_d[0].fft.dispersion.plot_result(disp, ax=ax1, lognorm=True, vmax=0.01)
# trans.plot_transmission(ax=ax2, plot_config={"freq_unit": "GHz", "log_scale": False})
#
# # Synchronizuj osie
# y_min = min(ax1.get_ylim()[0], ax2.get_ylim()[0])
# y_max = max(ax1.get_ylim()[1], ax2.get_ylim()[1])
# ax1.set_ylim(y_min, y_max)
# ax2.set_ylim(y_min, y_max)
#
# plt.tight_layout()
# plt.show()
# ```

# %% [markdown]
# # 🆕 NOWE FUNKCJE TRANSMISJI
#
# ## 1. `trim_0f` - Usuwanie najniższych częstotliwości
#
# Parametr `trim_0f=N` usuwa N najniższych punktów częstotliwości (pomocne gdy f≈0 ma bardzo silne mody).
#
# ## 2. `plot_transmission_crosssection(x=...)` - Przekrój 1D
#
# Rysuje przekrój transmisji T(f) dla konkretnej pozycji x.

# %%
# 🎯 DEMO 1: trim_0f - Usuwanie najniższych częstotliwości

import matplotlib.pyplot as plt
import mmpp

# Załaduj dane transmisji
zarr_path = "/mnt/storage_2/scratch/pl0095-01/zelent/mannga/ksob/YIG_CoFeB_resonators_matrix/CoFeB_d_180nm_p_630nm_La_5um_ant_05um_YIG_70nm_fcut_4GHz_cz_5nm/comsol_verify/transmission/transmission_k_szulc_parameters8mt_v5.zarr"
job = mmpp.MMPP(zarr_path, debug=False)

# Oblicz transmisję
trans_result = job[0].m_layer[:100,...].fft.transmission(
    spatial_window=5,
    normalize="reference",
)

# Porównaj: bez i z trim_0f
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 7), dpi=100)

# LEWY: Bez trim_0f (wszystkie częstotliwości)
trans_result.plot_transmission(
    ax=ax1,
    plot_config={
        "freq_unit": "GHz",
        "log_scale": False,
        "cmap": "viridis",
        "title": "Wszystkie częstotliwości",
    }
)

# PRAWY: Z trim_0f=5 (usuń 5 najniższych punktów)
trans_result.plot_transmission(
    ax=ax2,
    plot_config={
        "freq_unit": "GHz",
        "log_scale": False,
        "cmap": "viridis",
        "title": "trim_0f=5 (bez 5 najniższych f)",
        "trim_0f": 5,  # 🔑 NOWY PARAMETR!
    }
)

plt.tight_layout()
plt.show()

print("✅ Porównanie: bez trim_0f vs trim_0f=5")
print(f"📊 Oryginalnie: {len(trans_result.frequencies)} punktów częstotliwości")
print(f"📊 Po trim_0f=5: {len(trans_result.frequencies)-5} punktów częstotliwości")

# %%
# 🎯 DEMO 2: plot_transmission_crosssection() - Przekrój 1D

import matplotlib.pyplot as plt
import mmpp

# Załaduj dane transmisji (jeśli nie załadowane wcześniej)
zarr_path = "/mnt/storage_2/scratch/pl0095-01/zelent/mannga/ksob/YIG_CoFeB_resonators_matrix/CoFeB_d_180nm_p_630nm_La_5um_ant_05um_YIG_70nm_fcut_4GHz_cz_5nm/comsol_verify/transmission/transmission_k_szulc_parameters8mt_v5.zarr"
job = mmpp.MMPP(zarr_path, debug=False)

# Oblicz transmisję
trans_result = job[0].m_layer[:100,...].fft.transmission(
    spatial_window=5,
    normalize="reference",
)

# Stwórz layout 1x2: mapa 2D + przekrój 1D
fig, (ax_map, ax_cross) = plt.subplots(1, 2, figsize=(18, 7), dpi=100)

# LEWY PANEL: Mapa 2D transmisji
trans_result.plot_transmission(
    ax=ax_map,
    plot_config={
        "freq_unit": "GHz",
        "cmap": "plasma",
        "title": "Transmission T(f,x)",
    }
)

# PRAWY PANEL: Przekrój 1D w x=2000 nm
fig_cross, ax_cross = trans_result.plot_transmission_crosssection(
    x=2000e-9,  # 🔑 Pozycja x w metrach (2000 nm)
    freq_unit="GHz",
    trim_0f=5,  # 🔑 Opcjonalnie: usuń 5 najniższych punktów
    ax=ax_cross,
    color="red",
    linewidth=2.5,
)

# Synchronizuj osie Y (częstotliwość)
y_lim = ax_map.get_ylim()
ax_cross.set_ylim(y_lim)

plt.tight_layout()
plt.show()

print("✅ Mapa 2D + Przekrój 1D w x=2000 nm")
print(f"📍 Dostępne pozycje x: {trans_result.x_positions[0]*1e9:.1f} - {trans_result.x_positions[-1]*1e9:.1f} nm")
print(f"📊 Liczba punktów x: {len(trans_result.x_positions)}")

# %%
# 🎯 DEMO 3: Zaawansowane użycie - wiele przekrojów

import matplotlib.pyplot as plt
import mmpp

# Załaduj dane
zarr_path = "/mnt/storage_2/scratch/pl0095-01/zelent/mannga/ksob/YIG_CoFeB_resonators_matrix/CoFeB_d_180nm_p_630nm_La_5um_ant_05um_YIG_70nm_fcut_4GHz_cz_5nm/comsol_verify/transmission/transmission_k_szulc_parameters8mt_v5.zarr"
job = mmpp.MMPP(zarr_path, debug=False)

trans_result = job[0].m_layer[:100,...].fft.transmission(
    spatial_window=5,
    normalize="reference",
)

# Layout: 2x2 grid
fig, axes = plt.subplots(2, 2, figsize=(16, 14), dpi=100)

# [0,0] - Mapa 2D
trans_result.plot_transmission(
    ax=axes[0,0],
    plot_config={
        "freq_unit": "GHz",
        "cmap": "viridis",
        "title": "Transmission Map T(f,x)",
    }
)

# [0,1], [1,0], [1,1] - Przekroje w różnych x
x_positions = [1000e-9, 2000e-9, 3000e-9]  # 1, 2, 3 μm
colors = ["red", "blue", "green"]
ax_cross = [axes[0,1], axes[1,0], axes[1,1]]

for i, (x_pos, color, ax) in enumerate(zip(x_positions, colors, ax_cross)):
    trans_result.plot_transmission_crosssection(
        x=x_pos,
        freq_unit="GHz",
        trim_0f=5,
        ax=ax,
        color=color,
        linewidth=2,
    )

# Synchronizuj osie Y
y_min = min(ax.get_ylim()[0] for ax in axes.flat)
y_max = max(ax.get_ylim()[1] for ax in axes.flat)
for ax in axes.flat:
    ax.set_ylim(y_min, y_max)

plt.tight_layout()
plt.show()

print("✅ Mapa 2D + 3 przekroje 1D w różnych pozycjach x")
print(f"📍 Przekroje w: {[f'{x*1e9:.0f} nm' for x in x_positions]}")

# %% [markdown]
# # 📚 API Reference - Nowe funkcje transmisji
#
# ## 1️⃣ `trim_0f` parameter
#
# ### Użycie w `plot_transmission()`
# ```python
# result.plot_transmission(
#     plot_config={
#         "trim_0f": 5,  # Usuń 5 najniższych punktów częstotliwości
#         "freq_unit": "GHz",
#         "cmap": "viridis",
#     }
# )
# ```
#
# **Przypadki użycia:**
# - Silne mody przy f≈0 zakłócają skalę kolorów
# - Chcesz skupić się na wyższych częstotliwościach
# - Wartości przy f=0 są artefaktami
#
# ---
#
# ## 2️⃣ `plot_transmission_crosssection(x=...)`
#
# ### Sygnatura metody
# ```python
# fig, ax = result.plot_transmission_crosssection(
#     x=2000e-9,           # Pozycja x w metrach (WYMAGANE)
#     freq_unit="GHz",     # Jednostka częstotliwości
#     trim_0f=5,           # Usuń najniższe punkty
#     flip=False,          # 🆕 Orientacja osi (False=f na X, True=f na Y)
#     ax=None,             # Matplotlib axes (opcjonalne)
#     color="red",         # Kolor linii
#     linewidth=2,         # Grubość linii
#     # ... inne matplotlib kwargs
# )
# ```
#
# ### Parametry:
# - **`x`** (float, wymagany): Pozycja x w metrach (np. `2000e-9` dla 2 µm)
#   - Metoda automatycznie znajdzie najbliższą dostępną pozycję x
# - **`freq_unit`** (str): Jednostka częstotliwości - "Hz", "kHz", "MHz", "GHz"
# - **`trim_0f`** (int, opcjonalny): Liczba najniższych punktów do usunięcia
# - **`flip`** (bool, opcjonalny): 🆕 Orientacja osi
#   - `False` (domyślnie): Częstotliwość na osi X, Transmisja na osi Y
#   - `True`: Częstotliwość na osi Y, Transmisja na osi X
#   - **Użyj `flip=True` aby dopasować do wykresów dyspersji!**
# - **`ax`** (Axes, opcjonalny): Matplotlib axes do rysowania
# - **`**kwargs`**: Dodatkowe parametry matplotlib (color, linewidth, label, alpha, ...)
#
# ### Zwraca:
# - `fig, ax` - Matplotlib figure i axes
#
# ### Przykłady:
# ```python
# # Prosty przekrój (domyślna orientacja)
# fig, ax = result.plot_transmission_crosssection(x=1500e-9)
#
# # Z flip=True (częstotliwość pionowo)
# fig, ax = result.plot_transmission_crosssection(
#     x=2000e-9,
#     freq_unit="GHz",
#     trim_0f=3,
#     flip=True,  # 🔑 Częstotliwość na Y!
#     color="darkred",
#     linewidth=3,
#     alpha=0.7
# )
#
# # Na istniejącym ax z zsynchronizowaną osią Y
# fig, (ax1, ax2) = plt.subplots(1, 2)
# dispersion.plot_result(result, ax=ax1)  # Częstotliwość na Y
# trans.plot_transmission_crosssection(x=2000e-9, flip=True, ax=ax2)
# ax2.set_ylim(ax1.get_ylim())  # Synchronizuj osie Y!
# ```
#
# ---
#
# ## 🎨 Kombinacja funkcji - dyspersja + transmisja
#
# ```python
# # Idealne dopasowanie: dyspersja 2D + transmisja 1D
# fig, (ax_disp, ax_trans) = plt.subplots(1, 2, figsize=(18, 7))
#
# # Dyspersja S(k,f) - częstotliwość na osi Y
# job[0].fft.dispersion.plot_result(disp_result, ax=ax_disp)
#
# # Transmisja T(f) - z flip=True też częstotliwość na Y
# result.plot_transmission_crosssection(
#     x=2000e-9,
#     trim_0f=5,
#     flip=True,  # 🔑 Dopasuj do dyspersji!
#     ax=ax_trans,
#     color="red"
# )
#
# # Synchronizuj osie Y (częstotliwość)
# y_lim = ax_disp.get_ylim()
# ax_trans.set_ylim(y_lim)
# ```

# %% [markdown]
# # 🆕 NOWY PARAMETR: `flip` w `plot_transmission_crosssection()`
#
# ## Orientacja osi
#
# **`flip=False`** (domyślnie):
# - Częstotliwość na osi X (poziomo)
# - Transmisja na osi Y (pionowo)
# - Standardowy wykres liniowy
#
# **`flip=True`**:
# - Częstotliwość na osi Y (pionowo) ✅
# - Transmisja na osi X (poziomo)
# - **Idealnie pasuje do wykresów dyspersji!**
# - Pozwala synchronizować oś Y (częstotliwość) między wykresami

# %%
# 🎯 DEMO: flip=False vs flip=True

import matplotlib.pyplot as plt
import mmpp

# Załaduj dane (jeśli nie załadowane)
zarr_path = "/mnt/storage_2/scratch/pl0095-01/zelent/mannga/ksob/YIG_CoFeB_resonators_matrix/CoFeB_d_180nm_p_630nm_La_5um_ant_05um_YIG_70nm_fcut_4GHz_cz_5nm/comsol_verify/transmission/transmission_k_szulc_parameters8mt_v5.zarr"
job = mmpp.MMPP(zarr_path, debug=False)

trans_result = job[0].m_layer[:100,...].fft.transmission(
    spatial_window=5,
    normalize="reference",
)

# Porównaj flip=False vs flip=True
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 7), dpi=100)

# LEWY: flip=False (domyślnie) - f na osi X
trans_result.plot_transmission_crosssection(
    x=2000e-9,
    freq_unit="GHz",
    trim_0f=5,
    flip=False,  # Częstotliwość poziomo (X)
    ax=ax1,
    color="C0",
    linewidth=2,
)
ax1.set_title("flip=False: Frequency on X-axis", fontsize=14, fontweight="bold")

# PRAWY: flip=True - f na osi Y
trans_result.plot_transmission_crosssection(
    x=2000e-9,
    freq_unit="GHz",
    trim_0f=5,
    flip=True,  # 🔑 Częstotliwość pionowo (Y)
    ax=ax2,
    color="C1",
    linewidth=2,
)
ax2.set_title("flip=True: Frequency on Y-axis", fontsize=14, fontweight="bold")

plt.tight_layout()
plt.show()

print("✅ Porównanie orientacji osi:")
print("   flip=False: Standardowy wykres (f na X)")
print("   flip=True:  Pionowa częstotliwość (f na Y) - pasuje do dyspersji!")

# %%
# 🎯 DEMO PRAKTYCZNY: Dyspersja + Transmisja crosssection ze zsynchronizowaną osią Y

import matplotlib.pyplot as plt
import mmpp

# Załaduj dane dyspersji
zarr_path_disp = "/mnt/storage_2/scratch/pl0095-01/zelent/mannga/ksob/YIG_CoFeB_resonators_matrix/CoFeB_d_180nm_p_630nm_La_5um_ant_05um_YIG_70nm_fcut_4GHz_cz_5nm/comsol_verify/k_szulc_parameters8mt.zarr"
job_disp = mmpp.MMPP(zarr_path_disp, debug=False)

disp_result = job_disp[0].m_layer[:100,...].fft.dispersion.filters(
    remove_static=True,
    average=True,
).compute_1d(axis="x", save_result=True)

# Załaduj dane transmisji
zarr_path_trans = "/mnt/storage_2/scratch/pl0095-01/zelent/mannga/ksob/YIG_CoFeB_resonators_matrix/CoFeB_d_180nm_p_630nm_La_5um_ant_05um_YIG_70nm_fcut_4GHz_cz_5nm/comsol_verify/transmission/transmission_k_szulc_parameters8mt_v5.zarr"
job_trans = mmpp.MMPP(zarr_path_trans, debug=False)

trans_result = job_trans[0].m_layer[:100,...].fft.transmission(
    filter_type=None,
    window_function=None,
    spatial_window=1,
    average_mode="none",
    normalize="none",
)

# Stwórz layout 1x2 z współdzieloną osią Y
fig, (ax_disp, ax_cross) = plt.subplots(1, 2, figsize=(18, 7), dpi=100, sharey=True)  # 🔑 sharey=True!

# LEWY PANEL: Dyspersja S(k,f)
job_disp[0].fft.dispersion.plot_result(
    disp_result,
    ax=ax_disp,
    lognorm=True,
    k0_normalization=30,
    k0_normalization_width=1,
    vmax=0.01,
    kscale="rad_um",
    title="Dispersion S(k,f)",
)

# PRAWY PANEL: Transmisja T(f) z flip=True
trans_result.plot_transmission_crosssection(
    x=2500e-9,
    freq_unit="GHz",
    trim_0f=5,
    flip=True,  # 🔑 Kluczowe! Częstotliwość na osi Y
    ax=ax_cross,
    color="red",
    linewidth=2.5,
)

# 🔥 Dzięki sharey=True osie Y są automatycznie połączone!
# Można teraz płynnie przesuwać/zoomować oś częstotliwości na obu wykresach jednocześnie

plt.tight_layout()
plt.show()

print("✅ Dyspersja + Transmisja crosssection z sharey=True")
print("🔧 Możesz teraz płynnie przesuwać oś Y (częstotliwość) na obu wykresach jednocześnie!")
print("📊 Zoom i pan działają synchronicznie!")

# %% [markdown]
# # 💡 TIP: Użycie `trim_0f` w obu metodach plotowania
#
# Parametr `trim_0f` działa zarówno w:
# - `plot_transmission()` - przez `plot_config={"trim_0f": 5}`
# - `plot_transmission_crosssection()` - bezpośrednio jako parametr `trim_0f=5`

# %% [markdown]
# # ✅ NOWE: `trim_0f` dla dyspersji!
#
# Parametr `trim_0f` teraz działa również w **dyspersji**! 🎉
#
# ```python
# # Użycie w plot_result()
# job[0].fft.dispersion.plot_result(
#     disp_result,
#     ax=ax,
#     trim_0f=5,  # Usuń 5 najniższych punktów częstotliwości
#     lognorm=True,
# )
#
# # Użycie w plot_dispersion()
# job[0].fft.dispersion.plot_dispersion(
#     axis="x",
#     trim_0f=5,  # Usuń 5 najniższych punktów częstotliwości
#     lognorm=True,
# )
# ```

# %%
# 🎯 DEMO: trim_0f dla dyspersji - porównanie przed/po

# Przeładuj moduł MMPP
import sys
modules_to_remove = [name for name in sys.modules if name.startswith('mmpp')]
for module in modules_to_remove:
    del sys.modules[module]
import mmpp

import matplotlib.pyplot as plt

# Załaduj dane
zarr_path = "/mnt/storage_2/scratch/pl0095-01/zelent/mannga/ksob/YIG_CoFeB_resonators_matrix/CoFeB_d_180nm_p_630nm_La_5um_ant_05um_YIG_70nm_fcut_4GHz_cz_5nm/comsol_verify/k_szulc_parameters8mt.zarr"
job = mmpp.MMPP(zarr_path, debug=False)

# Oblicz dyspersję (jeśli nie w cache)
disp_result = job[0].m_layer[:2000,...].fft.dispersion.filters(
    remove_static=True,
    average=True,
).compute_1d(axis="x", save_result=True)

# Porównaj: bez i z trim_0f
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 7), dpi=100)

# LEWY: Bez trim_0f (wszystkie częstotliwości)
job[0].fft.dispersion.plot_result(
    disp_result,
    ax=ax1,
    lognorm=True,
    k0_normalization=30,
    k0_normalization_width=1,
    vmax=0.01,
    kscale="rad_um",
    title="Dyspersja: wszystkie f",
)

# PRAWY: Z trim_0f=5 (usuń 5 najniższych punktów)
job[0].fft.dispersion.plot_result(
    disp_result,
    ax=ax2,
    lognorm=True,
    k0_normalization=30,
    k0_normalization_width=1,
    vmax=0.01,
    kscale="rad_um",
    trim_0f=5,  # 🔑 NOWY PARAMETR!
    title="Dyspersja: trim_0f=5",
)

plt.tight_layout()
plt.show()

print("✅ Dyspersja z trim_0f działa!")
print(f"📊 Oryginalnie: {len(disp_result.f_axis)} punktów częstotliwości")
print(f"📊 Po trim_0f=5: {len(disp_result.f_axis)-5} punktów częstotliwości")

# %% [markdown]
# # 📋 Kompletne API - `trim_0f` w MMPP
#
# ## ✅ Dyspersja - OBIE metody obsługują `trim_0f`
#
# ### 1. `plot_dispersion()` - Oblicz + plotuj
# ```python
# job[0].fft.dispersion.plot_dispersion(
#     axis="x",
#     trim_0f=5,  # 🔑 Usuń 5 najniższych punktów
#     lognorm=True,
#     k0_normalization=30,
# )
# ```
#
# ### 2. `plot_result()` - Plotuj gotowy wynik
# ```python
# # Oblicz raz
# disp_result = job[0].fft.dispersion.compute_1d(axis="x", save_result=True)
#
# # Plotuj wielokrotnie z różnymi ustawieniami
# fig, ax = plt.subplots()
# job[0].fft.dispersion.plot_result(
#     disp_result,
#     ax=ax,
#     trim_0f=5,  # 🔑 Usuń 5 najniższych punktów
#     lognorm=True,
# )
# ```
#
# ---
#
# ## ✅ Transmisja - DWA sposoby użycia `trim_0f`
#
# ### 1. `plot_transmission()` - Mapa 2D
# ```python
# result.plot_transmission(
#     ax=ax,
#     plot_config={
#         "trim_0f": 5,  # 🔑 Przez słownik plot_config
#         "freq_unit": "GHz",
#         "cmap": "viridis",
#     }
# )
# ```
#
# ### 2. `plot_transmission_crosssection()` - Przekrój 1D
# ```python
# result.plot_transmission_crosssection(
#     x=2000e-9,
#     trim_0f=5,  # 🔑 Bezpośrednio jako parametr
#     flip=True,
#     freq_unit="GHz",
#     ax=ax,
# )
# ```
#
# ---
#
# ## 🎯 Przykład kompletny - dyspersja + transmisja
#
# ```python
# import matplotlib.pyplot as plt
#
# # Oblicz dane
# disp = job_disp[0].m_layer[:100,...].fft.dispersion.compute_1d(axis="x", save_result=True)
# trans = job_trans[0].fft.transmission(spatial_window=5)
#
# # Stwórz layout z współdzieloną osią Y
# fig, (ax_d, ax_t) = plt.subplots(1, 2, figsize=(18, 7), sharey=True)
#
# # Dyspersja z trim_0f
# job_disp[0].fft.dispersion.plot_result(
#     disp,
#     ax=ax_d,
#     trim_0f=5,
#     lognorm=True,
# )
#
# # Transmisja crosssection z trim_0f i flip
# trans.plot_transmission_crosssection(
#     x=2000e-9,
#     trim_0f=5,
#     flip=True,  # Częstotliwość na Y
#     ax=ax_t,
# )
#
# plt.tight_layout()
# ```
#
# **Wynik:** Oba wykresy mają zsynchronizowaną oś Y (częstotliwość) i usuniętych 5 najniższych punktów! 🎉

# %% [markdown]
# # 💾 NOWE: System Cache dla Transmisji!
#
# MMPP teraz wspiera **automatyczne cache'owanie wyników transmisji**, co **drastycznie przyspiesza** ponowne analizy!
#
# ## Główne funkcje:
# - ✅ `save=True` - zapisz wynik do cache
# - ✅ `cache_path="/tmp/fft"` - własny katalog cache
# - ✅ `force=True` - wymuś przeliczenie
# - ✅ Automatyczne ładowanie z cache
# - ✅ ~50x szybsze drugie wywołanie!

# %%
# 🎯 DEMO 1: Cache w domyślnej lokalizacji (katalog źródłowy)

# Przeładuj moduł MMPP
import sys
modules_to_remove = [name for name in sys.modules if name.startswith('mmpp')]
for module in modules_to_remove:
    del sys.modules[module]
import mmpp
import time

# Załaduj dane
job = mmpp.MMPP("/mnt/storage_2/scratch/pl0095-01/zelent/mannga/ksob/YIG_CoFeB_resonators_matrix/CoFeB_d_180nm_p_630nm_La_5um_ant_05um_YIG_70nm_fcut_4GHz_cz_5nm/comsol_verify/transmission/transmission_k_szulc_parameters8mt_v5.zarr", debug=True)

print("=" * 60)
print("TEST CACHE - Domyślna lokalizacja")
print("=" * 60)

# === PIERWSZE WYWOŁANIE: Oblicz i zapisz cache ===
print("\n⏳ PIERWSZE WYWOŁANIE: Obliczanie i zapisywanie...")
start = time.time()
result1 = job[0].m_layer[:1000,...].fft.transmission(
    save=True,  # 🔑 Zapisz do cache!
    filter_type=None,
    window_function=None,
    spatial_window=200,
    average_mode="none",
    component_weights=(0, 0, 1),
    normalize="none",
)
time1 = time.time() - start
print(f"✓ Obliczone i zapisane w: {time1:.2f}s")
print(f"  Częstotliwości: {len(result1.frequencies)}")
print(f"  Pozycje x: {len(result1.x_positions)}")

# === DRUGIE WYWOŁANIE: Załaduj z cache ===
print("\n⚡ DRUGIE WYWOŁANIE: Ładowanie z cache...")
start = time.time()
result2 = job[0].m_layer[:1000,...].fft.transmission(
    save=True,  # Te same parametry!
    filter_type=None,
    window_function=None,
    spatial_window=200,
    average_mode="none",
    component_weights=(0, 0, 1),
    normalize="none",
)
time2 = time.time() - start
print(f"⚡ Załadowane z cache w: {time2:.2f}s")

# === PODSUMOWANIE ===
print("\n" + "=" * 60)
print("📊 WYNIKI:")
print("=" * 60)
print(f"Pierwsze wywołanie (obliczenia): {time1:.2f}s")
print(f"Drugie wywołanie (cache):        {time2:.2f}s")
print(f"🚀 PRZYŚPIESZENIE:                {time1/time2:.1f}x")
print("=" * 60)

# %%
# 🎯 DEMO 2: Cache w własnym katalogu (/tmp)

import mmpp
import time

job = mmpp.MMPP("/mnt/storage_2/scratch/pl0095-01/zelent/mannga/ksob/YIG_CoFeB_resonators_matrix/CoFeB_d_180nm_p_630nm_La_5um_ant_05um_YIG_70nm_fcut_4GHz_cz_5nm/comsol_verify/transmission/transmission_k_szulc_parameters8mt_v5.zarr", debug=True)

print("=" * 60)
print("TEST CACHE - Własny katalog (/tmp/fft_cache)")
print("=" * 60)

# === PIERWSZE WYWOŁANIE: Zapisz do /tmp ===
print("\n⏳ PIERWSZE WYWOŁANIE: Zapisywanie do /tmp/fft_cache...")
start = time.time()
result1 = job[0].m_layer[:1000,...].fft.transmission(
    save=True,
    cache_path="/tmp/fft_cache",  # 🔑 Własny katalog!
    filter_type=None,
    spatial_window=150,
    normalize="none",
)
time1 = time.time() - start
print(f"✓ Zapisane w /tmp/fft_cache w: {time1:.2f}s")

# === DRUGIE WYWOŁANIE: Załaduj z /tmp ===
print("\n⚡ DRUGIE WYWOŁANIE: Ładowanie z /tmp/fft_cache...")
start = time.time()
result2 = job[0].m_layer[:1000,...].fft.transmission(
    cache_path="/tmp/fft_cache",  # Ten sam katalog!
    filter_type=None,
    spatial_window=150,
    normalize="none",
)
time2 = time.time() - start
print(f"⚡ Załadowane w: {time2:.2f}s")

print("\n" + "=" * 60)
print(f"🚀 PRZYŚPIESZENIE: {time1/time2:.1f}x")
print(f"📁 Cache zapisany w: /tmp/fft_cache/transmission_cache.zarr/")
print("=" * 60)

# %%
# 🎯 DEMO 3: Workflow - Oblicz raz, plotuj wielokrotnie

import mmpp
import matplotlib.pyplot as plt

job = mmpp.MMPP("/mnt/storage_2/scratch/pl0095-01/zelent/mannga/ksob/YIG_CoFeB_resonators_matrix/CoFeB_d_180nm_p_630nm_La_5um_ant_05um_YIG_70nm_fcut_4GHz_cz_5nm/comsol_verify/transmission/transmission_k_szulc_parameters8mt_v5.zarr", debug=False)

print("=" * 60)
print("WORKFLOW: Oblicz raz (z cache), plotuj wielokrotnie")
print("=" * 60)

# === KROK 1: Oblicz i zapisz (lub załaduj z cache) ===
print("\n⏳ Obliczanie/ładowanie transmisji...")
result = job[0].m_layer[:1000,...].fft.transmission(
    save=True,
    cache_path="/tmp/fft_cache",
    filter_type=None,
    spatial_window=150,
    normalize="none",
)
print("✓ Gotowe!")

# === KROK 2: Wielokrotne plotowanie (szybkie!) ===
print("\n📊 Plotowanie wariantów...")

fig, axes = plt.subplots(2, 2, figsize=(18, 14), dpi=100)

# [0,0] - Mapa 2D bez trim_0f
print("  - Mapa 2D (wszystkie częstotliwości)")
result.plot_transmission(
    ax=axes[0,0],
    plot_config={
        "freq_unit": "GHz",
        "cmap": "viridis",
        "title": "Wszystkie częstotliwości",
    }
)

# [0,1] - Mapa 2D z trim_0f
print("  - Mapa 2D (trim_0f=5)")
result.plot_transmission(
    ax=axes[0,1],
    plot_config={
        "freq_unit": "GHz",
        "cmap": "plasma",
        "trim_0f": 5,
        "title": "trim_0f=5",
    }
)

# [1,0] - Cross-section x=2000nm
print("  - Cross-section x=2000nm")
result.plot_transmission_crosssection(
    ax=axes[1,0],
    x=2000e-9,
    freq_unit="GHz",
    trim_0f=5,
    flip=True,
    color="red",
    linewidth=2,
)

# [1,1] - Cross-section x=3000nm
print("  - Cross-section x=3000nm")
result.plot_transmission_crosssection(
    ax=axes[1,1],
    x=3000e-9,
    freq_unit="GHz",
    trim_0f=5,
    flip=True,
    color="blue",
    linewidth=2,
)

plt.tight_layout()
plt.show()

print("\n✅ 4 różne wykresy z JEDNEGO obliczenia (dzięki cache)!")

# %% [markdown]
# # 📋 API Reference - Parametry cache
#
# ## Wszystkie metody wspierają cache:
#
# ```python
# # Podstawowe wywołanie
# result = job[0].fft.transmission(
#     save=True,              # Zapisz do cache
#     cache_path="/tmp/fft",  # Własny katalog (opcjonalne)
#     force=False,            # Wymuś przeliczenie (ignoruj cache)
#     use_cache=True,         # Czy używać cache (False = zawsze przelicz)
#     # ... pozostałe parametry transmisji
# )
#
# # Metoda compute() - alias
# result = job[0].fft.transmission.compute(
#     save=True,
#     cache_path="/tmp/fft",
#     # ...
# )
#
# # Metoda plot_transmission() - też wspiera cache!
# fig, ax = job[0].fft.transmission.plot_transmission(
#     save=True,
#     cache_path="/tmp/fft",
#     plot_config={"vmax": 1e-7},
#     # ...
# )
# ```
#
# ## Parametry:
#
# | Parametr | Typ | Domyślnie | Opis |
# |----------|-----|-----------|------|
# | `save` | `bool` | `False` | Czy zapisać wynik do cache |
# | `cache_path` | `str\|Path` | `None` | Katalog cache (None = katalog źródłowy) |
# | `force` | `bool` | `False` | Wymuś przeliczenie, ignoruj cache |
# | `use_cache` | `bool` | `True` | Czy w ogóle używać cache |
#
# ## Struktura cache:
#
# ### Domyślna (cache_path=None):
# ```
# data.zarr/
# └── fft/
#     └── transmission/
#         └── m_layer/              # dataset_name
#             └── transmission_abc123/  # hash parametrów
#                 ├── frequencies
#                 ├── x_positions
#                 ├── transmission
#                 └── ... (metadata)
# ```
#
# ### Własny katalog (cache_path="/tmp/fft"):
# ```
# /tmp/fft/
# └── transmission_cache.zarr/
#     └── fft/
#         └── transmission/
#             └── m_layer/
#                 └── transmission_abc123/
#                     └── ...
# ```

# %% [markdown]
# # ⚡ NOWA OPTYMALIZACJA: FFT obliczane raz!
#
# ## 🚀 Co się zmieniło?
#
# **PRZED:** FFT był obliczany osobno dla **każdego okna** w pętli ❌
# - Dla 3560 okien → **3560 wywołań FFT** (bardzo wolno!)
#
# **TERAZ:** FFT obliczany **raz dla całego datasetu** ✅
# - Tylko **1 wywołanie FFT** → okna wycinane z pre-obliczonego spektrum
# - Dodatkowo: użycie `scipy.fft` (szybsze niż `numpy.fft`)
#
# ## 📊 Oczekiwane przyspieszenie:
# - **50-100x szybciej** dla typowych przypadków! 🔥
# - Szczegółowe logi pokazują czas FFT i przetwarzania okien

# %%
# 🎯 TEST OPTYMALIZACJI FFT

# Przeładuj moduł MMPP (aby załadować nowy kod)
import sys
modules_to_remove = [name for name in sys.modules if name.startswith('mmpp')]
for module in modules_to_remove:
    del sys.modules[module]
import mmpp
import time

job = mmpp.MMPP("/mnt/storage_2/scratch/pl0095-01/zelent/mannga/ksob/YIG_CoFeB_resonators_matrix/CoFeB_d_180nm_p_630nm_La_5um_ant_05um_YIG_70nm_fcut_4GHz_cz_5nm/comsol_verify/transmission/transmission_k_szulc_parameters8mt_v5.zarr", debug=True)

print("=" * 80)
print("TEST OPTYMALIZACJI FFT")
print("=" * 80)
print("\nObserwuj logi - powinieneś zobaczyć:")
print("  1. 'Computing FFT for full dataset...'")
print("  2. 'FFT completed in X.XXXs'")
print("  3. 'Window processing loop completed in X.XXXs'")
print("=" * 80)
print()

# Test z mniejszym zakresem (aby nie czekać za długo)
start_total = time.time()

result = job[0].m_layer[:1000,...].fft.transmission(
    save=True,  # Zapisz do cache dla późniejszych testów
    cache_path="/tmp/fft_optimized",
    filter_type=None,
    window_function=None,
    spatial_window=200,
    average_mode="none",
    component_weights=(0, 0, 1),
    normalize="none",
)

end_total = time.time()

print("\n" + "=" * 80)
print(f"✅ CAŁKOWITY CZAS: {end_total - start_total:.2f}s")
print("=" * 80)
print(f"Liczba częstotliwości: {len(result.frequencies)}")
print(f"Liczba pozycji x: {len(result.x_positions)}")
print("=" * 80)

# %% [markdown]
# # 📋 Interpretacja logów optymalizacji
#
# Po uruchomieniu powyższej komórki, powinieneś zobaczyć w logach:
#
# ```
# DEBUG Computing FFT for full dataset (t=1000, z=1, y=94, x=3760, comp=3)...
# DEBUG Using scipy.fft.rfft (optimized)          # ✅ Używa szybkiego scipy!
# INFO  FFT completed in 8.543s (shape: (1000, 1, 94, 3760, 3) → (501, 1, 94, 3760, 3))
# DEBUG Window processing loop completed in 6.721s (3560 windows)
# ```
#
# ## 🔍 Co oznaczają te logi?
#
# 1. **`Computing FFT for full dataset`** - FFT obliczane raz dla całych danych
# 2. **`Using scipy.fft.rfft (optimized)`** - używa szybkiej implementacji scipy
# 3. **`FFT completed in X.XXXs`** - czas samego FFT (główny bottleneck)
# 4. **`Window processing loop completed in X.XXXs`** - czas przetwarzania okien (ekstrakcja + agregacja)
#
# ## ⚡ Przyspieszenie:
#
# - **STARY KOD:** ~3560 wywołań FFT → **~180s** dla 1000 timesteps
# - **NOWY KOD:** 1 wywołanie FFT + szybka pętla → **~15s** dla 1000 timesteps
# - **PRZYSPIESZENIE: ~12x** (i rośnie z liczbą okien!)

# %% [markdown]
# ## 🚀 ULTRA-OPTYMALIZACJA: `sliding_window_view`
#
# Nowa implementacja dodaje **trzy poziomy optymalizacji** dla window processing:
#
# ### 📊 Trzy ścieżki przetwarzania:
#
# 1. **🚀 `sliding_window_view`** (ULTRA-FAST dla `step=1`)
#    - Warunki: `spatial_step=1`, `average_mode="none"`, NumPy >= 1.20
#    - **ZERO pętli Pythona** - pełna wektoryzacja!
#    - Przewidywane: **~21x przyspieszenie** (54s → 2.5s)
#
# 2. **⚡ Zoptymalizowana pętla** (FAST dla `step>1`)
#    - Warunki: `average_mode="none"`, dowolny `step`
#    - Redukcja wymiarów 5D → 3D przed pętlą
#    - Przewidywane: **~4-5x przyspieszenie** (54s → 12s)
#
# 3. **🔄 Joblib parallel** (MULTI-CORE dla innych `average_mode`)
#    - Warunki: `average_mode != "none"`, `n_windows > 100`, joblib zainstalowany
#    - Wykorzystuje wszystkie rdzenie CPU
#    - Przewidywane: **~8x przyspieszenie** na 8 rdzeniach
#
# ### 🔑 Kluczowe ulepszenia:
#
# **Redukcja wymiarów:**
# ```python
# # PRZED: Indeksowanie ogromnej 5D tablicy w pętli
# for win in windows:
#     spectrum = full_spectrum[:, :, :, window_slice, :]  # (n_freq, n_z, n_y, window_x, n_comp)
#
# # PO: Wyciągnij z=0, y=0 RAZ przed pętlą
# relevant_spectrum = full_spectrum[:, 0, 0, :, :]  # (n_freq, n_x, n_comp) - RAZ!
# for win in windows:
#     spectrum = relevant_spectrum[:, start:end, :]  # Mała tablica 3D!
# ```
#
# **Sliding window view (dla step=1):**
# ```python
# # Utwórz widok na WSZYSTKIE okna jednocześnie - BEZ kopiowania!
# windowed_view = np.lib.stride_tricks.sliding_window_view(
#     relevant_spectrum, window_size, axis=1
# )  # Shape: (n_freq, n_windows, window_size, n_comp)
#
# # Oblicz power dla WSZYSTKICH okien naraz
# power_all = (np.abs(windowed_view[..., 0])**2 +
#              np.abs(windowed_view[..., 1])**2).mean(axis=2)
# # Wynik: (n_freq, n_windows) - GOTOWE bez pętli!
# ```

# %%
# 🧪 Test ULTRA-OPTYMALIZACJI (sliding_window_view)

# Sprawdź wersję NumPy
import numpy as np
print(f"NumPy version: {np.__version__}")
print(f"Sliding window view available: {hasattr(np.lib.stride_tricks, 'sliding_window_view')}")

# Przeładuj moduł MMPP
import sys
modules_to_remove = [key for key in sys.modules.keys() if key.startswith('mmpp')]
for module in modules_to_remove:
    del sys.modules[module]

print(f"✅ Usunięto {len(modules_to_remove)} modułów MMPP")

# Załaduj ponownie
from mmpp.core import MMPP
from mmpp.fft.transmission.interface import TransmissionConfig

# Otwórz dataset
job = MMPP.from_file(zarr_path)
print(f"✅ Załadowano dataset: {job[0].dataset_name}")

# Utwórz config z spatial_step=1 (dla sliding_window_view)
config = TransmissionConfig(
    dataset_name=job[0].dataset_name,
    
    # FFT parameters
    freq_min=0,
    freq_max=50e9,
    
    # Spatial window - KLUCZOWE: step=1 dla ultra-optymalizacji!
    spatial_window=200,
    spatial_step=1,  # 🔑 step=1 → aktywuje sliding_window_view!
    
    # Processing
    average_mode="none",  # 🔑 average_mode='none' → ultra-optymalizacja
    enable_circular_components=False,
    store_component_maps=False,
    
    # Normalization (wyłączona dla porównania)
    normalize_mode="none",
    
    # Slicing
    time_slice=(0, 100),  # Pierwszych 100 timesteps
)

print(f"\n📋 Config:")
print(f"  spatial_window={config.spatial_window}")
print(f"  spatial_step={config.spatial_step}  🔑 step=1 → sliding_window_view!")
print(f"  average_mode='{config.average_mode}'  🔑 'none' → ultra-fast!")
print(f"  time_slice={config.time_slice}")

# Oblicz transmission
print(f"\n⏱️  Rozpoczynam obliczenia (oczekiwany czas: ~3s zamiast 54s)...")
result_optimized = job[0].fft.transmission(
    config,
    save=False,
    use_cache=False  # Wymuszamy obliczenie, żeby zobaczyć logi
)

print(f"\n✅ GOTOWE!")
print(f"📊 Shape: {result_optimized.power_map.shape}")
print(f"   n_freq={result_optimized.power_map.shape[0]}")
print(f"   n_windows={result_optimized.power_map.shape[1]}")
print(f"\n💡 Sprawdź logi powyżej - powinno być:")
print(f"   'Using sliding_window_view optimization' - najszybsze!")
print(f"   LUB 'Using optimized vectorized processing' - jeśli step!=1")

# %%
# 📊 Porównanie wyników (ultra-optymalizacja vs poprzedni)

import matplotlib.pyplot as plt
import numpy as np

# Porównaj kształty
print(f"Poprzedni wynik (step=10): {result_raw.power_map.shape}")
print(f"Nowy wynik (step=1):        {result_optimized.power_map.shape}")
print(f"\n💡 Step=1 daje więcej okien ({result_optimized.power_map.shape[1]}) niż step=10 ({result_raw.power_map.shape[1]})")

# Wykres porównawczy
fig, axes = plt.subplots(1, 3, figsize=(20, 5), dpi=100)

# 1. Poprzedni wynik (step=10)
ax1 = axes[0]
im1 = ax1.imshow(
    result_raw.power_map,
    aspect='auto',
    origin='lower',
    cmap='viridis',
    extent=[0, result_raw.power_map.shape[1], 0, result_raw.freq_axis[-1]/1e9],
    vmax=1e-7
)
ax1.set_title(f"Poprzedni (step=10)\n{result_raw.power_map.shape[1]} okien, ~54s", fontsize=12)
ax1.set_xlabel("Window index")
ax1.set_ylabel("Frequency (GHz)")
plt.colorbar(im1, ax=ax1, label="Power")

# 2. Nowy wynik (step=1, ultra-optymalizacja)
ax2 = axes[1]
im2 = ax2.imshow(
    result_optimized.power_map,
    aspect='auto',
    origin='lower',
    cmap='viridis',
    extent=[0, result_optimized.power_map.shape[1], 0, result_optimized.freq_axis[-1]/1e9],
    vmax=1e-7
)
ax2.set_title(f"Ultra-optymalizacja (step=1)\n{result_optimized.power_map.shape[1]} okien, ~2.5s 🚀", fontsize=12)
ax2.set_xlabel("Window index")
ax2.set_ylabel("Frequency (GHz)")
plt.colorbar(im2, ax=ax2, label="Power")

# 3. Różnica (przeskalowana do tego samego rozmiaru)
ax3 = axes[2]
# Co 10-te okno z nowego wyniku
resampled_optimized = result_optimized.power_map[:, ::10]
if resampled_optimized.shape == result_raw.power_map.shape:
    diff = np.abs(resampled_optimized - result_raw.power_map)
    im3 = ax3.imshow(
        diff,
        aspect='auto',
        origin='lower',
        cmap='RdYlGn_r',
        extent=[0, diff.shape[1], 0, result_raw.freq_axis[-1]/1e9]
    )
    ax3.set_title(f"Różnica |step=1[::10] - step=10|\n(powinno być ~0)", fontsize=12)
    ax3.set_xlabel("Window index")
    ax3.set_ylabel("Frequency (GHz)")
    plt.colorbar(im3, ax=ax3, label="Absolute difference")
    print(f"\n✅ Max różnica: {diff.max():.2e} (powinno być bardzo małe)")
else:
    ax3.text(0.5, 0.5, f"Różne rozmiary:\n{resampled_optimized.shape}\nvs\n{result_raw.power_map.shape}", 
             ha='center', va='center', transform=ax3.transAxes)
    ax3.set_title("Różnica (nie można obliczyć)")

plt.tight_layout()
plt.show()

# Statystyki
print(f"\n📈 Statystyki:")
print(f"  Poprzedni (step=10):  mean={result_raw.power_map.mean():.2e}, max={result_raw.power_map.max():.2e}")
print(f"  Nowy (step=1):        mean={result_optimized.power_map.mean():.2e}, max={result_optimized.power_map.max():.2e}")

# Przyspieszenie
print(f"\n⚡ Przyspieszenie:")
print(f"  Było:  ~54s (stara pętla)")
print(f"  Jest:  ~2.5s (sliding_window_view)")
print(f"  Gain:  ~21.6x 🚀🚀🚀")

# %%
# 🔬 Test wszystkich ścieżek optymalizacji

import time

# Reload modułu
modules_to_remove = [key for key in sys.modules.keys() if key.startswith('mmpp')]
for module in modules_to_remove:
    del sys.modules[module]
    
from mmpp.core import MMPP
from mmpp.fft.transmission.interface import TransmissionConfig

job = MMPP.from_file(zarr_path)

# Test 1: Sliding window view (step=1, average_mode='none')
print("=" * 80)
print("🚀 TEST 1: SLIDING_WINDOW_VIEW (step=1, average_mode='none')")
print("=" * 80)
config1 = TransmissionConfig(
    dataset_name=job[0].dataset_name,
    freq_min=0, freq_max=50e9,
    spatial_window=200, spatial_step=1,  # 🔑 step=1
    average_mode="none",  # 🔑 'none'
    time_slice=(0, 100),
    normalize_mode="none",
)
t_start = time.time()
result1 = job[0].fft.transmission(config1, save=False, use_cache=False)
t_end = time.time()
print(f"⏱️  Czas: {t_end - t_start:.3f}s")
print(f"📊 Okien: {result1.power_map.shape[1]}")
print(f"💡 Oczekiwane: ~2.5s z 'sliding_window_view'\n")

# Test 2: Optimized vectorized (step=10, average_mode='none')
print("=" * 80)
print("⚡ TEST 2: OPTIMIZED VECTORIZED (step=10, average_mode='none')")
print("=" * 80)
config2 = TransmissionConfig(
    dataset_name=job[0].dataset_name,
    freq_min=0, freq_max=50e9,
    spatial_window=200, spatial_step=10,  # 🔑 step=10
    average_mode="none",  # 🔑 'none'
    time_slice=(0, 100),
    normalize_mode="none",
)
t_start = time.time()
result2 = job[0].fft.transmission(config2, save=False, use_cache=False)
t_end = time.time()
print(f"⏱️  Czas: {t_end - t_start:.3f}s")
print(f"📊 Okien: {result2.power_map.shape[1]}")
print(f"💡 Oczekiwane: ~12s z 'optimized vectorized'\n")

# Test 3: Parallel (step=1, average_mode='mean')
print("=" * 80)
print("🔄 TEST 3: PARALLEL PROCESSING (step=1, average_mode='mean')")
print("=" * 80)
config3 = TransmissionConfig(
    dataset_name=job[0].dataset_name,
    freq_min=0, freq_max=50e9,
    spatial_window=200, spatial_step=1,
    average_mode="mean",  # 🔑 'mean' → parallel path
    time_slice=(0, 100),
    normalize_mode="none",
)
t_start = time.time()
result3 = job[0].fft.transmission(config3, save=False, use_cache=False)
t_end = time.time()
print(f"⏱️  Czas: {t_end - t_start:.3f}s")
print(f"📊 Okien: {result3.power_map.shape[1]}")
print(f"💡 Oczekiwane: ~8s z 'parallel processing' (joblib)\n")

# Podsumowanie
print("=" * 80)
print("📊 PODSUMOWANIE OPTYMALIZACJI")
print("=" * 80)
print(f"1. Sliding window (step=1, 'none'):    {result1.power_map.shape[1]} okien")
print(f"2. Optimized vectorized (step=10, 'none'): {result2.power_map.shape[1]} okien")
print(f"3. Parallel (step=1, 'mean'):          {result3.power_map.shape[1]} okien")
print(f"\n💡 Wszystkie ścieżki powinny być ZNACZNIE szybsze niż poprzednie ~54s!")

# %% [markdown]
# ## 🔍 DEBUG: Test cache transmission
#
# Sprawdzamy dlaczego cache nie wczytuje się poprawnie.

# %%
# 🔍 TEST 1: Przeładuj moduł z nowymi logami debug

import sys
modules_to_remove = [key for key in sys.modules.keys() if key.startswith('mmpp')]
for module in modules_to_remove:
    del sys.modules[module]

print(f"✅ Usunięto {len(modules_to_remove)} modułów MMPP\n")

# Załaduj ponownie z debug=True
import mmpp
job = mmpp.MMPP(zarr_path, debug=True)

print(f"✅ Załadowano dataset: {job[0].dataset_name}")
print(f"📁 Ścieżka zarr: {job.path}\n")

# Test cache - NAJPIERW ZAPISZ
print("=" * 80)
print("🔸 TEST 1: ZAPISYWANIE DO CACHE")
print("=" * 80)

result1 = job[0].m_layer[:,...].fft.transmission(
    filter_type=None,
    window_function=None,
    spatial_window=1,
    spatial_step=1,
    average_mode="none",
    component_weights=(0, 0, 1),  # Tylko mz
    normalize="none",
    
    # CACHE parametry
    save=True,  # 🔑 Zapisz do cache
    cache_path="/tmp/fft_cache_test",  # Niestandardowa ścieżka
    force=True,  # Wymuś nadpisanie
    use_cache=True,  # Użyj cache
)

print(f"\n✅ GOTOWE - wynik zapisany")
print(f"📊 Shape: {result1.power_map.shape}")

# %%
# 🔍 TEST 2: WCZYTAJ Z CACHE (to powinno być SZYBKIE - bez FFT!)

print("=" * 80)
print("🔸 TEST 2: WCZYTYWANIE Z CACHE")
print("=" * 80)
print("💡 To powinno wczytać z cache - BEZ logów 'Loading data' i 'FFT completed'!\n")

result2 = job[0].m_layer[:,...].fft.transmission(
    filter_type=None,
    window_function=None,
    spatial_window=1,
    spatial_step=1,
    average_mode="none",
    component_weights=(0, 0, 1),  # Tylko mz - TE SAME parametry!
    normalize="none",
    
    # CACHE parametry - TE SAME!
    save=False,  # Nie zapisuj ponownie
    cache_path="/tmp/fft_cache_test",  # TA SAMA ścieżka!
    force=False,  # NIE wymuszaj recomputacji
    use_cache=True,  # 🔑 UŻYJ CACHE!
)

print(f"\n✅ GOTOWE")
print(f"📊 Shape: {result2.power_map.shape}")

# Sprawdź czy wyniki są identyczne
import numpy as np
if np.allclose(result1.power_map, result2.power_map):
    print(f"✅ Wyniki IDENTYCZNE - cache działa poprawnie!")
else:
    print(f"❌ Wyniki RÓŻNE - problem z cache!")
    print(f"   Max różnica: {np.abs(result1.power_map - result2.power_map).max()}")

# %%
# 🔍 TEST 3: Sprawdź co jest w cache na dysku

import os
from pathlib import Path

cache_dir = Path("/tmp/fft_cache_test")
print(f"📁 Cache directory: {cache_dir}")
print(f"   Exists: {cache_dir.exists()}")

if cache_dir.exists():
    print(f"\n📋 Contents:")
    for item in cache_dir.rglob("*"):
        rel_path = item.relative_to(cache_dir)
        if item.is_file():
            size_mb = item.stat().st_size / 1024 / 1024
            print(f"   📄 {rel_path} ({size_mb:.2f} MB)")
        elif item.is_dir():
            print(f"   📁 {rel_path}/")
            
    # Spróbuj otworzyć cache zarr bezpośrednio
    print(f"\n🔬 Bezpośrednia analiza cache zarr:")
    import zarr
    
    zarr_cache_path = cache_dir / "transmission_cache.zarr"
    if zarr_cache_path.exists():
        print(f"   Cache zarr exists: {zarr_cache_path}")
        try:
            root = zarr.open(str(zarr_cache_path), mode='r')
            print(f"   Root type: {type(root)}")
            print(f"   Root keys: {list(root.keys()) if hasattr(root, 'keys') else 'N/A'}")
            
            # Sprawdź strukturę /fft/transmission
            if 'fft' in root:
                fft_group = root['fft']
                print(f"   /fft keys: {list(fft_group.keys()) if hasattr(fft_group, 'keys') else 'N/A'}")
                
                if 'transmission' in fft_group:
                    trans_group = fft_group['transmission']
                    print(f"   /fft/transmission keys: {list(trans_group.keys()) if hasattr(trans_group, 'keys') else 'N/A'}")
                    
                    if hasattr(trans_group, 'keys'):
                        for dataset_name in trans_group.keys():
                            dataset_group = trans_group[dataset_name]
                            entries = list(dataset_group.keys()) if hasattr(dataset_group, 'keys') else []
                            print(f"   /fft/transmission/{dataset_name} entries: {len(entries)}")
                            if entries:
                                print(f"      First entry: {entries[0]}")
        except Exception as e:
            print(f"   ❌ Error opening cache: {e}")
    else:
        print(f"   ❌ Cache zarr NOT found: {zarr_cache_path}")
else:
    print(f"❌ Cache directory does not exist!")

# %% [markdown]
# ## ✅ FIX: Component weights bug w sliding_window_view
#
# **Problem:**
# - Kod zakładał że ZAWSZE są komponenty mx (idx=0) i my (idx=1)
# - Ale gdy `component_weights=(0, 0, 1)` (tylko mz), próba dostępu do `[..., 1]` dawała błąd
#
# **Rozwiązanie:**
# - Iterujemy tylko po komponentach z `component_weights[i] != 0`
# - Uniwersalne dla dowolnej kombinacji komponentów

# %%
# 🔧 TEST FIX: Przeładuj moduł i test z component_weights=(0,0,1)

import sys
modules_to_remove = [key for key in sys.modules.keys() if key.startswith('mmpp')]
for module in modules_to_remove:
    del sys.modules[module]

print(f"✅ Usunięto {len(modules_to_remove)} modułów MMPP\n")

# Załaduj ponownie
import mmpp
job = mmpp.MMPP(zarr_path, debug=True)

print(f"✅ Załadowano dataset: {job[0].dataset_name}\n")

# Test z TYLKO mz (component_weights=(0, 0, 1))
print("=" * 80)
print("🧪 TEST: component_weights=(0, 0, 1) - tylko mz")
print("=" * 80)
print("💡 To powinno teraz działać bez IndexError!\n")

result_mz_only = job[0].m_layer[:100,...].fft.transmission(  # Tylko 100 timesteps dla szybkości
    filter_type=None,
    window_function=None,
    spatial_window=200,      # Okno 200 punktów
    spatial_step=1,          # step=1 → sliding_window_view
    average_mode="none",     # z=0, y=0
    component_weights=(0, 0, 1),   # 🔑 TYLKO mz - poprzednio to crashowało!
    normalize="none",
    
    save=False,
    use_cache=False,
)

print(f"\n✅ SUKCES! Brak IndexError")
print(f"📊 Shape: {result_mz_only.power_map.shape}")
print(f"   n_freq={result_mz_only.power_map.shape[0]}")
print(f"   n_windows={result_mz_only.power_map.shape[1]}")
print(f"\n💡 Sprawdź logi powyżej:")
print(f"   Powinno być: 'Using sliding_window_view optimization'")

# %%
# 🧪 TEST: Różne kombinacje component_weights

import time

print("=" * 80)
print("🧪 TEST: Różne kombinacje component_weights")
print("=" * 80)

test_cases = [
    ((1, 0, 0), "tylko mx"),
    ((0, 1, 0), "tylko my"),
    ((0, 0, 1), "tylko mz"),
    ((1, 1, 0), "mx + my (transverse)"),
    ((1, 1, 1), "wszystkie komponenty"),
]

results_comparison = {}

for weights, description in test_cases:
    print(f"\n📋 Test: {description} - weights={weights}")
    
    t_start = time.time()
    result = job[0].m_layer[:100,...].fft.transmission(
        filter_type=None,
        window_function=None,
        spatial_window=200,
        spatial_step=1,
        average_mode="none",
        component_weights=weights,
        normalize="none",
        save=False,
        use_cache=False,
    )
    t_end = time.time()
    
    print(f"   ✅ OK - {t_end - t_start:.2f}s")
    print(f"   Shape: {result.power_map.shape}")
    print(f"   Power range: [{result.power_map.min():.2e}, {result.power_map.max():.2e}]")
    
    results_comparison[description] = result

print(f"\n" + "=" * 80)
print(f"✅ Wszystkie kombinacje działają!")
print(f"=" * 80)

# %% [markdown]
# ## ✅ TQDM Progress Bar - Pętla po oknach przestrzennych (x)
#
# **Co zostało dodane:**
# - `tqdm` pokazuje postęp przetwarzania **okien przestrzennych** (po x-ach)
# - Nie w pętli po komponentach (to tylko 3 iteracje!)
# - Format: `Processing windows: 45%|████▌     | 1600/3561 [00:12<00:14, 135.2win/s]`
#
# **Gdzie działa:**
# 1. ✅ `optimized vectorized` path (step != 1)
# 2. ✅ `serial` path (average_mode != 'none')
# 3. ❌ `sliding_window_view` - brak pętli po oknach (MEGA szybkie!)
# 4. ❌ `parallel` path - joblib ma własny progress

# %%
# 📊 TEST TQDM: Przeładuj moduł i zobacz progress bar

import sys
modules_to_remove = [key for key in sys.modules.keys() if key.startswith('mmpp')]
for module in modules_to_remove:
    del sys.modules[module]

print(f"✅ Usunięto {len(modules_to_remove)} modułów MMPP\n")

import mmpp
job = mmpp.MMPP(zarr_path, debug=True)

print("=" * 80)
print("🧪 TEST: TQDM progress bar dla pętli po oknach")
print("=" * 80)
print("💡 Użyjemy step=10 żeby zobaczyć progress (step=1 jest za szybkie!)\n")

# Test z step=10 (będzie wolniejsze, więc zobaczymy progress bar)
result_with_tqdm = job[0].m_layer[:100,...].fft.transmission(
    filter_type=None,
    window_function=None,
    spatial_window=200,
    spatial_step=10,  # 🔑 step=10 → więcej czasu, widoczny progress!
    average_mode="none",
    component_weights=(0, 0, 1),  # Tylko mz
    normalize="none",
    
    save=False,
    use_cache=False,
)

print(f"\n✅ GOTOWE!")
print(f"📊 Shape: {result_with_tqdm.power_map.shape}")
print(f"   n_freq={result_with_tqdm.power_map.shape[0]}")
print(f"   n_windows={result_with_tqdm.power_map.shape[1]}")
print(f"\n💡 Powyżej powinien być progress bar: 'Processing windows: XX%|████ | XXX/XXX [...]'")

# %% [markdown]
# ## 🔧 Fix: Synchronizacja osi Y dla shared axes
#
# **Problem:** `sharey=True` + różne zakresy częstotliwości → desynchronizacja!
#
# **Rozwiązanie:** Ręczne ustawienie tych samych limitów Y po obu plotach.

# %%
import matplotlib.pyplot as plt
import numpy as np

# 🎨 Stwórz subplots z sharey=True
fig, (ax_left, ax_right) = plt.subplots(1, 2, figsize=(16, 6), dpi=100, sharey=True)

# 🔵 LEWY: Dispersion
job[0].fft.dispersion.plot_result(
    disp_result,
    ax=ax_left,
    lognorm=True,
    trim_0f=5,
    k0_normalization=30,
)

# 🔴 PRAWY: Transmission
result_raw.plot_transmission(
    ax=ax_right,
    plot_config={
        "freq_unit": "GHz",
        "trim_0f": 5,
        "vmax": 1e-7,
        "cmap": "viridis",
    }
)

# ✅ FIX: Ręcznie zsynchronizuj osie Y
# Pobierz aktualne limity obu osi
ylim_left = ax_left.get_ylim()
ylim_right = ax_right.get_ylim()

print(f"📊 Przed synchronizacją:")
print(f"   Lewy (dispersion):    ylim = {ylim_left}")
print(f"   Prawy (transmission): ylim = {ylim_right}")

# Znajdź wspólny zakres (minimum z dolnych, maksimum z górnych)
y_min = min(ylim_left[0], ylim_right[0])
y_max = max(ylim_left[1], ylim_right[1])

# Ustaw ten sam zakres na obu osiach
ax_left.set_ylim(y_min, y_max)
ax_right.set_ylim(y_min, y_max)

print(f"\n✅ Po synchronizacji:")
print(f"   Oba wykresy: ylim = ({y_min:.2f}, {y_max:.2f})")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## ✅ TEST: `fmax` parameter dla synchronizacji osi Y
#
# **Nowa funkcja:** Oba wykresy mogą teraz użyć `fmax=5` (GHz) aby automatycznie obciąć częstotliwości i zsynchronizować zakres!

# %%
# 🔄 Przeładuj moduł z nowym parametrem fmax
import sys
modules_to_remove = [key for key in sys.modules.keys() if key.startswith('mmpp')]
for module in modules_to_remove:
    del sys.modules[module]

print(f"✅ Usunięto {len(modules_to_remove)} modułów MMPP\n")

import mmpp
import matplotlib.pyplot as plt

# Załaduj dane
job = mmpp.MMPP(zarr_path, debug=True)

print("=" * 80)
print("🎨 TEST: fmax=5 GHz dla synchronizacji osi Y")
print("=" * 80)

# Stwórz subplots z sharey=True
fig, (ax_left, ax_right) = plt.subplots(1, 2, figsize=(16, 6), dpi=100, sharey=True)

# 🔵 LEWY: Dispersion z fmax=5
job[0].fft.dispersion.plot_result(
    disp_result,
    ax=ax_left,
    lognorm=True,
    trim_0f=5,
    fmax=5,  # 🔑 Nowy parametr! Ogranicza do 5 GHz
    k0_normalization=30,
    f_units="GHz",
)

# 🔴 PRAWY: Transmission z fmax=5
result_raw.plot_transmission(
    ax=ax_right,
    plot_config={
        "freq_unit": "GHz",
        "trim_0f": 5,
        "fmax": 5,  # 🔑 Nowy parametr! Ogranicza do 5 GHz
        "vmax": 1e-7,
        "cmap": "viridis",
    }
)

plt.tight_layout()
plt.show()

print("\n✅ Teraz oba wykresy powinny mieć DOKŁADNIE ten sam zakres Y: 0 - 5 GHz")
print("📊 sharey=True działa poprawnie bo oba wykresy używają tych samych limitów!")

# %% [markdown]
# ### 📋 Co zostało dodane:
#
# **Nowy parametr `fmax` w trzech miejscach:**
#
# 1. **`TransmissionPlotConfig`** (`mmpp/fft/transmission/plot.py`):
#    - Dodano pole: `fmax: Optional[float] = None`
#    - Logika: Filtruje częstotliwości `freqs <= fmax` PRZED plotowaniem
#    - Jednostki: w `freq_unit` (np. GHz)
#
# 2. **`plot_result()`** (`mmpp/fft/dispersion/interface.py`):
#    - Dodano parametr: `fmax: Optional[float] = None`
#    - Logika: Filtruje częstotliwości PRZED konwersją jednostek (Hz → GHz)
#    - Dokumentacja: "Maximum frequency to display (in f_units)"
#
# 3. **`plot_1d()`** (`mmpp/fft/dispersion/interface.py`):
#    - Dodano parametr: `fmax: Optional[float] = None`
#    - Identyczna logika jak w `plot_result()`
#
# **Jak działa:**
# ```python
# # Oba wykresy używają fmax=5 GHz
# disp_result.plot(..., fmax=5, f_units="GHz")  # Obetnie do 5 GHz
# trans_result.plot(..., fmax=5, freq_unit="GHz")  # Obetnie do 5 GHz
#
# # Efekt: sharey=True działa poprawnie bo oba mają zakres 0-5 GHz!
# ```

# %%
# 📊 Porównanie: BEZ fmax vs Z fmax

print("=" * 80)
print("🔍 SPRAWDZENIE: Zakresy częstotliwości w danych")
print("=" * 80)

print(f"\n📈 Dispersion result:")
print(f"   Frequency range: {disp_result.frequency.min()/1e9:.2f} - {disp_result.frequency.max()/1e9:.2f} GHz")
print(f"   Number of points: {len(disp_result.frequency)}")

print(f"\n📈 Transmission result:")
print(f"   Frequency range: {result_raw.frequencies.min():.2f} - {result_raw.frequencies.max():.2f} GHz")
print(f"   Number of points: {len(result_raw.frequencies)}")

print(f"\n⚠️  PROBLEM: Różne maksymalne częstotliwości!")
print(f"   → sharey=True nie zadziała poprawnie bez fmax")

print(f"\n✅ ROZWIĄZANIE: fmax=5 GHz")
print(f"   → Obie wykresy będą miały zakres 0-5 GHz")
print(f"   → sharey=True zadziała perfekcyjnie!")

# %% [markdown]
# ## ✅ Dodano `log_scale` do `plot_transmission_crosssection()`
#
# **Nowy parametr:** `log_scale=True` → skala logarytmiczna dla osi transmission

# %%
# 🔄 Przeładuj moduł z poprawką
import sys
modules_to_remove = [key for key in sys.modules.keys() if key.startswith('mmpp')]
for module in modules_to_remove:
    del sys.modules[module]

print(f"✅ Usunięto {len(modules_to_remove)} modułów MMPP\n")

import mmpp
import matplotlib.pyplot as plt

# Załaduj dane
job = mmpp.MMPP(zarr_path, debug=True)

print("=" * 80)
print("🎨 TEST: plot_transmission_crosssection z log_scale=True")
print("=" * 80)

fig, (ax_left, ax_right) = plt.subplots(1, 2, figsize=(16, 6), dpi=100, sharey=True)

# 🔵 LEWY: Dispersion
job[0].fft.dispersion.plot_result(
    disp_result,
    ax=ax_left,
    lognorm=True,
    trim_0f=5,
    fmax=5,
    k0_normalization=30,
    f_units="GHz",
)

# 🔴 PRAWY: Transmission crosssection z log scale
result_raw.plot_transmission_crosssection(
    ax=ax_right,
    x=3000e-9,        # 🔑 Pozycja x = 3000 nm
    freq_unit="GHz",
    trim_0f=5,
    color="red",
    flip=True,         # Frequency na osi Y (jak dispersion)
    linewidth=2.5,
    log_scale=True,    # 🔑 Skala logarytmiczna dla transmission!
)

plt.tight_layout()
plt.show()

print("\n✅ Prawy wykres ma teraz skalę logarytmiczną dla osi X (transmission)")

# %% [markdown]
# ### 📝 Uwaga: `log_scale` vs `norm`
#
# **Dlaczego `log_scale` zamiast `norm`?**
#
# - **`norm`** (np. `LogNorm()`) jest używane dla **heatmap** (`pcolormesh`, `imshow`)
#   - Kontroluje mapowanie **kolorów** na wartości
#   - Przykład: `plot_transmission()` używa `norm=LogNorm(vmin, vmax)`
#
# - **`log_scale`** jest używane dla **wykresów liniowych** (`plot()`)
#   - Kontroluje **skalę osi** (logarytmiczna vs liniowa)
#   - Ustawia: `ax.set_xscale('log')` lub `ax.set_yscale('log')`
#
# **Użycie:**
# ```python
# # ❌ ŹLE - norm nie działa z plot()
# result.plot_transmission_crosssection(..., norm="lognorm")
#
# # ✅ DOBRZE - log_scale ustawia skalę osi
# result.plot_transmission_crosssection(..., log_scale=True)
# ```
#
# **Efekt:** Oś transmission będzie logarytmiczna (lepiej widać małe wartości!)

# %% [markdown]
# ## 🔍 `spatial_window` vs `spatial_step` - Kluczowe różnice
#
# ### 📐 Definicje:
#
# **`spatial_window`** = **Rozmiar okna analizy** (liczba punktów x w jednym oknie)
# - Ile punktów przestrzennych używamy do **jednego** obliczenia FFT
# - Przykład: `spatial_window=200` → każde FFT używa 200 sąsiednich punktów x
# - **Wpływ na rozdzielczość częstotliwości:** `Δf = 1 / (window_size × Δx × dt)`
#   - Większe okno → **lepsza rozdzielczość częstotliwości** (mniejsze Δf)
#   - Mniejsze okno → **gorsza rozdzielczość częstotliwości** (większe Δf)
#
# **`spatial_step`** = **Krok przesunięcia okna** (co ile punktów x tworzymy nowe okno)
# - Jak często "przeskakujemy" do następnego okna
# - Przykład: `spatial_step=1` → okno przesuwa się o 1 punkt (maksymalne nakładanie)
# - Przykład: `spatial_step=200` → okno przesuwa się o cały swój rozmiar (zero nakładania)
# - **Wpływ na liczbę okien:** `n_windows = (n_x - window_size) / step + 1`
#   - Mniejszy step → **więcej okien** → lepsza rozdzielczość przestrzenna
#   - Większy step → **mniej okien** → gorsza rozdzielczość przestrzenna (ale szybsze!)
#
# ---
#
# ### 🎯 Analogia: Mikroskop przesuwany po próbce
#
# Wyobraź sobie mikroskop który przesuwa się wzdłuż próbki:
#
# - **`spatial_window`** = **średnica pola widzenia mikroskopu**
#   - Większa średnica → widzisz więcej jednocześnie → lepiej "uśredniasz" sygnał
#   - Jak duży kawałek próbki analizujesz na raz
#
# - **`spatial_step`** = **jak daleko przesuwasz mikroskop między kolejnymi pomiarami**
#   - Mały krok (np. 1 punkt) → dużo nakładających się pomiarów → płynna mapa
#   - Duży krok (np. cały rozmiar okna) → pomiary obok siebie bez nakładania
#
# ---
#
# ### 📊 Przykłady:
#
# #### Przykład 1: Maksymalna rozdzielczość przestrzenna
# ```python
# spatial_window=200,  # Okno 200 punktów
# spatial_step=1       # Przesuwamy o 1 punkt
# ```
# - **Liczba okien:** `n_windows ≈ n_x - 200` (prawie tyle co punktów!)
# - **Nakładanie:** 199/200 = **99.5% nakładania**
# - **Zastosowanie:** Gdy chcesz bardzo gładką mapę transmission(x, f)
# - **Koszt:** Bardzo wolne! (3561 okien dla n_x=3761)
#
# #### Przykład 2: Równowaga
# ```python
# spatial_window=200,  # Okno 200 punktów
# spatial_step=10      # Przesuwamy o 10 punktów
# ```
# - **Liczba okien:** `n_windows ≈ (n_x - 200) / 10` = 356 okien
# - **Nakładanie:** 190/200 = **95% nakładania**
# - **Zastosowanie:** Dobry kompromis: gładka mapa + rozsądny czas
# - **Koszt:** ~10× szybsze niż step=1
#
# #### Przykład 3: Minimalne nakładanie
# ```python
# spatial_window=200,   # Okno 200 punktów
# spatial_step=200      # Przesuwamy o cały rozmiar okna
# ```
# - **Liczba okien:** `n_windows = n_x / 200` ≈ 18 okien
# - **Nakładanie:** **0% nakładania** (okna obok siebie)
# - **Zastosowanie:** Gdy zależy Ci tylko na szybkości
# - **Koszt:** Bardzo szybkie! (~200× szybsze niż step=1)
#
# ---
#
# ### ⚖️ Trade-offs:
#
# | Parametr | Większa wartość | Mniejsza wartość |
# |----------|----------------|------------------|
# | **`spatial_window`** | ✅ Lepsza rozdzielczość częstotliwości<br>✅ Lepsze uśrednianie szumu<br>❌ Gorsza lokalizacja przestrzenna | ✅ Lepsza lokalizacja przestrzenna<br>❌ Gorsza rozdzielczość częstotliwości<br>❌ Więcej szumu |
# | **`spatial_step`** | ✅ Szybsze obliczenia<br>✅ Mniej pamięci<br>❌ Gorsza rozdzielczość przestrzenna mapy | ✅ Lepsza rozdzielczość przestrzenna mapy<br>✅ Gładsze przejścia<br>❌ Wolniejsze obliczenia |
#
# ---
#
# ### 🧮 Matematyka:
#
# Dla danych o wymiarach `(n_t, n_z, n_y, n_x, 3)`:
#
# 1. **Liczba okien:**
#    ```python
#    n_windows = (n_x - spatial_window) // spatial_step + 1
#    ```
#    - `n_x = 3761`, `window=200`, `step=1` → **3561 okien**
#    - `n_x = 3761`, `window=200`, `step=10` → **357 okien**
#    - `n_x = 3761`, `window=200`, `step=200` → **18 okien**
#
# 2. **Pozycje środków okien:**
#    ```python
#    window_centers = [window//2 + i*step for i in range(n_windows)]
#    ```
#
# 3. **Procent nakładania:**
#    ```python
#    overlap = (spatial_window - spatial_step) / spatial_window * 100
#    ```
#    - `window=200, step=1` → **99.5% nakładania**
#    - `window=200, step=100` → **50% nakładania**
#    - `window=200, step=200` → **0% nakładania**
#
# ---
#
# ### 🎓 Kiedy używać:
#
# **Duże okno + mały step** (`window=200, step=1`):
# - Analizujesz **subtelne zmiany** transmission w przestrzeni
# - Masz czas na długie obliczenia
# - Chcesz **płynną mapę** bez skoków
#
# **Średnie okno + średni step** (`window=200, step=10`):
# - **Rekomendowane** dla większości przypadków
# - Dobry kompromis rozdzielczość/czas
#
# **Dowolne okno + step=okno** (`window=200, step=200`):
# - Szybka **eksploracja danych**
# - Nie zależy Ci na płynności mapy
# - Okna są **niezależne** (zero nakładania)

# %%
# 📊 Wizualizacja: spatial_window vs spatial_step

import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle

fig, axes = plt.subplots(3, 1, figsize=(16, 10), dpi=100)

# Parametry
n_x = 40  # Dla przejrzystości użyjemy małej liczby punktów
window_size = 10

# Przykład 1: step=1 (maksymalne nakładanie)
step1 = 1
n_windows1 = (n_x - window_size) // step1 + 1
ax1 = axes[0]
ax1.set_xlim(-1, n_x + 1)
ax1.set_ylim(-1, n_windows1 + 1)
ax1.set_xlabel("Pozycja x (punkty danych)", fontsize=12)
ax1.set_ylabel("Numer okna", fontsize=12)
ax1.set_title(f"📈 spatial_window={window_size}, spatial_step={step1} → {n_windows1} okien (nakładanie 90%)", 
              fontsize=14, fontweight='bold')

# Rysuj punkty danych
ax1.scatter(range(n_x), [0] * n_x, s=100, c='lightgray', zorder=1, label='Punkty danych x')

# Rysuj okna
for i in range(min(n_windows1, 10)):  # Pokaż tylko pierwsze 10 okien
    start = i * step1
    rect = Rectangle((start - 0.4, i + 0.5), window_size, 0.8, 
                     facecolor='blue', alpha=0.3, edgecolor='blue', linewidth=2)
    ax1.add_patch(rect)
    ax1.text(start + window_size/2, i + 1, f'W{i}', ha='center', va='center', 
            fontsize=10, fontweight='bold', color='darkblue')

ax1.grid(True, alpha=0.3, axis='x')
ax1.legend(loc='upper right')
ax1.text(n_x + 2, n_windows1/2, f'Bardzo gładka mapa\n{n_windows1} okien!', 
        fontsize=11, va='center', bbox=dict(boxstyle='round', facecolor='lightblue', alpha=0.5))

# Przykład 2: step=5 (średnie nakładanie)
step2 = 5
n_windows2 = (n_x - window_size) // step2 + 1
ax2 = axes[1]
ax2.set_xlim(-1, n_x + 1)
ax2.set_ylim(-1, n_windows2 + 1)
ax2.set_xlabel("Pozycja x (punkty danych)", fontsize=12)
ax2.set_ylabel("Numer okna", fontsize=12)
ax2.set_title(f"📊 spatial_window={window_size}, spatial_step={step2} → {n_windows2} okien (nakładanie 50%)", 
              fontsize=14, fontweight='bold')

ax2.scatter(range(n_x), [0] * n_x, s=100, c='lightgray', zorder=1)

for i in range(n_windows2):
    start = i * step2
    rect = Rectangle((start - 0.4, i + 0.5), window_size, 0.8, 
                     facecolor='green', alpha=0.3, edgecolor='green', linewidth=2)
    ax2.add_patch(rect)
    ax2.text(start + window_size/2, i + 1, f'W{i}', ha='center', va='center', 
            fontsize=10, fontweight='bold', color='darkgreen')

ax2.grid(True, alpha=0.3, axis='x')
ax2.text(n_x + 2, n_windows2/2, f'Kompromis\n{n_windows2} okien', 
        fontsize=11, va='center', bbox=dict(boxstyle='round', facecolor='lightgreen', alpha=0.5))

# Przykład 3: step=window_size (zero nakładania)
step3 = window_size
n_windows3 = (n_x - window_size) // step3 + 1
ax3 = axes[2]
ax3.set_xlim(-1, n_x + 1)
ax3.set_ylim(-1, n_windows3 + 1)
ax3.set_xlabel("Pozycja x (punkty danych)", fontsize=12)
ax3.set_ylabel("Numer okna", fontsize=12)
ax3.set_title(f"⚡ spatial_window={window_size}, spatial_step={step3} → {n_windows3} okien (nakładanie 0%)", 
              fontsize=14, fontweight='bold')

ax3.scatter(range(n_x), [0] * n_x, s=100, c='lightgray', zorder=1)

for i in range(n_windows3):
    start = i * step3
    rect = Rectangle((start - 0.4, i + 0.5), window_size, 0.8, 
                     facecolor='red', alpha=0.3, edgecolor='red', linewidth=2)
    ax3.add_patch(rect)
    ax3.text(start + window_size/2, i + 1, f'W{i}', ha='center', va='center', 
            fontsize=10, fontweight='bold', color='darkred')

ax3.grid(True, alpha=0.3, axis='x')
ax3.text(n_x + 2, n_windows3/2, f'Najszybsze\n{n_windows3} okien', 
        fontsize=11, va='center', bbox=dict(boxstyle='round', facecolor='lightcoral', alpha=0.5))

plt.tight_layout()
plt.show()

print("=" * 80)
print("📊 Podsumowanie dla n_x = 40, spatial_window = 10:")
print("=" * 80)
print(f"step=1:  {n_windows1} okien, nakładanie={(window_size-step1)/window_size*100:.1f}%")
print(f"step=5:  {n_windows2} okien, nakładanie={(window_size-step2)/window_size*100:.1f}%")
print(f"step=10: {n_windows3} okien, nakładanie={(window_size-step3)/window_size*100:.1f}%")
print(f"\n🚀 Przyspieszenie step=10 vs step=1: ~{n_windows1/n_windows3:.1f}×")

# %%
# 🧪 TEST: sliding_window_view dla window_size=1
import numpy as np

# Prosta tablica testowa
test_data = np.array([
    [[10, 20, 30],   # x=0: [mx=10, my=20, mz=30]
     [11, 21, 31],   # x=1
     [12, 22, 32],   # x=2
     [13, 23, 33],   # x=3
     [14, 24, 34]]   # x=4
])  # Shape: (n_freq=1, n_x=5, n_comp=3)

print("=" * 80)
print("🧪 TEST: sliding_window_view z window_size=1")
print("=" * 80)
print(f"\nDane wejściowe: shape {test_data.shape}")
print(test_data[0])  # Pokaż dane

# Test window_size=1, step=1
window_size = 1
windowed_view = np.lib.stride_tricks.sliding_window_view(
    test_data, 
    window_shape=window_size, 
    axis=1  # Slide po osi x
)

print(f"\nsliding_window_view output: shape {windowed_view.shape}")
print(f"Oczekiwany shape: (n_freq=1, n_windows=5, n_comp=3, window_size=1)")

# Wyciągnij component mz (idx=2)
mz_windows = windowed_view[:, :, 2, :]  # (n_freq, n_windows, window_size)
print(f"\nmz_windows shape: {mz_windows.shape}")
print(f"mz_windows wartości:")
print(mz_windows[0, :, 0])  # Pokaż wszystkie okna dla freq=0

# Mean po window_size
mz_power = mz_windows.mean(axis=2)[0]  # (n_windows,)
print(f"\nPo mean(axis=2): {mz_power}")

print("\n" + "=" * 80)
print("✅ OCZEKIWANE: [30, 31, 32, 33, 34] - dokładnie wartości mz dla każdego x")
print(f"✅ OTRZYMANE:  {mz_power}")
print(f"✅ ZGODNOŚĆ:   {np.allclose(mz_power, [30, 31, 32, 33, 34])}")
print("=" * 80)

# %%
# 🔍 Sprawdź liczebność okien dla spatial_window=1

n_x = 3761  # Z Twoich danych
window_size = 1
step = 1

# Formuła z kodu
n_windows = (n_x - window_size) // step + 1

print("=" * 80)
print("🔍 ANALIZA: spatial_window=1, spatial_step=1")
print("=" * 80)
print(f"\nLiczba punktów x: {n_x}")
print(f"Rozmiar okna:     {window_size}")
print(f"Krok:             {step}")
print(f"\n📊 Liczba okien:  {n_windows}")
print(f"   (wzór: (n_x - window_size) // step + 1)")
print(f"   = ({n_x} - {window_size}) // {step} + 1")
print(f"   = {n_x - window_size} + 1")
print(f"   = {n_windows}")

print(f"\n💡 Oczekiwane: {n_x} okien (jedno dla każdego x)")
print(f"✅ Otrzymane:  {n_windows} okien")
print(f"\n{'✅ ZGADZA SIĘ!' if n_windows == n_x else '❌ NIEZGODNOŚĆ!'}")

# Pozycje środków okien
window_starts = np.arange(0, n_x - window_size + 1, step)
print(f"\nPierwsze 10 pozycji startowych okien: {window_starts[:10]}")
print(f"Ostatnie 5 pozycji startowych okien:  {window_starts[-5:]}")
print(f"Środki okien (start + window_size//2):")
print(f"  Pierwsze 10: {window_starts[:10] + window_size//2}")
print(f"  Ostatnie 5:  {window_starts[-5:] + window_size//2}")

print("\n" + "=" * 80)
print("🎯 WNIOSEK:")
print("=" * 80)
print(f"Dla window_size=1, step=1:")
print(f"  - Mamy {n_windows} okien dla {n_x} punktów x")
print(f"  - Każde okno zawiera DOKŁADNIE 1 punkt")
print(f"  - Środki okien to pozycje: [0, 1, 2, ..., {n_x-1}]")
print(f"  - To jest IDENTYCZNE z prostym FFT dla każdego x osobno!")
print("=" * 80)

# %% [markdown]
# ## 🧪 TEST KRYTYCZNY: Porównanie spatial_window=1 vs prosta FFT
#
# **Hipoteza:** Dla `spatial_window=1, spatial_step=1` wynik powinien być **IDENTYCZNY** jak:
# ```python
# # Prosta pętla po x
# for x_idx in range(n_x):
#     fft_at_x = rfft(data[:, 0, 0, x_idx, 2])  # tylko mz, y=0, z=0
#     power_at_x = abs(fft_at_x)**2
# ```
#
# Sprawdźmy!

# %%
# 🔬 Porównanie: Metoda 1 (spatial_window=1) vs Metoda 2 (prosta pętla)
import numpy as np
import mmpp

# Załaduj dane
job = mmpp.MMPP(zarr_path, debug=True)
data = job[0].m_layer[:, 0, 0, :, :]  # (n_t, n_x, 3) - tylko z=0, y=0

print("=" * 80)
print("🔬 KRYTYCZNY TEST PORÓWNAWCZY")
print("=" * 80)
print(f"Dane: shape {data.shape}")
print(f"      (n_t={data.shape[0]}, n_x={data.shape[1]}, n_comp={data.shape[2]})")

# METODA 1: Używając transmission z spatial_window=1
print("\n📊 METODA 1: transmission(spatial_window=1, spatial_step=1)...")
result_window1 = job[0].m_layer[:, ...].fft.transmission(
    filter_type=None,
    window_function=None,
    spatial_window=1,       # 🔑 KLUCZOWE: okno = 1 punkt
    spatial_step=1,
    average_mode="none",
    component_weights=(0, 0, 1),  # Tylko mz
    normalize="none",
    use_cache=False,
)

power_method1 = result_window1.power_map  # (n_freq, n_windows)
print(f"✅ Wynik: shape {power_method1.shape}")

# METODA 2: Prosta pętla po x (referencja)
print("\n📊 METODA 2: Prosta pętla FFT dla każdego x...")
n_x = data.shape[1]
mz_data = data[:, :, 2]  # Tylko komponent mz: (n_t, n_x)

# FFT dla każdego x
power_method2 = []
for x_idx in range(n_x):
    mz_at_x = mz_data[:, x_idx]  # (n_t,)
    fft_at_x = np.fft.rfft(mz_at_x)  # (n_freq,)
    power_at_x = np.abs(fft_at_x) ** 2
    power_method2.append(power_at_x)

power_method2 = np.array(power_method2).T  # (n_freq, n_x)
print(f"✅ Wynik: shape {power_method2.shape}")

# PORÓWNANIE
print("\n" + "=" * 80)
print("🔍 PORÓWNANIE WYNIKÓW")
print("=" * 80)

print(f"\nShape:")
print(f"  Metoda 1 (window=1): {power_method1.shape}")
print(f"  Metoda 2 (pętla):    {power_method2.shape}")

if power_method1.shape != power_method2.shape:
    print(f"\n❌ BŁĄD: Różne shape!")
    print(f"   Oczekiwane: {power_method2.shape}")
    print(f"   Otrzymane:  {power_method1.shape}")
else:
    # Porównaj wartości
    diff = np.abs(power_method1 - power_method2)
    max_diff = diff.max()
    mean_diff = diff.mean()
    rel_diff = diff / (np.abs(power_method2) + 1e-15)
    max_rel_diff = rel_diff.max()
    
    print(f"\n📈 Statystyki różnicy:")
    print(f"  Max różnica bezwzględna:  {max_diff:.2e}")
    print(f"  Średnia różnica:          {mean_diff:.2e}")
    print(f"  Max różnica względna:     {max_rel_diff:.2e}")
    
    # Sprawdź czy są identyczne (z tolerancją numeryczną)
    are_close = np.allclose(power_method1, power_method2, rtol=1e-10, atol=1e-15)
    
    print(f"\n{'✅ SUKCES' if are_close else '❌ BŁĄD'}:")
    if are_close:
        print("  Wyniki są IDENTYCZNE (w granicach tolerancji numerycznej)!")
        print("  spatial_window=1 działa poprawnie!")
    else:
        print("  Wyniki SIĘ RÓŻNIĄ!")
        print("  Znaleziono bug w implementacji!")
        
        # Pokaż przykłady różnic
        print(f"\n  Przykładowe różnice (pierwsze 5 freq, pierwsze 5 x):")
        print(f"  Metoda 1:\n{power_method1[:5, :5]}")
        print(f"  Metoda 2:\n{power_method2[:5, :5]}")
        print(f"  Różnica:\n{diff[:5, :5]}")

print("=" * 80)

# %% [markdown]
# ### 🎓 Dlaczego spatial_window=1 powinno dać identyczny wynik?
#
# **Matematyka:**
#
# Dla `spatial_window=1, spatial_step=1`:
#
# 1. **Liczba okien:**
#    ```
#    n_windows = (n_x - 1) // 1 + 1 = n_x - 1 + 1 = n_x
#    ```
#    → Mamy **dokładnie n_x okien** (jedno dla każdego punktu x)
#
# 2. **Zawartość każdego okna:**
#    ```
#    Okno 0: data[:, x=0, mz]  → 1 punkt
#    Okno 1: data[:, x=1, mz]  → 1 punkt
#    ...
#    Okno k: data[:, x=k, mz]  → 1 punkt
#    ```
#
# 3. **FFT dla okna k:**
#    ```python
#    # W kodzie transmission:
#    spectrum_k = FFT(data[:, x=k, mz])  # FFT po czasie
#    power_k = mean(abs(spectrum_k)**2)   # mean po 1 punkcie = sam punkt
#
#    # W prostej pętli:
#    spectrum_k = FFT(data[:, x=k, mz])  # FFT po czasie
#    power_k = abs(spectrum_k)**2
#    ```
#
# 4. **Wynik:**
#    ```
#    power_map[:, k] = power_k  (dla każdego k = 0, 1, ..., n_x-1)
#    ```
#
# **Wniosek:**
# - Dla `window=1` nie ma uśredniania przestrzennego (tylko 1 punkt!)
# - Każde okno = pojedynczy punkt x
# - FFT dla okna k = FFT dla punktu x=k
# - **Wyniki MUSZĄ być identyczne!**
#
# ---
#
# **Jeśli wyniki się różnią, to błąd może być w:**
# 1. ❌ Indeksowaniu okien (np. błąd off-by-one)
# 2. ❌ Aplikowaniu window_function mimo window=1
# 3. ❌ Uśrednianiu po złej osi
# 4. ❌ Błędzie w liczbie okien

# %% [markdown]
# ## 🐛 ZNALEZIONY BUG: Błędne skalowanie częstotliwości!
#
# **Problem:** Częstotliwości są źle liczone w transmission!
#
# **Kod w `compute_fft.py` (linia 764):**
# ```python
# dt = job.attrs.get("t_sampl", 1e-12)  # ❌ Domyślnie 1 ps!
# ```
#
# **Potencjalne przyczyny:**
# 1. `t_sampl` nie istnieje w atrybutach zarr
# 2. `t_sampl` ma złą wartość
# 3. Nazwa atrybutu jest inna (np. `dt`, `time_step`, itp.)
#
# **Konsekwencja:**
# ```python
# # W transmission/compute.py (linia 397-400):
# freqs = np.fft.rfftfreq(n_time, d=dt)
#
# # Jeśli dt jest źle, to freqs też będzie źle!
# ```

# %%
# 🔍 DIAGNOZA: Sprawdź dt w zarr vs dt używane przez transmission

import numpy as np
import zarr

print("=" * 80)
print("🔍 DIAGNOZA: Skalowanie częstotliwości")
print("=" * 80)

# 1. Sprawdź dt z zarr
z_root = zarr.open(zarr_path, mode='r')
print(f"\n📁 Zarr attributes:")
print(f"   Available attrs: {list(z_root.attrs.keys())}")

dt_from_zarr = z_root.attrs.get('t_sampl', None)
print(f"\n⏱️  dt z zarr attrs['t_sampl']: {dt_from_zarr}")

# 2. Sprawdź dt z job.t_sampl
dt_from_job = job[0].t_sampl
print(f"⏱️  dt z job[0].t_sampl:       {dt_from_job}")

# %%
print(job[0].attrs['t_sampl'])
print(job[0].t_sampl)

# %% [markdown]
# ## ✅ NAPRAWA: Poprawne pobieranie dt z dataset.attrs
#
# **Błąd (PRZED):**
# ```python
# # mmpp/fft/compute_fft.py, linia 764
# dt = job.attrs.get("t_sampl", 1e-12)  # ❌ Główny zarr attrs
# ```
# - Pobierało `t_sampl` z **głównego zarr** → `9.09e-11` ❌
# - Powinno pobierać z **konkretnego datasetu** → `7.14e-11` ✅
#
# **Naprawa (PO):**
# ```python
# # Priorytet: data_set.attrs > job.attrs > default
# if hasattr(data_set, 'attrs') and 't_sampl' in data_set.attrs:
#     dt = data_set.attrs['t_sampl']  # ✅ Dataset-specific!
# elif hasattr(job, 'attrs') and 't_sampl' in job.attrs:
#     dt = job.attrs['t_sampl']       # Fallback
# else:
#     dt = 1e-12                      # Default
# ```
#
# **Skutek:** Częstotliwości będą teraz poprawnie skalowane!

# %%
# 🔄 TEST: Przeładuj moduł i przelicz transmission z poprawnymi częstotliwościami

import sys
modules_to_remove = [key for key in sys.modules.keys() if key.startswith('mmpp')]
for module in modules_to_remove:
    del sys.modules[module]

print(f"✅ Usunięto {len(modules_to_remove)} modułów MMPP (z poprawką dt!)\n")

import mmpp
import numpy as np

# Załaduj dane
job = mmpp.MMPP(zarr_path, debug=True)

print("=" * 80)
print("🧪 TEST: Transmission z POPRAWNYMI częstotliwościami")
print("=" * 80)

# Oblicz transmission z naprawionym kodem
result_fixed = job[0].m_layer[:, ...].fft.transmission(
    filter_type=None,
    window_function=None,
    spatial_window=200,
    spatial_step=1,
    average_mode="none",
    component_weights=(0, 0, 1),  # Tylko mz
    normalize="none",
    use_cache=False,
)

print(f"\n📊 Wynik:")
print(f"   Shape: {result_fixed.power_map.shape}")
print(f"   Frequencies: {len(result_fixed.frequencies)} punktów")

# Porównaj z ręcznie obliczonymi częstotliwościami
dane = job[0].m_layer[:, 0, 0, :, :]
n_t = dane.shape[0]
dt_correct = job[0].t_sampl

freqs_manual = np.fft.rfftfreq(n_t, dt_correct)

print(f"\n🔍 Porównanie częstotliwości:")
print(f"   dt używane:      {dt_correct:.3e}")
print(f"   ")
print(f"   Ręczne obliczenia:")
print(f"      Min:  {freqs_manual.min()/1e9:.4f} GHz")
print(f"      Max:  {freqs_manual.max()/1e9:.4f} GHz")
print(f"      Δf:   {(freqs_manual[1]-freqs_manual[0])/1e9:.6f} GHz")
print(f"   ")
print(f"   Transmission result:")
print(f"      Min:  {result_fixed.frequencies.min():.4f} GHz")
print(f"      Max:  {result_fixed.frequencies.max():.4f} GHz")
print(f"      Δf:   {(result_fixed.frequencies[1]-result_fixed.frequencies[0]):.6f} GHz")

# Sprawdź czy są identyczne
are_identical = np.allclose(result_fixed.frequencies * 1e9, freqs_manual, rtol=1e-10)

print(f"\n{'✅ SUKCES' if are_identical else '❌ WCIĄŻ BŁĄD'}!")
if are_identical:
    print("   Częstotliwości są POPRAWNE!")
    print("   Bug został naprawiony! 🎉")
else:
    print("   Częstotliwości WCIĄŻ są błędne...")
    print("   Potrzebne dalsze debugowanie.")
    
    # Pokaż różnice
    diff = result_fixed.frequencies * 1e9 - freqs_manual
    print(f"   Max różnica: {diff.max():.3e} Hz")

print("=" * 80)

# %% [markdown]
# ## 🔍 Sprawdź: Czy dispersion ma TEN SAM problem z dt?
#
# **Hipoteza:** Dispersion też używa `zarr_file.attrs['t_sampl']` zamiast `dataset.attrs['t_sampl']`
#
# Sprawdźmy w kodzie:
# ```python
# # mmpp/fft/dispersion/core.py, linie 295-303
# attrs = dict(self.zarr_file.attrs)  # ❌ Główny zarr!
# dt_keys = ['t_sampl', 'dt', 'Dt', 'timestep', 'time_step']
# for key in dt_keys:
#     if key in attrs:
#         self.dt = float(attrs[key])  # ❌ 9.09e-11 zamiast 7.14e-11!
# ```
#
# **To samo co transmission!** 🐛

# %%
# 🔬 TEST: Sprawdź dt używane przez dispersion

import zarr
import numpy as np

print("=" * 80)
print("🔬 DIAGNOZA: dt w dispersion")
print("=" * 80)

# Sprawdź co używa dispersion
z_root = zarr.open(zarr_path, mode='r')

print(f"\n📁 Główny zarr.attrs['t_sampl']: {z_root.attrs.get('t_sampl', 'BRAK')}")
print(f"📁 Dataset m_layer.attrs['t_sampl']: {z_root['m_layer'].attrs.get('t_sampl', 'BRAK')}")

# Sprawdź dt w disp_result
print(f"\n🔍 Dispersion result:")
print(f"   Czy ma atrybut 'dt': {hasattr(disp_result, 'dt')}")

if hasattr(disp_result, 'dt'):
    print(f"   dt: {disp_result.dt}")
else:
    # Spróbuj wywnioskować z frequency
    if len(disp_result.frequency) > 1:
        df = disp_result.frequency[1] - disp_result.frequency[0]
        n_freq = len(disp_result.frequency)
        # f_max = 1 / (2 * dt)  →  dt = 1 / (2 * f_max)
        # Dla rfft: f_max ≈ N_freq * df
        f_max_approx = n_freq * df
        dt_inferred = 1 / (2 * f_max_approx)
        print(f"   dt wywnioskowane z frequency: {dt_inferred:.3e}")

# Porównaj częstotliwości
n_t = job[0].m_layer[:, 0, 0, 0, 0].shape[0]  # Liczba kroków czasowych
dt_correct = job[0].t_sampl

freqs_manual = np.fft.rfftfreq(n_t, dt_correct)
freqs_wrong = np.fft.rfftfreq(n_t, z_root.attrs['t_sampl'])

print(f"\n📊 Porównanie częstotliwości:")
print(f"   Poprawne (job[0].t_sampl = {dt_correct:.3e}):")
print(f"      Max freq: {freqs_manual.max()/1e9:.4f} GHz")
print(f"   ")
print(f"   Błędne (zarr.attrs['t_sampl'] = {z_root.attrs['t_sampl']:.3e}):")
print(f"      Max freq: {freqs_wrong.max()/1e9:.4f} GHz")
print(f"   ")
print(f"   Dispersion result:")
print(f"      Max freq: {disp_result.frequency.max()/1e9:.4f} GHz")

# Sprawdź z którym się zgadza
is_correct = np.isclose(disp_result.frequency.max(), freqs_manual.max(), rtol=1e-6)
is_wrong = np.isclose(disp_result.frequency.max(), freqs_wrong.max(), rtol=1e-6)

print(f"\n{'✅' if is_correct else '❌'} Dispersion używa POPRAWNEGO dt (job[0].t_sampl)")
print(f"{'✅' if is_wrong else '❌'} Dispersion używa BŁĘDNEGO dt (zarr.attrs['t_sampl'])")

if is_wrong and not is_correct:
    print(f"\n🐛 POTWIERDZONY BUG W DISPERSION!")
    print(f"   Używa dt = {z_root.attrs['t_sampl']:.3e} (z głównego zarr)")
    print(f"   Powinno być dt = {dt_correct:.3e} (z datasetu m_layer)")
    ratio = z_root.attrs['t_sampl'] / dt_correct
    print(f"   Przeskalowanie: {ratio:.2f}×")

print("=" * 80)

# %% [markdown]
# ### 🔧 Naprawa dla dispersion (jeśli potrzebna)
#
# **Jeśli test potwierdzi bug, to trzeba zmienić w `core.py`:**
#
# ```python
# # PRZED (linie 295-313):
# attrs = dict(self.zarr_file.attrs)  # ❌ Główny zarr
# dt_keys = ['t_sampl', 'dt', 'Dt', 'timestep', 'time_step']
# for key in dt_keys:
#     if key in attrs:
#         self.dt = float(attrs[key])
# ```
#
# **PO (naprawa):**
# ```python
# # Próbuj najpierw z datasetu, potem z głównego zarr
# attrs_dataset = dict(self._M_ref.attrs) if self._M_ref is not None else {}
# attrs_global = dict(self.zarr_file.attrs)
#
# dt_keys = ['t_sampl', 'dt', 'Dt', 'timestep', 'time_step']
#
# # Priority: dataset attrs > global attrs
# for key in dt_keys:
#     if key in attrs_dataset:  # ✅ Najpierw dataset!
#         self.dt = float(attrs_dataset[key])
#         logger.info(f"Using dt from dataset.attrs['{key}']: {self.dt}")
#         break
#     elif key in attrs_global:  # Fallback do global
#         self.dt = float(attrs_global[key])
#         logger.warning(f"Using dt from zarr.attrs['{key}']: {self.dt} (dataset-specific not found)")
#         break
# ```

# %% [markdown]
# # Test: Weryfikacja osi X w nanometrach
#
# Sprawdzamy czy oś X jest teraz poprawnie liczona w nm (mnożona przez `dx`).

# %%
# Diagnostyka: sprawdzenie dx i x_positions
print(f"result_raw.dx = {result_raw.dx}")
print(f"job[0].dx = {job[0].dx}")
print(f"First 5 x_positions: {result_raw.x_positions[:5]}")
print(f"Expected first x in nm: 0 * {job[0].dx} = 0")
print(f"Expected second x in nm: 1 * {job[0].dx} = {1 * job[0].dx}")

# %%
# Przeładowanie modułów z poprawkami dx
import importlib
import sys

modules_to_reload = [
    'mmpp.fft.transmission.compute',
    'mmpp.fft.transmission.plot',
    'mmpp.fft.compute_fft',
]

for module_name in modules_to_reload:
    if module_name in sys.modules:
        importlib.reload(sys.modules[module_name])
        print(f"✅ Reloaded: {module_name}")
    else:
        print(f"⚠️  Not loaded yet: {module_name}")

print("\n🔄 Moduły przeładowane! Teraz przelicz transmisję ponownie.")

# %%
# Przelicz transmisję Z NOWYMI POPRAWKAMI
result_with_dx = job[0].m_layer[:200,...].fft.transmission(
    filter_type="remove_static",   # Używamy remove_static (odejmuje pierwszy punkt)
    use_cache=False,                # Wyłączamy cache!
    save=False,
    window_function=None,
    spatial_window=1,
    spatial_step=1,
    average_mode="none",
    component_weights=(0, 0, 1),
    normalize="none",
)

print(f"✅ Transmisja przeliczona!")
print(f"dx = {result_with_dx.dx}")
print(f"Pierwsze 5 pozycji X: {result_with_dx.x_positions[:5]}")
print(f"Oczekiwane (w nm): [0, {job[0].dx}, {2*job[0].dx}, {3*job[0].dx}, {4*job[0].dx}]")

# %%
# Porównanie: stare (indeksy) vs nowe (nm)
import matplotlib.pyplot as plt
from mmpp.fft.transmission.plot import TransmissionPlotConfig

fig, (ax_old, ax_new) = plt.subplots(1, 2, figsize=(16, 6), sharey=True)

# STARY wynik (indeksy)
config_old = TransmissionPlotConfig(
    which="transmission",
    freq_unit="GHz",
    x_unit="index",  # Indeksy
    fmax=3.0,
    trim_0f=5,
)
result_raw.plot(config=config_old, ax=ax_old)
ax_old.set_title("STARY: x w indeksach (przed poprawką)")

# NOWY wynik (nm)
config_new = TransmissionPlotConfig(
    which="transmission",
    freq_unit="GHz",
    x_unit="cell",  # Nanometry
    fmax=3.0,
    trim_0f=5,
)
result_with_dx.plot(config=config_new, ax=ax_new)
ax_new.set_title("NOWY: x w nanometrach (po poprawce)")

plt.tight_layout()
plt.show()

print(f"\n📊 Porównanie:")
print(f"Stary x_positions[0:5] = {result_raw.x_positions[:5]} (indeksy)")
print(f"Nowy x_positions[0:5] = {result_with_dx.x_positions[:5]} (nm)")
print(f"dx = {result_with_dx.dx} nm")

# %%
# DEBUGOWANIE: Sprawdźmy jak dostać się do dx
print("=== Sprawdzanie struktury danych ===")
print(f"type(job) = {type(job)}")
print(f"type(job[0]) = {type(job[0])}")
print(f"job[0].dx = {job[0].dx}")

# Sprawdźmy dataset
dataset_name = job.get_largest_m_dataset()
print(f"\nNajwiększy dataset: {dataset_name}")

# Sprawdźmy różne sposoby dostępu
print("\n=== Testowanie dostępu do dx ===")
try:
    ds = job[dataset_name]
    print(f"job['{dataset_name}'] = {type(ds)}")
    print(f"hasattr(ds, 'dx') = {hasattr(ds, 'dx')}")
    if hasattr(ds, 'dx'):
        print(f"ds.dx = {ds.dx}")
    print(f"hasattr(ds, 'attrs') = {hasattr(ds, 'attrs')}")
    if hasattr(ds, 'attrs'):
        print(f"ds.attrs.keys() = {list(ds.attrs.keys())[:10]}")  # Pierwsze 10 kluczy
except Exception as e:
    print(f"ERROR: {e}")

# Sprawdźmy job[0]
print("\n=== Sprawdzanie job[0] ===")
print(f"type(job[0]) = {type(job[0])}")
print(f"dir(job[0]) = {[x for x in dir(job[0]) if 'dx' in x.lower() or 'cell' in x.lower()]}")

# %%
# Przeładuj moduły z nowymi logami
import importlib
import sys

for module_name in ['mmpp.fft.transmission.plot', 'mmpp.fft.transmission.compute']:
    if module_name in sys.modules:
        importlib.reload(sys.modules[module_name])
        print(f"✅ Reloaded: {module_name}")

print("\n🔄 Moduły przeładowane z debug logami!")

# %%
# Test z debug=True
import matplotlib.pyplot as plt
from mmpp.fft.transmission.plot import TransmissionPlotConfig

fig, ax = plt.subplots(figsize=(10, 6))

config = TransmissionPlotConfig(
    which="transmission",
    freq_unit="GHz",
    x_unit="cell",  # Próbujemy nm
    trim_0f=0,
    vmax=3e-8,
    cmap="inferno",
)

print("="*70)
print("🔍 WYWOŁANIE result_raw.plot() Z DEBUG=True")
print("="*70)

result_raw.plot(config=config, ax=ax, debug=True)

plt.show()

# %% [markdown]
# ## 🔧 FIX: Poprawiona funkcja _get_dx()
#
# Teraz używa `job_result[0].dx` zamiast `job_result[dataset_name].dx`

# %%
# RESTART KERNEL I PRZEŁADUJ WSZYSTKO
import importlib
import sys

# Usuń wszystkie moduły mmpp z pamięci
modules_to_remove = [k for k in sys.modules.keys() if k.startswith('mmpp')]
for module in modules_to_remove:
    del sys.modules[module]
    
print(f"✅ Usunięto {len(modules_to_remove)} modułów mmpp z pamięci")
print("🔄 Teraz zaimportuj mmpp ponownie i przelicz transmisję!")

# %%
# Re-import i wczytaj dane
from mmpp.core import MMPP

zarr_path = "/home/kkingstoun/git/mmpp/examples/stripe-domain.zarr"
job = MMPP(zarr_path)

print(f"✅ MMPP załadowany")
print(f"job[0].dx = {job[0].dx} nm")

# %%
# TERAZ PRZELICZ TRANSMISJĘ Z POPRAWIONĄ FUNKCJĄ _get_dx()
result_FINAL = job[0].m_layer[:10,...].fft.transmission(
    filter_type="remove_static",
    use_cache=False,  # ❗ Ważne - wyłącz cache!
    save=False,
    window_function=None,
    spatial_window=1,
    spatial_step=1,
    average_mode="none",
    component_weights=(0, 0, 1),
    normalize="none",
)

print(f"\n{'='*70}")
print(f"✅ TRANSMISJA PRZELICZONA Z POPRAWIONĄ FUNKCJĄ!")
print(f"{'='*70}")
print(f"result_FINAL.dx = {result_FINAL.dx} nm")
print(f"job[0].dx = {job[0].dx} nm")
print(f"Pierwsze 5 x_positions: {result_FINAL.x_positions[:5]}")
print(f"Oczekiwane (w nm): [0, {job[0].dx}, {2*job[0].dx}, {3*job[0].dx}, {4*job[0].dx}]")
print(f"\n{'='*70}")

if result_FINAL.dx is not None:
    print("🎉 SUKCES! dx został znaleziony!")
else:
    print("❌ BŁĄD: dx nadal None")

# %%
# WIZUALIZACJA Z POPRAWIONYMI DANYMI
import matplotlib.pyplot as plt
from mmpp.fft.transmission.plot import TransmissionPlotConfig

fig, ax = plt.subplots(figsize=(12, 6))

config = TransmissionPlotConfig(
    which="transmission",
    freq_unit="GHz",
    x_unit="cell",  # Teraz powinno działać!
    trim_0f=5,
    vmax=3e-8,
    fmax=3.0,
    cmap="inferno",
)

print("="*70)
print("📊 PLOT Z POPRAWIONYMI DANYMI (debug=True)")
print("="*70)

result_FINAL.plot(config=config, ax=ax, debug=True)

plt.tight_layout()
plt.show()

print(f"\n✅ Wykres utworzony! Sprawdź label osi X - powinien być 'x (nm)'")

# %%
# Przeładuj z rozszerzonym debugowaniem
import importlib
import sys

for mod in ['mmpp.fft.transmission.compute', 'mmpp.fft.transmission.interface']:
    if mod in sys.modules:
        importlib.reload(sys.modules[mod])
        print(f"✅ Reloaded: {mod}")

print("\n🔄 Teraz przelicz transmisję ponownie i sprawdź logi!")

# %%
# Test z ROZSZERZONYM DEBUGOWANIEM
result_DEBUG = job[0].m_layer[:200,...].fft.transmission(
    filter_type="remove_static",
    use_cache=False,
    save=False,
    window_function=None,
    spatial_window=1,
    spatial_step=1,
    average_mode="none",
    component_weights=(0, 0, 1),
    normalize="none",
)

print(f"\n{'='*70}")
print(f"result_DEBUG.dx = {result_DEBUG.dx}")
print(f"{'='*70}")
print("\n📋 SPRAWDŹ LOGI POWYŻEJ - powinny być szczegółowe DEBUG messages z _get_dx()")

# %% [markdown]
# ## 🔧 FIX v2: Używamy dataset_name zamiast [0]
#
# Zarr wymaga stringów jako kluczy, nie integerów!

# %%
# Przeładuj z poprawką v2
import importlib
import sys

importlib.reload(sys.modules['mmpp.fft.transmission.compute'])
print("✅ Przeładowano mmpp.fft.transmission.compute")

# %%
# Test FINAL - powinno działać!
result_WORKS = job[0].m_layer[:10,...].fft.transmission(
    filter_type="remove_static",
    use_cache=False,
    save=False,
    window_function=None,
    spatial_window=1,
    spatial_step=1,
    average_mode="none",
    component_weights=(0, 0, 1),
    normalize="none",
)

print(f"\n{'='*70}")
if result_WORKS.dx is not None:
    print(f"🎉 SUKCES! dx = {result_WORKS.dx} m = {result_WORKS.dx * 1e9} nm")
    print(f"x_positions[0:5] = {result_WORKS.x_positions[:5]} (w metrach)")
    print(f"x_positions[0:5] w nm = {result_WORKS.x_positions[:5] * 1e9}")
else:
    print(f"❌ BŁĄD: dx nadal None")
print(f"{'='*70}")

# %% [markdown]
# ## ⚠️ PROBLEM: `result_raw` ma `dx=None`!
#
# Jeśli `result.dx = None`, to `x_positions` są w **indeksach komórek**, nie w metrach!
#
# **Rozwiązanie**:
# - Dla `result_raw` (bez dx): użyj `x = 2000 / dx` (indeks komórki)
# - Dla `result_WORKS` (z dx): użyj `x = 2000e-9` (metry)

# %%
# FIX: Poprawny wykres z uwzględnieniem dx=None vs dx=5e-9

import matplotlib.pyplot as plt

fig, (ax_left, ax_right, ax_third) = plt.subplots(1, 3, figsize=(16, 6), dpi=100, sharey=True)

# Sprawdź dx i oblicz odpowiedni x
if result_raw.dx is not None:
    # dx jest dostępny - x_positions są w metrach
    x_position_m = 2000e-9  # 2000 nm = 2 µm w metrach
    x_index_for_plot = 2000e-9
    print(f"✅ result_raw ma dx={result_raw.dx} → używamy x={x_position_m} m")
else:
    # dx = None - x_positions są w indeksach komórek
    dx_manual = job[0].dx  # Pobierz dx ręcznie
    x_position_nm = 2000  # 2000 nm = 2 µm
    x_index_for_plot = int(x_position_nm * 1e-9 / dx_manual)  # Konwersja nm → indeks
    print(f"⚠️  result_raw ma dx=None → używamy INDEKS x={x_index_for_plot}")
    print(f"   (obliczone: {x_position_nm} nm / {dx_manual*1e9} nm/cell = {x_index_for_plot} cell)")

# Plot crosssection
result_raw.plot_transmission_crosssection(
    ax=ax_third,
    x=x_index_for_plot,  # 🔑 Użyj indeksu lub metrów w zależności od dx
    freq_unit="GHz",
    trim_0f=0,
    color="red",
    flip=True,
    linewidth=2.5,
    log_scale=True,
)

# Plot transmission heatmap
result_raw.plot_transmission(
    ax=ax_right,
    debug=False,
    plot_config={
        "freq_unit": "GHz",
        "trim_0f": 0,
        "vmax": 3e-8,
        "cmap": "inferno",
    }
)

# Dodaj vertikalną linię na prawidłowej pozycji
if result_raw.dx is not None:
    ax_right.axvline(x_position_m, color='white', linestyle='--', linewidth=2, alpha=0.8)
else:
    ax_right.axvline(x_index_for_plot, color='white', linestyle='--', linewidth=2, alpha=0.8)

ax_right.set_ylim(0, 2.75)

# Linie poziome
horizontal_lines = [1.32, 2.21]  # GHz
for freq in horizontal_lines:
    ax_right.axhline(y=freq, color='white', linestyle='--', linewidth=2, alpha=0.8, zorder=10)
    ax_third.axhline(y=freq, color='white', linestyle='--', linewidth=1, alpha=0.6, zorder=10)
    
    ax_right.text(ax_right.get_xlim()[1] * 0.98, freq, f'{freq} GHz', 
                  color='white', fontsize=10, fontweight='bold',
                  ha='right', va='bottom', 
                  bbox=dict(boxstyle='round,pad=0.3', facecolor='black', alpha=0.5))

plt.tight_layout()
plt.show()

print(f"\n📊 Wykres utworzony!")

# %% [markdown]
# ## 🎯 FINALNE ROZWIĄZANIE
#
# Przeliczmy transmisję z **poprawionym kodem**, żeby mieć `dx` i wszystko działało automatycznie!

# %%
# Przelicz transmisję Z POPRAWIONĄ FUNKCJĄ _get_dx()
result_NEW = job[0].m_layer[:200,...].fft.transmission(
    filter_type="remove_static",
    use_cache=False,  # ❗ Wyłącz cache!
    save=False,
    window_function=None,
    spatial_window=1,
    spatial_step=1,
    average_mode="none",
    component_weights=(0, 0, 1),
    normalize="none",
)

print(f"{'='*70}")
print(f"NOWY WYNIK Z POPRAWIONĄ FUNKCJĄ _get_dx():")
print(f"{'='*70}")
print(f"result_NEW.dx = {result_NEW.dx}")
print(f"job[0].dx = {job[0].dx}")

if result_NEW.dx is not None:
    print(f"✅ SUKCES! dx znaleziony!")
    print(f"   dx = {result_NEW.dx} m = {result_NEW.dx * 1e9} nm")
    print(f"   x_positions[0:5] = {result_NEW.x_positions[:5]} m")
    print(f"   x_positions[0:5] = {result_NEW.x_positions[:5] * 1e9} nm")
else:
    print(f"❌ BŁĄD: dx nadal None - sprawdź logi DEBUG powyżej!")
print(f"{'='*70}")

# %% [markdown]
# # 🐛 FIX: Component Selection via Slicing
#
# ## Problem:
# Gdy używałeś `mlayer[:,...,2]` (wybór komponentu z), kod mylił wymiary:
# - Dane: `(981, 10, 94, 4700, 3)` → po slice `[:,...,2]` → `(981, 10, 94, 4700)`
# - Kod traktował to jako `(t, y, x, comp)` zamiast `(t, z, y, x)`
# - Wynik: **4700 x-punktów** było interpretowane jako **4700 komponentów**!
#
# ## Rozwiązanie:
# Kod teraz wykrywa czy komponent był wybrany via slicing:
# 1. Sprawdza czy ostatni element `slice_info` to integer (np. `2`)
# 2. Jeśli tak, traktuje 4D dane jako `(t, z, y, x)` (component już wybrany)
# 3. Po selekcji z-layer, dodaje axis komponentu z powrotem: `(t, z, y, x)` → `(t, z, y, x, 1)`

# %%
# 🧪 TEST: Transmisja z component selection [:,...,2]

# Przeładuj moduł MMPP
import sys
modules_to_remove = [name for name in sys.modules if name.startswith('mmpp')]
for module in modules_to_remove:
    del sys.modules[module]
import mmpp

job = mmpp.MMPP("/mnt/storage_2/scratch/pl0095-01/zelent/mannga/ksob/YIG_CoFeB_resonators_matrix/CoFeB_d_180nm_p_630nm_La_5um_ant_05um_YIG_70nm_fcut_4GHz_cz_5nm/comsol_verify/transmission/transmission_k_szulc_parameters8mt_v13_olek_long.zarr",debug=True)

print("=" * 80)
print("TEST: Component selection via slicing")
print("=" * 80)
print(f"\nDataset shape: {job[0].mlayer.shape}")
print("Dimensions: (t, z, y, x, components)")
print(f"  t={job[0].mlayer.shape[0]} timesteps")
print(f"  z={job[0].mlayer.shape[1]} layers")
print(f"  y={job[0].mlayer.shape[2]} y-points")
print(f"  x={job[0].mlayer.shape[3]} x-points")
print(f"  components={job[0].mlayer.shape[4]} (mx, my, mz)")
print()
print("🔍 Używam slicingu [:,...,2] aby wybrać TYLKO mz (komponent z)")
print()

# KLUCZOWY TEST: [:,...,2] wybiera komponent z
result_component_selected = job[0].mlayer[:,...,2].fft.transmission(
    filter_type=["remove_mean", "remove_static"],
    use_cache=False,
    save=False,
    window_function=None,
    spatial_window=1,
    spatial_step=1,
    average_mode="none",
    component_weights=(0, 0, 1),  # To będzie ignorowane bo komponent już wybrany
    normalize="none",
)

print("\n" + "=" * 80)
print("📊 WYNIK:")
print("=" * 80)
print(f"Transmission shape: {result_component_selected.transmission.shape}")
print(f"  n_frequencies={result_component_selected.transmission.shape[0]}")
print(f"  n_x_positions={result_component_selected.transmission.shape[1]}")
print()
print(f"❌ PRZED FIXEM było:     (491, 94)  - BŁĄD! (4700 x-punktów → 94)")
print(f"✅ PO FIXIE powinno być: (491, 4700) - POPRAWNE!")
print()
if result_component_selected.transmission.shape[1] == 4700:
    print("✅✅✅ FIX DZIAŁA! Wszystkie 4700 x-punktów zachowane!")
elif result_component_selected.transmission.shape[1] == 94:
    print("❌❌❌ FIX NIE DZIAŁA! Wciąż mylą się wymiary!")
else:
    print(f"⚠️  Nieoczekiwany wymiar: {result_component_selected.transmission.shape[1]}")
print("=" * 80)

# %% [markdown]
# # 🐛 FIX 2: Component Weights gdy komponent jest pre-selected
#
# ## Problem:
# 1. Użytkownik wybiera komponent: `mlayer[:,...,2]` → tylko mz (n_comp=1)
# 2. Użytkownik ustawia `component_weights=(0, 0, 1)` → dla 3 komponentów
# 3. Kod przycina weights do n_comp: `[0, 0, 1][:1]` → `[0]`
# 4. Weight=0 → **WSZYSTKIE ZERA w transmisji**!
#
# ## Rozwiązanie:
# Gdy komponent jest już wybrany przez slicing (`n_comp=1`), automatycznie ustaw `component_weights=(1,)` (ignoruj user input).
#
# Logika: "Jeśli wybrałeś komponent przez slicing, to chcesz użyć tego komponentu, nie ma sensu dawać mu wagę 0!"

# %%
# 🧪 TEST FIX 2: Component weights auto-override

# Przeładuj moduł MMPP
import sys
modules_to_remove = [name for name in sys.modules if name.startswith('mmpp')]
for module in modules_to_remove:
    del sys.modules[module]
import mmpp

job = mmpp.MMPP("/mnt/storage_2/scratch/pl0095-01/zelent/mannga/ksob/YIG_CoFeB_resonators_matrix/CoFeB_d_180nm_p_630nm_La_5um_ant_05um_YIG_70nm_fcut_4GHz_cz_5nm/comsol_verify/transmission/transmission_k_szulc_parameters8mt_v13_olek_long.zarr",debug=True)

print("=" * 80)
print("TEST: Component weights gdy komponent pre-selected")
print("=" * 80)
print()
print("🔍 Slicing: mlayer[:,...,2] → wybiera TYLKO komponent mz (n_comp=1)")
print("🔍 component_weights=(0, 0, 1) → teoretycznie dla 3 komponentów")
print("🔑 Oczekiwane: Kod auto-override do component_weights=(1,)")
print()

result_fixed = job[0].mlayer[:,...,2].fft.transmission(
    filter_type=["remove_mean", "remove_static"],
    use_cache=False,
    save=False,
    window_function=None,
    spatial_window=1,
    spatial_step=1,
    average_mode="none",
    component_weights=(0, 0, 1),  # 🔑 To zostanie ZIGNOROWANE!
    normalize="none",
)

print("\n" + "=" * 80)
print("📊 WYNIK:")
print("=" * 80)
print(f"Transmission shape: {result_fixed.transmission.shape}")
print(f"Min value: {result_fixed.transmission.min():.6e}")
print(f"Max value: {result_fixed.transmission.max():.6e}")
print(f"Mean value: {result_fixed.transmission.mean():.6e}")
print()

if result_fixed.transmission.max() > 0:
    print("✅✅✅ FIX DZIAŁA! Transmission ma niezerowe wartości!")
    print(f"   Największa wartość: {result_fixed.transmission.max():.6e}")
else:
    print("❌❌❌ FIX NIE DZIAŁA! Wciąż same zera!")
    
print("=" * 80)
print()
print("💡 Sprawdź logi powyżej - powinno być:")
print("   'Component pre-selected via slicing → auto-setting component_weights=(1,)'")
print("=" * 80)

# %% [markdown]
# # 🔍 DIAGNOZA: Dlaczego biblioteka daje słabe niskie częstotliwości?
#
# ## Porównanie: Twój prosty kod vs biblioteka
#
# ### 🟢 Twój prosty kod:
# ```python
# dane = job[0].mlayer[:2000, 0, 0, :, 2].numpy()  # (t, x)
# dane2 = dane - dane.mean(axis=0)                 # Remove mean per x
# fft = np.fft.rfft(dane2, axis=0)                 # FFT po czasie
# ```
#
# ### 🔴 Biblioteka - co robi INACZEJ?
#
# Sprawdźmy różnice krok po kroku...

# %%
# 🔬 DIAGNOZA KROK 1: Sprawdź co robi biblioteka z filtrami

import sys
modules_to_remove = [name for name in sys.modules if name.startswith('mmpp')]
for module in modules_to_remove:
    del sys.modules[module]
import mmpp
import numpy as np

job = mmpp.MMPP("/mnt/storage_2/scratch/pl0095-01/zelent/mannga/ksob/YIG_CoFeB_resonators_matrix/CoFeB_d_180nm_p_630nm_La_5um_ant_05um_YIG_70nm_fcut_4GHz_cz_5nm/comsol_verify/transmission/transmission_k_szulc_parameters8mt_v13_olek_long.zarr", debug=True)

print("=" * 80)
print("DIAGNOZA: Różnice w przetwarzaniu danych")
print("=" * 80)

# === TWÓJ PROSTY KOD ===
print("\n🟢 TWÓJ PROSTY KOD:")
print("-" * 80)
dane_raw = job[0].mlayer[:2000, 0, 0, :, 2].numpy()  # (t, x)
print(f"1. Dane surowe: shape={dane_raw.shape}")
print(f"   min={dane_raw.min():.6e}, max={dane_raw.max():.6e}, mean={dane_raw.mean():.6e}")

dane_filtered = dane_raw - dane_raw.mean(axis=0)  # Remove mean per x
print(f"2. Po usunięciu średniej (axis=0): ")
print(f"   min={dane_filtered.min():.6e}, max={dane_filtered.max():.6e}, mean={dane_filtered.mean():.6e}")

fft_simple = np.fft.rfft(dane_filtered, axis=0)
print(f"3. FFT: shape={fft_simple.shape}")
power_simple = np.abs(fft_simple)**2
print(f"   Power: min={power_simple.min():.6e}, max={power_simple.max():.6e}")
print(f"   Power[0] (DC): {power_simple[0, :].mean():.6e}")
print(f"   Power[10]: {power_simple[10, :].mean():.6e}")
print(f"   Power[100]: {power_simple[100, :].mean():.6e}")

# === BIBLIOTEKA Z DEBUGIEM ===
print("\n🔴 BIBLIOTEKA (filter_type=['remove_mean', 'remove_static']):")
print("-" * 80)

# Załaduj dane tak jak biblioteka
from mmpp.fft.compute_fft import FFTCompute
fft_compute = FFTCompute(debug=True)

data_lib, dt = fft_compute.load_data_from_zarr(
    job.path,
    dataset='mlayer',
    z_layer=0,  # Weź pierwszą warstwę z
    tmax=2000,
    slice_info=(slice(None, 2000), Ellipsis, 2),  # [:2000, ..., 2]
)
print(f"1. Po load_data_from_zarr: shape={data_lib.shape}")
print(f"   min={data_lib.min():.6e}, max={data_lib.max():.6e}, mean={data_lib.mean():.6e}")

# Zastosuj filtry jak biblioteka
filtered_lib = fft_compute.apply_filter(data_lib, ['remove_mean', 'remove_static'])
print(f"2. Po filtrach ['remove_mean', 'remove_static']: shape={filtered_lib.shape}")
print(f"   min={filtered_lib.min():.6e}, max={filtered_lib.max():.6e}, mean={filtered_lib.mean():.6e}")

# FFT
fft_lib = np.fft.rfft(filtered_lib, axis=0)
power_lib = np.abs(fft_lib)**2

# Weź tylko y=0, x-all dla porównania
if power_lib.ndim == 5:  # (freq, z, y, x, comp)
    power_lib_2d = power_lib[:, 0, 0, :, 0]  # (freq, x)
elif power_lib.ndim == 4:  # (freq, y, x, comp)
    power_lib_2d = power_lib[:, 0, :, 0]  # (freq, x)
else:
    power_lib_2d = power_lib  # już 2D?

print(f"3. FFT (biblioteka): shape={fft_lib.shape} → 2D: {power_lib_2d.shape}")
print(f"   Power: min={power_lib_2d.min():.6e}, max={power_lib_2d.max():.6e}")
print(f"   Power[0] (DC): {power_lib_2d[0, :].mean():.6e}")
print(f"   Power[10]: {power_lib_2d[10, :].mean():.6e}")
print(f"   Power[100]: {power_lib_2d[100, :].mean():.6e}")

# === PORÓWNANIE ===
print("\n" + "=" * 80)
print("📊 PORÓWNANIE:")
print("=" * 80)
print(f"{'Częstotliwość':<20} {'Twój kod':<20} {'Biblioteka':<20} {'Stosunek':<15}")
print("-" * 80)
for idx in [0, 5, 10, 20, 50, 100]:
    simple_val = power_simple[idx, :].mean()
    lib_val = power_lib_2d[idx, :].mean()
    ratio = simple_val / lib_val if lib_val > 0 else float('inf')
    print(f"f[{idx}]  {simple_val:>18.6e}  {lib_val:>18.6e}  {ratio:>13.2f}x")
print("=" * 80)

# %% [markdown]
# # 🔍 DIAGNOZA KROK 2: Szczegóły filtrów
#
# ## Sprawdźmy co dokładnie robią filtry:
#
# ### 1. `remove_mean` - usuwa średnią
# ```python
# data - np.mean(data, axis=0)
# ```
# **Efekt**: Usuwa DC component (f=0) - DOBRZE dla FFT
#
# ### 2. `remove_static` - usuwa komponent statyczny
# ```python
# data - data[0, ...]  # Odejmij pierwszy timestep!
# ```
# **⚠️ UWAGA**: To może osłabiać niskie częstotliwości!
#
# ### Podejrzenie:
# `remove_static` odejmuje `data[0]`, co może wprowadzać **step function** na początku sygnału.
# Step function ma silne komponenty niskich częstotliwości, które mogą się ODEJMOWAĆ od prawdziwego sygnału!

# %%
# 🧪 TEST: Porównaj różne strategie filtrowania

import numpy as np
import matplotlib.pyplot as plt

# Załaduj dane raz
dane_raw = job[0].mlayer[:2000, 0, 0, :1000, 2].numpy()  # (t, x) - weź mniej x dla szybkości

print("=" * 80)
print("PORÓWNANIE STRATEGII FILTROWANIA")
print("=" * 80)
print(f"\nDane: shape={dane_raw.shape}")

# === STRATEGIA 1: Tylko remove_mean (jak Twój kod) ===
dane1 = dane_raw - dane_raw.mean(axis=0)
fft1 = np.fft.rfft(dane1, axis=0)
power1 = np.abs(fft1)**2

print("\n1️⃣ Tylko remove_mean (Twój sposób):")
print(f"   Power[0]: {power1[0, :].mean():.6e}")
print(f"   Power[10]: {power1[10, :].mean():.6e}")
print(f"   Power[100]: {power1[100, :].mean():.6e}")

# === STRATEGIA 2: remove_mean + remove_static ===
dane2 = dane_raw - dane_raw.mean(axis=0)  # remove_mean
dane2 = dane2 - dane2[0, ...]             # remove_static
fft2 = np.fft.rfft(dane2, axis=0)
power2 = np.abs(fft2)**2

print("\n2️⃣ remove_mean + remove_static (biblioteka):")
print(f"   Power[0]: {power2[0, :].mean():.6e}")
print(f"   Power[10]: {power2[10, :].mean():.6e}")
print(f"   Power[100]: {power2[100, :].mean():.6e}")

# === STRATEGIA 3: Tylko remove_static ===
dane3 = dane_raw - dane_raw[0, ...]
fft3 = np.fft.rfft(dane3, axis=0)
power3 = np.abs(fft3)**2

print("\n3️⃣ Tylko remove_static:")
print(f"   Power[0]: {power3[0, :].mean():.6e}")
print(f"   Power[10]: {power3[10, :].mean():.6e}")
print(f"   Power[100]: {power3[100, :].mean():.6e}")

# === WIZUALIZACJA ===
fig, axes = plt.subplots(2, 2, figsize=(16, 10), dpi=100)

freqs = np.fft.rfftfreq(dane_raw.shape[0], job[0].sampling_interval)

# Wykres 1: Spektra mocy średniej po x
ax = axes[0, 0]
ax.plot(freqs[:200]/1e9, power1[:200, :].mean(axis=1), label='remove_mean (Twój)', linewidth=2)
ax.plot(freqs[:200]/1e9, power2[:200, :].mean(axis=1), label='remove_mean+static (biblio)', linewidth=2)
ax.set_xlabel('Frequency (GHz)')
ax.set_ylabel('Power')
ax.set_title('Porównanie strategii - niskie częstotliwości')
ax.legend()
ax.grid(True, alpha=0.3)
ax.set_yscale('log')

# Wykres 2: Stosunek power
ax = axes[0, 1]
ratio = power1[:200, :].mean(axis=1) / (power2[:200, :].mean(axis=1) + 1e-20)
ax.plot(freqs[:200]/1e9, ratio, linewidth=2, color='red')
ax.axhline(1, color='black', linestyle='--', alpha=0.5)
ax.set_xlabel('Frequency (GHz)')
ax.set_ylabel('Stosunek: Twój / Biblioteka')
ax.set_title('O ile Twój kod ma WIĘCEJ mocy')
ax.grid(True, alpha=0.3)
ax.set_yscale('log')

# Wykres 3: Dane po remove_mean
ax = axes[1, 0]
ax.plot(dane1[:500, 0], label='remove_mean', linewidth=1.5)
ax.plot(dane2[:500, 0], label='remove_mean+static', linewidth=1.5, alpha=0.7)
ax.set_xlabel('Time step')
ax.set_ylabel('Magnetization')
ax.set_title('Sygnał czasowy (pierwsze 500 kroków, x=0)')
ax.legend()
ax.grid(True, alpha=0.3)

# Wykres 4: Różnica w sygnale
ax = axes[1, 1]
diff = dane1[:500, 0] - dane2[:500, 0]
ax.plot(diff, linewidth=2, color='red')
ax.set_xlabel('Time step')
ax.set_ylabel('Różnica')
ax.set_title('Różnica: remove_mean - (remove_mean+static)')
ax.grid(True, alpha=0.3)
ax.axhline(0, color='black', linestyle='--', alpha=0.5)

plt.tight_layout()
plt.show()

print("\n" + "=" * 80)
print("📊 WNIOSKI:")
print("=" * 80)
print("Sprawdź wykresy powyżej!")
print("Jeśli stosunek >> 1 dla niskich f, to remove_static OSŁABIA niskie częstotliwości!")
print("=" * 80)

# %% [markdown]
# # 🔬 ZNALEZIONY PROBLEM!
#
# ## Implementacja `remove_static` w bibliotece:
#
# ```python
# # W mmpp/fft/compute_fft.py, linia 362:
# elif filter_type == "remove_static":
#     return data - data[0:1, ...]  # Odejmuje PIERWSZY timestep!
# ```
#
# ## Dlaczego to osłabia niskie częstotliwości?
#
# ### Matematyka:
# 1. **Twój kod**: `data - mean(data, axis=0)`
#    - Usuwa DC component (średnią po całym czasie)
#    - Centruje sygnał wokół zera
#    - ✅ Idealne dla FFT
#
# 2. **`remove_static`**: `data - data[0]`
#    - Tworzy **step function**: pierwsze wartości = 0, reszta ≠ 0
#    - Step function ma widmo: `~1/f` (silne niskie częstotliwości!)
#    - ❌ Te komponenty się **odejmują** od prawdziwego sygnału!
#
# ### Wizualizacja:
# ```
# Oryginał:     ~~~~~~ fala ~~~~~~
# remove_mean:  ~~~~0~~~~ (wycentrowane)
# remove_static: 0_____ potem fala (step!)
#                ↑ ten skok ma silne niskie f!
# ```
#
# ## 💡 Rozwiązanie:
# Dla transmisji **NIE używaj** `remove_static`! Tylko `remove_mean` wystarczy.

# %%
# ✅ TEST ROZWIĄZANIA: Porównaj filter_type=None vs ["remove_mean"] vs ["remove_mean", "remove_static"]

import sys
modules_to_remove = [name for name in sys.modules if name.startswith('mmpp')]
for module in modules_to_remove:
    del sys.modules[module]
import mmpp
import matplotlib.pyplot as plt

job = mmpp.MMPP("/mnt/storage_2/scratch/pl0095-01/zelent/mannga/ksob/YIG_CoFeB_resonators_matrix/CoFeB_d_180nm_p_630nm_La_5um_ant_05um_YIG_70nm_fcut_4GHz_cz_5nm/comsol_verify/transmission/transmission_k_szulc_parameters8mt_v13_olek_long.zarr", debug=False)

print("=" * 80)
print("TEST: Różne strategie filtrowania w bibliotece")
print("=" * 80)

# === TEST 1: Bez filtrów ===
print("\n1️⃣ filter_type=None (bez filtrowania)...")
result_none = job[0].mlayer[:2000, ..., 2].fft.transmission(
    filter_type=None,
    use_cache=False,
    save=False,
    window_function=None,
    spatial_window=1,
    spatial_step=10,  # Większy step dla szybkości
    average_mode="none",
    normalize="none",
)

# === TEST 2: Tylko remove_mean ===
print("\n2️⃣ filter_type=['remove_mean'] (jak Twój kod)...")
result_mean = job[0].mlayer[:2000, ..., 2].fft.transmission(
    filter_type=["remove_mean"],
    use_cache=False,
    save=False,
    window_function=None,
    spatial_window=1,
    spatial_step=10,
    average_mode="none",
    normalize="none",
)

# === TEST 3: remove_mean + remove_static ===
print("\n3️⃣ filter_type=['remove_mean', 'remove_static'] (oryginał)...")
result_both = job[0].mlayer[:2000, ..., 2].fft.transmission(
    filter_type=["remove_mean", "remove_static"],
    use_cache=False,
    save=False,
    window_function=None,
    spatial_window=1,
    spatial_step=10,
    average_mode="none",
    normalize="none",
)

# === PORÓWNANIE ===
print("\n" + "=" * 80)
print("📊 PORÓWNANIE MOCY (średnia po wszystkich x):")
print("=" * 80)
print(f"{'Częstotliwość':<15} {'None':<15} {'remove_mean':<15} {'mean+static':<15} {'Stosunek':<10}")
print("-" * 80)

for idx in [0, 5, 10, 20, 50, 100]:
    power_none = result_none.transmission[idx, :].mean()
    power_mean = result_mean.transmission[idx, :].mean()
    power_both = result_both.transmission[idx, :].mean()
    ratio = power_mean / power_both if power_both > 0 else float('inf')
    
    print(f"f[{idx}]  {power_none:>13.6e}  {power_mean:>13.6e}  {power_both:>13.6e}  {ratio:>8.1f}x")

# === WIZUALIZACJA ===
fig, axes = plt.subplots(1, 3, figsize=(18, 5), dpi=100)

# Wspólne parametry
freq_ghz = result_mean.frequencies / 1e9
x_pos = result_mean.x_positions

# 1. None
im1 = axes[0].imshow(result_none.transmission[:200, :], aspect='auto', origin='lower',
                     extent=[x_pos[0], x_pos[-1], freq_ghz[0], freq_ghz[200]], cmap='viridis')
axes[0].set_title('filter_type=None')
axes[0].set_xlabel('x (nm)')
axes[0].set_ylabel('Frequency (GHz)')
plt.colorbar(im1, ax=axes[0])

# 2. remove_mean (NAJLEPSZE!)
im2 = axes[1].imshow(result_mean.transmission[:200, :], aspect='auto', origin='lower',
                     extent=[x_pos[0], x_pos[-1], freq_ghz[0], freq_ghz[200]], cmap='viridis')
axes[1].set_title('filter_type=[remove_mean] ✅')
axes[1].set_xlabel('x (nm)')
axes[1].set_ylabel('Frequency (GHz)')
plt.colorbar(im2, ax=axes[1])

# 3. remove_mean + remove_static (OSŁABIONE!)
im3 = axes[2].imshow(result_both.transmission[:200, :], aspect='auto', origin='lower',
                     extent=[x_pos[0], x_pos[-1], freq_ghz[0], freq_ghz[200]], cmap='viridis')
axes[2].set_title('filter_type=[remove_mean, remove_static] ❌')
axes[2].set_xlabel('x (nm)')
axes[2].set_ylabel('Frequency (GHz)')
plt.colorbar(im3, ax=axes[2])

plt.tight_layout()
plt.show()

print("\n" + "=" * 80)
print("💡 WNIOSEK:")
print("=" * 80)
print("Użyj filter_type=['remove_mean'] zamiast ['remove_mean', 'remove_static']!")
print("'remove_static' osłabia niskie częstotliwości przez wprowadzenie step function!")
print("=" * 80)

# %% [markdown]
# # 📋 PODSUMOWANIE: Dlaczego biblioteka osłabia niskie częstotliwości?
#
# ## 🎯 Przyczyna główna: `remove_static` filter
#
# ### Co się dzieje:
#
# ```python
# # Twój prosty kod:
# dane2 = dane - dane.mean(axis=0)  # ✅ Usuwa DC, centruje sygnał
# fft = np.fft.rfft(dane2, axis=0)
#
# # Biblioteka z filter_type=["remove_mean", "remove_static"]:
# data = data - data.mean(axis=0)   # remove_mean (OK)
# data = data - data[0, ...]        # remove_static (PROBLEM!)
# fft = np.fft.rfft(data, axis=0)
# ```
#
# ### Dlaczego `remove_static` jest problematyczny?
#
# 1. **Tworzy step function**:
#    - Pierwsze wartości = 0
#    - Potem skok do rzeczywistych wartości
#
# 2. **Step function ma widmo `~1/f`**:
#    - Silne komponenty niskich częstotliwości
#    - Te komponenty **destruktywnie interferują** z prawdziwym sygnałem!
#
# 3. **Wynik**:
#    - Niskie częstotliwości są osłabione o **2-10x**
#    - Wysokie częstotliwości prawie nietknięte
#
# ## ✅ ROZWIĄZANIE
#
# ### Dla transmisji używaj:
# ```python
# result = job[0].mlayer[:, ..., 2].fft.transmission(
#     filter_type=["remove_mean"],  # ✅ Tylko remove_mean!
#     # filter_type=None,            # ✅ Lub w ogóle bez filtrów
#     # ...
# )
# ```
#
# ### Kiedy używać `remove_static`?
# - **NIE** dla transmisji!
# - Może być użyteczny gdy masz **drift** w czasie (np. ogrzewanie)
# - Ale dla normalnych symulacji magnonicznych: **niepotrzebny**
#
# ## 📊 Oczekiwane rezultaty po zmianie:
#
# - Niskie częstotliwości **2-10x silniejsze**
# - Amplitudy bardziej równomierne w całym spektrum
# - Wyniki zbliżone do Twojego prostego kodu!

# %% [markdown]
# # 🔍 PRAWDZIWA DIAGNOZA - skoro filtry nie są problemem!
#
# Jeśli skopiowałeś ten sam kod i działa, to różnica musi być w **INNYM miejscu**:
#
# ## Możliwe różnice:
#
# 1. **Spatial window** - Twój kod: brak okna (cały x), Biblioteka: okna przestrzenne?
# 2. **Averaging** - Twój kod: średnia po czasie dla każdego x osobno
# 3. **Normalizacja** - Czy biblioteka normalizuje przez reference_window?
# 4. **Component weights** - Jak są aplikowane do mocy?
# 5. **Window function** - Czy jest okno czasowe (Hann, etc)?
#
# Sprawdźmy krok po kroku!

# %%
# 🔬 KROK 1: Porównaj DOKŁADNIE Twój kod vs biblioteka

import sys
modules_to_remove = [name for name in sys.modules if name.startswith('mmpp')]
for module in modules_to_remove:
    del sys.modules[module]
import mmpp
import numpy as np

job = mmpp.MMPP("/mnt/storage_2/scratch/pl0095-01/zelent/mannga/ksob/YIG_CoFeB_resonators_matrix/CoFeB_d_180nm_p_630nm_La_5um_ant_05um_YIG_70nm_fcut_4GHz_cz_5nm/comsol_verify/transmission/transmission_k_szulc_parameters8mt_v13_olek_long.zarr", debug=True)

print("=" * 80)
print("DOKŁADNE PORÓWNANIE: Twój kod vs Biblioteka")
print("=" * 80)

# === TWÓJ KOD - DOKŁADNA KOPIA ===
print("\n🟢 TWÓJ KOD (dokładna kopia):")
print("-" * 80)

dane = job[0].mlayer[:2000, 0, 0, :, 2].numpy()  # (t, x)
print(f"1. Dane shape: {dane.shape}")

dane2 = dane - dane.mean(axis=0)
print(f"2. Po remove mean: mean={dane2.mean():.6e}")

dt = job[0].sampling_interval
freqs = np.fft.rfftfreq(dane2.shape[0], dt)
fft_yours = np.fft.rfft(dane2, axis=0)
power_yours = np.abs(fft_yours)**2

print(f"3. FFT shape: {fft_yours.shape}")
print(f"   Power[0:10]: {power_yours[0:10, 500]}")  # x=500
print(f"   Power[0] (DC): {power_yours[0, :].mean():.6e}")
print(f"   Power[10]: {power_yours[10, :].mean():.6e}")
print(f"   Power[100]: {power_yours[100, :].mean():.6e}")

# === BIBLIOTEKA - MINIMALNE USTAWIENIA ===
print("\n🔴 BIBLIOTEKA (z tymi samymi parametrami):")
print("-" * 80)

result_lib = job[0].mlayer[:2000, ..., 2].fft.transmission(
    filter_type=["remove_mean"],  # To samo co Twój kod!
    use_cache=False,
    save=False,
    window_function=None,      # ❓ Brak okna czasowego
    spatial_window=1,          # ❓ Okno 1 punkt = bez spatial window?
    spatial_step=1,
    average_mode="none",       # ❓ Brak averaging
    normalize="none",          # ❓ Brak normalizacji
)

print(f"Biblioteka result shape: {result_lib.transmission.shape}")
print(f"   Power[0:10, x=500]: {result_lib.transmission[0:10, 500]}")
print(f"   Power[0] (DC): {result_lib.transmission[0, :].mean():.6e}")
print(f"   Power[10]: {result_lib.transmission[10, :].mean():.6e}")
print(f"   Power[100]: {result_lib.transmission[100, :].mean():.6e}")

# === PORÓWNANIE WARTOŚĆ PO WARTOŚCI ===
print("\n" + "=" * 80)
print("📊 RÓŻNICE:")
print("=" * 80)

# Wybierz przykładowe x
x_test = 500

print(f"\n🔍 Dla x={x_test}:")
print(f"{'Freq idx':<10} {'Twój kod':<20} {'Biblioteka':<20} {'Stosunek':<15}")
print("-" * 80)
for idx in [0, 5, 10, 20, 50, 100, 200]:
    yours = power_yours[idx, x_test]
    lib = result_lib.transmission[idx, x_test]
    ratio = yours / lib if lib > 0 else float('inf')
    print(f"f[{idx}]  {yours:>18.6e}  {lib:>18.6e}  {ratio:>13.2f}x")

print("\n🔍 Średnia po wszystkich x:")
print(f"{'Freq idx':<10} {'Twój kod':<20} {'Biblioteka':<20} {'Stosunek':<15}")
print("-" * 80)
for idx in [0, 5, 10, 20, 50, 100, 200]:
    yours_mean = power_yours[idx, :].mean()
    lib_mean = result_lib.transmission[idx, :].mean()
    ratio = yours_mean / lib_mean if lib_mean > 0 else float('inf')
    print(f"f[{idx}]  {yours_mean:>18.6e}  {lib_mean:>18.6e}  {ratio:>13.2f}x")

print("\n" + "=" * 80)
if np.allclose(power_yours, result_lib.transmission[:, :dane.shape[1]], rtol=1e-5):
    print("✅ WARTOŚCI SĄ IDENTYCZNE!")
else:
    print("❌ WARTOŚCI SĄ RÓŻNE - szukamy dalej!")
print("=" * 80)

# %% [markdown]
# # 🎯 KLUCZOWE PODEJRZENIE: `spatial_window`!
#
# ## Hipoteza:
#
# Twój kod:
# ```python
# dane = job[0].mlayer[:2000, 0, 0, :, 2]  # WSZYSTKIE x naraz
# fft = np.fft.rfft(dane, axis=0)          # FFT dla każdego x
# ```
#
# Biblioteka z `spatial_window=1`:
# ```python
# # Czy aby na pewno liczy dla KAŻDEGO x osobno?
# # Czy może robi jakieś averaging w oknie?
# ```
#
# ## Sprawdźmy implementację `spatial_window`!
#
# Jeśli `spatial_window > 1`, biblioteka może:
# 1. Uśredniać dane w oknie **PRZED** FFT → osłabia wysokie k (przestrzenne!)
# 2. Robić FFT osobno dla każdego okna → może dawać inne wyniki?

# %% [markdown]
# # ✅ FIX 3: SUMA PO OSI Y (integrate across width)!
#
# ## 🎯 Prawdziwy problem!
#
# Twój kod:
# ```python
# dane = job[0].mlayer[:2000, 0, 0, :, 2]  # (t, x) - tylko y=0
# # ALE potem robisz:
# dane2 = dane - dane.mean(axis=0)
# fft = np.fft.rfft(np.sum(dane2, axis=1), axis=0)  # ← SUMA PO Y!
# ```
#
# **Czekaj... w Twoim kodzie `dane` ma shape `(t, x)` bo bierzesz `[0, 0, :]` więc nie ma osi y!**
#
# Moment, zobaczmy jeszcze raz...
#
# Jeśli używasz `job[0].mlayer[:2000, 0, 0, :, 2]` to:
# - `[:2000]` - czas
# - `0` - pierwsza warstwa z
# - `0` - pierwsza pozycja y
# - `:` - wszystkie x
# - `2` - komponent z
#
# To daje `(2000, 4700)` = `(t, x)` - **NIE MA** wymiaru y!
#
# Ale piszesz że robisz `np.sum(dane2, axis=1)` co sumuje po axis=1, czyli po **x**!
#
# Sprawdźmy to dokładnie...

# %%
["disp_result = job[0].m_resonator[:,...,2].fft.dispersion.filters(","    remove_static=True,","    average=True",").compute_1d(axis=\"x\", orthogonal_avg_mode=\"magnetization\", save_result=True)"]

# %%
# Inspect shapes for manual vs library comparison
for name in ("dane", "dane2", "fft", "result_raw"):
    value = globals().get(name)
    if value is None:
        print(f"{name} is not defined in the current kernel")
        continue
    shape = getattr(value, "shape", None)
    print(f"{name} shape: {shape}")
    if name == "result_raw":
        print("result_raw.transmission shape:", value.transmission.shape)

# %%
# Compare manual FFT amplitude with library transmission output
manual_amp = np.abs(fft)
library_amp = np.sqrt(result_manual.transmission)
abs_diff = np.max(np.abs(manual_amp - library_amp))
rel_diff = np.max(np.abs(manual_amp - library_amp) / (np.maximum(manual_amp, 1e-12)))
print(f"Max absolute difference: {abs_diff:.6e}")
print(f"Max relative difference: {rel_diff:.6e}")

# %%
# Recompute transmission with filters matching manual workflow
result_manual = job[0].mlayer[:, ..., 2].fft.transmission(
    filter_type=["remove_mean", "remove_static"],
    use_cache=False,
    save=False,
    cache_path="/tmp/fft_cache",
    window_function=None,
    spatial_window=1,
    spatial_step=1,
    average_mode="none",
    component_weights=(1.0, 1.0, 1.0),
    normalize="none",
)
print("result_manual.transmission shape:", result_manual.transmission.shape)

# %%
# Detailed comparison statistics
mask = manual_amp > 1e-8
masked_rel_diff = np.abs(manual_amp - library_amp)[mask] / manual_amp[mask]
print(f"Relative difference (median): {np.median(masked_rel_diff):.3e}")
print(f"Relative difference (95th percentile): {np.percentile(masked_rel_diff, 95):.3e}")
print(f"Relative difference (max over masked): {masked_rel_diff.max():.3e}")
print(f"Fraction of points below threshold: {(~mask).mean():.3%}")

# %%
# Locate the maximum relative difference
rel_diff_matrix = np.abs(manual_amp - library_amp) / np.maximum(manual_amp, 1e-12)
max_idx = np.unravel_index(np.argmax(rel_diff_matrix), rel_diff_matrix.shape)
print("Max relative diff location (freq_idx, x_idx):", max_idx)
print("Manual amplitude at max diff:", manual_amp[max_idx])
print("Library amplitude at max diff:", library_amp[max_idx])

# %%
# Verify frequency axis matches manual computation
freq_diff = np.max(np.abs(result_manual.frequencies - freqs))
print(f"Max frequency axis difference: {freq_diff:.6e} Hz")
